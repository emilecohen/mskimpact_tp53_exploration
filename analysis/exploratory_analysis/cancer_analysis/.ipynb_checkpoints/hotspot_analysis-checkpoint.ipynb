# %% [markdown]
# # <span style='font-family:"Times New Roman"'> <span styel=''>**HOTSPOT ANALYSIS**
# *Emile Cohen*
#
#  *June 2020*

# %% [markdown]
# **Goal:** In this notebook, we want to see if the Genome Instability differences we have spot are still present when splitting on the tp53 mutation hotspot. For that, we create different groups to compare GI differences.
#
# ---

# %%
# %run -i '../../../utils/setup_environment.ipy'

import warnings
warnings.filterwarnings('ignore')
from cancer_utils import *
from scipy.stats import fisher_exact, ranksums, chi2, norm
from statsmodels.sandbox.stats.multicomp import multipletests
import matplotlib.gridspec as gridspec

data_path = '../../../data/'
# Out:
# Setup environment... done!
# <span style="color:green">✅ Working on **mskimpact_env** conda environment.</span>

# %%
def boxplot_sampletype(df: pd.DataFrame, group:str, palette, order, metrics: str, figsize= (10,3), title: str = '', title_font: int=12, xlim=[0,1]):
    fig=plt.figure(figsize=figsize)
    ax = plt.subplot2grid(shape=(2,1), loc=(0,0), colspan=1)
    
    sns.boxplot(y=metrics, x=group,data=df,ax=ax, dodge=False,order=order, palette=palette).set_title(title, weight='bold', fontsize=title_font)

    style(ax)
    ax.set_ylim(xlim)
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)

    return fig, ax

# Let's give a look at medians and statistics

def get_statistics(df: pd.DataFrame, group:str, metrics: str, group_list: list):
    group_1 = df[df[group] == group_list[0]][metrics]
    group_2 = df[df[group] == group_list[1]][metrics]

    median_1 = group_1.median()
    median_2 = group_2.median()

    statistic, p_value = ranksums(group_1.dropna().values,group_2.dropna().values)
    
    results = [['', 'size', metrics],
               [group_list[0], group_1.shape[0], median_1],
               [group_list[1], group_2.shape[0], median_2],
               ['', 'Statistics', 'p-value'],
               ['', statistic, p_value]]


    return pd.DataFrame(results)



def get_hotspot_frac(df: pd.DataFrame, group_type:str = None, group: list = None, nb = 10):
    if group_type and group:
        df = df[df[group_type].isin(group)]
    result = [['spot', '#', 'frac']]
    for spot in get_groupby(df, 'tp53_spot_1', 'count').sort_values(by='count', ascending=False).head(nb).index.tolist():
        result.append([spot,df[df['tp53_spot_1'] == spot].frac_genome_altered.shape[0], df[df['tp53_spot_1'] == spot].frac_genome_altered.median()])

    return pd.DataFrame(result)

# %% [markdown]
# # Group Creation

# %% [markdown]
# ## Master loading

# %%
master = non_wgd_load_and_cut(data_path + 'impact-facets-tp53/processed/no_wgd/master_no_wgd.pkl')

# %%
get_hotspot_frac(df=master,
                group_type=None,
                group=None)
# Out:
#        0    1       2
# 0   spot    #    frac
# 1    nan  362   0.316
# 2    273  358  0.2695
# 3    248  325   0.293
# 4    175  229    0.31
# 5    282  147   0.307
# 6    245  144  0.3145
# 7    213  110  0.2935
# 8    342   91   0.296
# 9    220   77   0.317
# 10   196   75   0.329

# %%
wt = get_hotspot_frac(df=master,
                group_type='tp53_group',
                group=['1_WILD_TYPE'])

cnloh = get_hotspot_frac(df=master,
                group_type='tp53_group',
                group=['>=1_cnLOH'])

loss = get_hotspot_frac(df=master,
                group_type='tp53_group',
                group=['>=1_LOSS'])

display_side_by_side(wt, cnloh, loss)
# Out:
#                 <table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>spot</td>
#       <td>#</td>
#       <td>frac</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>273</td>
#       <td>45</td>
#       <td>0.106</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>248</td>
#       <td>43</td>
#       <td>0.237</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>175</td>
#       <td>25</td>
#       <td>0.143</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>nan</td>
#       <td>22</td>
#       <td>0.201</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>245</td>
#       <td>18</td>
#       <td>0.189</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>213</td>
#       <td>17</td>
#       <td>0.086</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>181</td>
#       <td>10</td>
#       <td>0.159</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>282</td>
#       <td>10</td>
#       <td>0.193</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>342</td>
#       <td>8</td>
#       <td>0.186</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>152</td>
#       <td>8</td>
#       <td>0.177</td>
#     </tr>
#   </tbody>
# </table style="display:inline">                <table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>spot</td>
#       <td>#</td>
#       <td>frac</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>273</td>
#       <td>53</td>
#       <td>0.244</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>248</td>
#       <td>46</td>
#       <td>0.356</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>nan</td>
#       <td>37</td>
#       <td>0.41</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>175</td>
#       <td>31</td>
#       <td>0.389</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>282</td>
#       <td>29</td>
#       <td>0.306</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>245</td>
#       <td>16</td>
#       <td>0.3475</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>179</td>
#       <td>14</td>
#       <td>0.402</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>213</td>
#       <td>14</td>
#       <td>0.3205</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>193</td>
#       <td>12</td>
#       <td>0.295</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>242</td>
#       <td>11</td>
#       <td>0.275</td>
#     </tr>
#   </tbody>
# </table style="display:inline">                <table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>spot</td>
#       <td>#</td>
#       <td>frac</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>nan</td>
#       <td>258</td>
#       <td>0.319</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>273</td>
#       <td>215</td>
#       <td>0.299</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>248</td>
#       <td>201</td>
#       <td>0.305</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>175</td>
#       <td>157</td>
#       <td>0.322</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>245</td>
#       <td>95</td>
#       <td>0.33</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>282</td>
#       <td>92</td>
#       <td>0.3105</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>213</td>
#       <td>65</td>
#       <td>0.307</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>196</td>
#       <td>59</td>
#       <td>0.348</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>220</td>
#       <td>57</td>
#       <td>0.321</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>342</td>
#       <td>51</td>
#       <td>0.33</td>
#     </tr>
#   </tbody>
# </table style="display:inline">

# %% [markdown]
# Here, we understand that the hotspot 273 is the less unstable. It is very interesting to see it in the 1_WT subgroup

# %% [markdown]
# ## Definition of the groups
# We define 3 different level groups for the hotspot analysis:
# * Missense / Truncated + In Frame
#     * encoded as mis / tr in column 'hotspot_group_1'
# * Hotspots / Other Missense / Truncated + In Frame
#     * encoded as hot / mis / tr in column 'hotspot_group_2'
# * 248 / 175 / 273 / Other Hotspot / Other Missense
#     * encoded as 248 / 175_273 / other_hot / mis in column 'hotpot_group_3'

# %%
def get_group_1(x):
    if x.tp53_vc_group_1 in ['missense', '175', '248', '273', 'hotspot']:
        return 'mis'
    elif x.tp53_vc_group_1 in ['in_frame', 'truncated']:
        return 'tr'
    
def get_group_2(x):
    if x.tp53_vc_group_1 in ['175', '248', '273', 'hotspot']:
        return 'hot'
    elif x.tp53_vc_group_1 in ['missense']:
        return 'mis'
    elif x.tp53_vc_group_1 in ['in_frame', 'truncated']:
        return 'tr'
    
def get_group_3(x):
    if  x.tp53_vc_group_1 in ['248']:
        return '248'
    elif  x.tp53_vc_group_1 in ['175']:
        return '175'
    elif  x.tp53_vc_group_1 in ['273']:
        return '273'
    elif  x.tp53_vc_group_1 in ['hotspot']:
        return 'other_hot'
    elif  x.tp53_vc_group_1 in ['missense']:
        return 'mis'
    elif x.tp53_vc_group_1 in ['in_frame', 'truncated']:
        return 'tr'

# %%
master['hot_group_1'] = master.apply(get_group_1, axis=1)
master['hot_group_2'] = master.apply(get_group_2, axis=1)
master['hot_group_3'] = master.apply(get_group_3, axis=1)

# %%
groupby_1 = get_groupby(master,'hot_group_1', 'count').sort_values(by='count', ascending=False)
groupby_2 = get_groupby(master,'hot_group_2', 'count').sort_values(by='count', ascending=False)
groupby_3 = get_groupby(master,'hot_group_3', 'count').sort_values(by='count', ascending=False)

display_side_by_side(groupby_1, groupby_2, groupby_3)
# Out:
#                 <table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>hot_group_1</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>mis</th>
#       <td>3331</td>
#     </tr>
#     <tr>
#       <th>tr</th>
#       <td>1847</td>
#     </tr>
#   </tbody>
# </table style="display:inline">                <table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>hot_group_2</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>mis</th>
#       <td>2036</td>
#     </tr>
#     <tr>
#       <th>tr</th>
#       <td>1847</td>
#     </tr>
#     <tr>
#       <th>hot</th>
#       <td>1295</td>
#     </tr>
#   </tbody>
# </table style="display:inline">                <table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>hot_group_3</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>mis</th>
#       <td>2036</td>
#     </tr>
#     <tr>
#       <th>tr</th>
#       <td>1847</td>
#     </tr>
#     <tr>
#       <th>other_hot</th>
#       <td>388</td>
#     </tr>
#     <tr>
#       <th>273</th>
#       <td>354</td>
#     </tr>
#     <tr>
#       <th>248</th>
#       <td>325</td>
#     </tr>
#     <tr>
#       <th>175</th>
#       <td>228</td>
#     </tr>
#   </tbody>
# </table style="display:inline">

# %% [markdown]
# # Group Comparison

# %% [markdown]
# ## Group 1

# %%
fig, ax = boxplot_sampletype(df=master,
                  group='hot_group_1',
                  palette={'mis': '#FF9900' , 'tr': '#146EB4'},
                  order=['mis', 'tr'],
                  metrics='frac_genome_altered',
                  figsize=(4,8),
                  title='Fraction of Genome Altered',
                  xlim=[0,1])
plt.show()

display(get_statistics(df=master,
               group='hot_group_1',
               metrics='frac_genome_altered', 
               group_list=['mis', 'tr']))
# Out:
#      0           1                    2
# 0             size  frac_genome_altered
# 1  mis        3331                0.298
# 2   tr        1847                0.321
# 3       Statistics              p-value
# 4         -3.93654          8.26656e-05

# %% [markdown]
# ## Group 2

# %%
fig, ax = boxplot_sampletype(df=master,
                  group='hot_group_2',
                  palette={'mis': '#FF9900' , 'tr': '#146EB4', 'hot': '#1E8449'},
                  order=['hot', 'mis', 'tr'],
                  metrics='frac_genome_altered',
                  figsize=(4,8),
                  title='Fraction of Genome Altered',
                  xlim=[0,1])
plt.show()

display_side_by_side(get_statistics(df=master,
               group='hot_group_2',
               metrics='frac_genome_altered', 
               group_list=['hot', 'mis']),
                    get_statistics(df=master,
               group='hot_group_2',
               metrics='frac_genome_altered', 
               group_list=['hot', 'tr']))
# Out:
#                 <table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td></td>
#       <td>size</td>
#       <td>frac_genome_altered</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>hot</td>
#       <td>1295</td>
#       <td>0.295</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>mis</td>
#       <td>2036</td>
#       <td>0.301</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td></td>
#       <td>Statistics</td>
#       <td>p-value</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td></td>
#       <td>-0.860228</td>
#       <td>0.389664</td>
#     </tr>
#   </tbody>
# </table style="display:inline">                <table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td></td>
#       <td>size</td>
#       <td>frac_genome_altered</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>hot</td>
#       <td>1295</td>
#       <td>0.295</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>tr</td>
#       <td>1847</td>
#       <td>0.321</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td></td>
#       <td>Statistics</td>
#       <td>p-value</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td></td>
#       <td>-3.66483</td>
#       <td>0.000247498</td>
#     </tr>
#   </tbody>
# </table style="display:inline">

# %% [markdown]
# ## Group 3

# %% [markdown]
# ### All cohort

# %%
mc = list(islice(cycle(list(sns.color_palette("muted"))), None, 6))

fig, ax = boxplot_sampletype(df=master,
                  group='hot_group_3',
                  palette={'mis': '#FF9900', 'other_hot': '#1E8449',  '175':mc[3], '248':mc[4], '273':mc[5], 'tr': '#146EB4'},
                  order=['248', '175', '273', 'other_hot', 'mis', 'tr'],
                  metrics='frac_genome_altered',
                  figsize=(4,8),
                  title='Fraction of Genome Altered',
                  xlim=[0,1])
plt.show()

display(get_statistics(df=master,
               group='hot_group_3',
               metrics='frac_genome_altered', 
               group_list=['248', '273']))
# Out:
#      0           1                    2
# 0             size  frac_genome_altered
# 1  248         325                0.293
# 2  273         354               0.2705
# 3       Statistics              p-value
# 4          2.50124            0.0123758

# %% [markdown]
# ### Pan cancer plot

# %%
# Out:
# ['Breast Cancer',
#  'Colorectal Cancer',
#  'Non-Small Cell Lung Cancer',
#  'Pancreatic Cancer',
#  'Prostate Cancer',
#  'Glioma',
#  'Bladder Cancer',
#  'Cancer of Unknown Primary',
#  'Ovarian Cancer',
#  'Hepatobiliary Cancer',
#  'Endometrial Cancer',
#  'Esophagogastric Cancer',
#  'Melanoma',
#  'Soft Tissue Sarcoma',
#  'Small Cell Lung Cancer',
#  'Head and Neck Cancer',
#  'Renal Cell Carcinoma',
#  'Skin Cancer, Non-Melanoma',
#  'Thyroid Cancer',
#  'Mesothelioma',
#  'Uterine Sarcoma',
#  'Gastrointestinal Stromal Tumor',
#  'Bone Cancer',
#  'Salivary Gland Cancer',
#  'Cervical Cancer',
#  'Mature B-Cell Neoplasms',
#  'Small Bowel Cancer',
#  'Gastrointestinal Neuroendocrine Tumor',
#  'Ampullary Cancer',
#  'Appendiceal Cancer',
#  'Breast Sarcoma',
#  'Germ Cell Tumor',
#  'Peripheral Nervous System',
#  'CNS Cancer',
#  'Retinoblastoma',
#  'Anal Cancer',
#  'Adrenocortical Carcinoma',
#  'Thymic Tumor',
#  'Vaginal Cancer',
#  'Embryonal Tumor',
#  'Nerve Sheath Tumor',
#  'Sellar Tumor',
#  'Mature T and NK Neoplasms',
#  'Wilms Tumor',
#  'Peritoneal Cancer, NOS',
#  'Sex Cord Stromal Tumor',
#  'Miscellaneous Neuroepithelial Tumor',
#  'Miscellaneous Brain Tumor',
#  'Penile Cancer',
#  'Gestational Trophoblastic Disease',
#  'Choroid Plexus Tumor',
#  'B-Lymphoblastic Leukemia/Lymphoma']

# %%
# Filter and order the samples in order to plot with decreasing medians on the cnloh subgroup
cancer_count = get_groupby(master[~master['tp53_group'].isna()], 'Cancer_Type', 'count').sort_values(by='count', ascending = False)
cancer_list = list(cancer_count[cancer_count['count']>=70].index.values)
master_list = master[master['Cancer_Type'].isin(cancer_list)]
cancer_count = get_groupby(mastermaster_list[~master['tp53_group'].isna()], 'Cancer_Type', 'count').sort_values(by='count', ascending = False)
cancer_order = cancer_count.index.tolist()
samples_list_ordered=[]
for cancer in cancer_order:
    samples_list_ordered = samples_list_ordered + master_list[master_list['Cancer_Type'] == cancer].index.tolist()
#samples_list_ordered

master_ordered = master_list.reindex(samples_list_ordered)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-133-d743c54bf4c0> in <module>
#       1 # Filter and order the samples in order to plot with decreasing medians on the cnloh subgroup
#       2
# ----> 3 cancer_list = list(cancer_count[cancer_count['count']>=70].index.values)
#       4 master_list = master[master['Cancer_Type'].isin(cancer_list)]
#       5 cancer_order = master_list.groupby('Cancer_Type')['Sample_Id']\
#
# NameError: name 'cancer_count' is not defined

# %% [markdown]
# ### 1_WILD_TYPE subgroup

# %%
mc = list(islice(cycle(list(sns.color_palette("muted"))), None, 6))
master_wt = master[master['tp53_group'] == '1_WILD_TYPE']

fig, ax = boxplot_sampletype(df=master_wt,
                  group='hot_group_3',
                  palette={'mis': '#FF9900', 'other_hot': '#1E8449',  '175':mc[3], '248':mc[4], '273':mc[5], 'tr': '#146EB4'},
                  order=['248', '175', '273', 'other_hot', 'mis', 'tr'],
                  metrics='frac_genome_altered',
                  figsize=(4,8),
                  title='Fraction of Genome Altered - 1_WILD_TYPE subgroup',
                  xlim=[0,1])
plt.show()

display(get_statistics(df=master,
               group='hot_group_3',
               metrics='frac_genome_altered', 
               group_list=['248', '273']))
# Out:
#      0           1                    2
# 0             size  frac_genome_altered
# 1  248         325                0.293
# 2  273         354               0.2705
# 3       Statistics              p-value
# 4          2.50124            0.0123758

# %% [markdown]
# ## Colorectal Cancer

# %%
master_cancer = master[master['Cancer_Type'] == 'Colorectal Cancer']

get_hotspot_frac(df=master_cancer,
                group_type=None,
                group=None)
# Out:
#        0    1       2
# 0   spot    #    frac
# 1    273  105   0.317
# 2    175   74   0.349
# 3    248   68   0.312
# 4    282   52    0.32
# 5    nan   42   0.309
# 6    245   34  0.3195
# 7    213   26   0.285
# 8    196   23    0.31
# 9    342   18   0.265
# 10   306   17   0.255

# %% [markdown]
# ### All samples

# %%
fig, ax = boxplot_sampletype(df=master_cancer,
                  group='hot_group_3',
                  palette={'mis': '#FF9900', 'other_hot': '#1E8449',  '175':mc[3], '248':mc[4], '273':mc[5], 'tr': '#146EB4'},
                  order=['248', '175', '273', 'other_hot', 'mis', 'tr'],
                  metrics='frac_genome_altered',
                  figsize=(4,8),
                  title='Fraction of Genome Altered - Colorectal Cancer',
                  xlim=[0,1])
plt.show()

display(get_groupby(master_cancer,'hot_group_3', 'count').sort_values(by='count', ascending=False))
# Out:
#              count
# hot_group_3
# tr             295
# mis            254
# 273            105
# other_hot      101
# 175             74
# 248             68

# %% [markdown]
# ### 1 WILD TYPE

# %%
get_hotspot_frac(df=master_cancer_wt,
                group_type=None,
                group=None,
                nb=20)

get_hotspot_frac(df = master[master['Cancer_Type'] == 'Non-Small Cell Lung Cancer'][master['tp53_group'] == '1_WILD_TYPE'],
                 group_type=None,
                group=None,
                nb=20)
# Out:
#        0  1       2
# 0   spot  #    frac
# 1    nan  5   0.216
# 2    273  5   0.055
# 3    248  5   0.307
# 4    214  3   0.076
# 5    285  2   0.318
# 6    245  2   0.216
# 7    141  2   0.053
# 8    156  2  0.3155
# 9    158  2  0.2705
# 10   162  2  0.3335
# 11   213  2   0.041
# 12   279  1   0.206
# 13   282  1   0.072
# 14   284  1   0.082
# 15   321  1   0.503
# 16   312  1       0
# 17   317  1   0.603
# 18    35  1   0.445
# 19   392  1   0.104
# 20    40  1   0.408

# %% [markdown]
# We see a dichotomy between very unstable hotspots (175, 282, 135, 248) and very stable hotspots (273, 245, 213, 90)

# %%
master_cancer_wt = master_cancer[master_cancer['tp53_group'] == '1_WILD_TYPE']
fig, ax = boxplot_sampletype(df=master_cancer_wt,
                  group='hot_group_3',
                  palette={'mis': '#FF9900', 'other_hot': '#1E8449',  '175':mc[3], '248':mc[4], '273':mc[5], 'tr': '#146EB4'},
                  order=['248', '175', '273', 'other_hot', 'mis', 'tr'],
                  metrics='frac_genome_altered',
                  figsize=(4,8),
                  title='Fraction of Genome Altered - Colorectal Cancer',
                  xlim=[0,1])
plt.show()

display(get_groupby(master_cancer_wt,'hot_group_3', 'count').sort_values(by='count', ascending=False))
# Out:
#              count
# hot_group_3
# tr              30
# mis             29
# 273             11
# 175              9
# other_hot        9
# 248              3

# %% [markdown]
# What would be the new 1_WT median if we remove 273

# %%
master_cancer_wt[~master_cancer_wt['tp53_spot_1'].isin(['273', '245', '213', '90'])].frac_genome_altered.median()
# Out:
# 0.147

# %%
master_cancer = master[master['Cancer_Type'] == 'Colorectal Cancer']
display(get_statistics(df=master_cancer,
               group='tp53_group',
               metrics='frac_genome_altered', 
               group_list=['1_WILD_TYPE', '0_HETLOSS']))
# Out:
#              0           1                    2
# 0                     size  frac_genome_altered
# 1  1_WILD_TYPE          92               0.1295
# 2    0_HETLOSS         136               0.2875
# 3               Statistics              p-value
# 4                 -6.06375          1.32985e-09
