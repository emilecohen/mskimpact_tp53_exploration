# %% [markdown]
# # <span style='font-family:"Times New Roman"'> <span styel=''> **>1muts SUBGROUP EXPLORATION**
#
# ## <span style='font-family:"Times New Roman"'> <span styel=''> *Emile Cohen*
# *March 2020*

# %% [markdown]
# **Goal:** In this notebook, we want to understand why the >1muts subgroup has a very different overall number of mutations and a different distribution of mutation Type. For that we will distinguish between the different cancer Type and try categorizing on the clonality of the samples.
#
# The Notebook is divided in X parts:
#
#
#
# **NB1:** In each part, you must run the cells from the begining in order to initialize the variables
#
# **NB2:** All functions used for the plots are located in utils/custom_tools.py
#
# ---

# %%
# %run -i '../../utils/setup_environment.ipy'
from utils.analysis_tools import *

import warnings, math
warnings.filterwarnings('ignore')
import ptitprince as pt
import IPython.display

data_path = '../../data/'
# Out:
# Setup environment... done!
# <span style="color:green">✅ Working on **mskimpact_env** conda environment.</span>

# %% [markdown]
# ---

# %%
# Loading the master
master = pd.read_pickle(data_path + 'merged_data/master_file.pkl')
master_sub = master[master['mut_cn_group'] == '>1muts']
master_sub
# Out:
#                                  Sample_Id           Tumor_Id Patient_Id  \
# 109    P-0022536-T01-IM6_P-0022536-N01-IM6  P-0022536-T01-IM6  P-0022536
# 115    P-0001253-T01-IM3_P-0001253-N01-IM3  P-0001253-T01-IM3  P-0001253
# 229    P-0006754-T01-IM5_P-0006754-N01-IM5  P-0006754-T01-IM5  P-0006754
# 268    P-0028367-T01-IM6_P-0028367-N01-IM6  P-0028367-T01-IM6  P-0028367
# 298    P-0013783-T01-IM5_P-0013783-N01-IM5  P-0013783-T01-IM5  P-0013783
# ...                                    ...                ...        ...
# 29188  P-0050446-T01-IM6_P-0050446-N01-IM6  P-0050446-T01-IM6  P-0050446
# 29224  P-0050559-T01-IM6_P-0050559-N01-IM6  P-0050559-T01-IM6  P-0050559
# 29226  P-0050639-T01-IM6_P-0050639-N01-IM6  P-0050639-T01-IM6  P-0050639
# 29248  P-0050421-T01-IM6_P-0050421-N01-IM6  P-0050421-T01-IM6  P-0050421
# 29282  P-0050204-T01-IM6_P-0050204-N01-IM6  P-0050204-T01-IM6  P-0050204
#
#                      Cancer_Type Sample_Type    purity    ploidy  \
# 109                       Glioma  Metastasis  0.621794  1.964867
# 115                       Glioma     Primary  0.945316  3.473627
# 229    Skin Cancer, Non-Melanoma  Metastasis  0.207614  1.894433
# 268         Head and Neck Cancer     Primary  0.468725  1.896462
# 298                       Glioma     Primary  0.933909  2.828483
# ...                          ...         ...       ...       ...
# 29188         Endometrial Cancer     Primary  0.277528  2.301555
# 29224             Bladder Cancer     Primary  0.162500  2.623393
# 29226             Ovarian Cancer     Primary  0.271635  3.810809
# 29248                   Melanoma  Metastasis  0.366186  2.354581
# 29282  Cancer of Unknown Primary  Metastasis  0.398650  2.043738
#
#        samples_per_patient Overall Survival Status  Overall Survival (Months)  \
# 109                    1.0                DECEASED                      3.255
# 115                    1.0                  LIVING                     65.096
# 229                    1.0                DECEASED                     18.016
# 268                    1.0                  LIVING                     23.573
# 298                    1.0                  LIVING                     18.937
# ...                    ...                     ...                        ...
# 29188                  1.0                  LIVING                      1.775
# 29224                  1.0                  LIVING                        NaN
# 29226                  1.0                  LIVING                      1.874
# 29248                  1.0                  LIVING                      1.578
# 29282                  1.0                  LIVING                      2.071
#
#        MSI Score                                           key_1  \
# 109         0.14                P-0022536-T01-IM6_17_7577094_G_A
# 115         0.78                P-0001253-T01-IM3_17_7577544_A_G
# 229         0.15                P-0006754-T01-IM5_17_7577539_G_A
# 268         0.36                P-0028367-T01-IM6_17_7578181_G_A
# 298         0.67                P-0013783-T01-IM5_17_7578406_C_T
# ...          ...                                             ...
# 29188       0.00  P-0050446-T01-IM6_17_7577105_-_GACAGGCACAAACAC
# 29224       0.00                P-0050559-T01-IM6_17_7577085_C_T
# 29226       0.00                P-0050639-T01-IM6_17_7578442_T_C
# 29248       0.06                P-0050421-T01-IM6_17_7576897_G_A
# 29282      10.93                P-0050204-T01-IM6_17_7576858_G_T
#
#                     vc_1  ccf_1     vaf_1             HGVSp_1 spot_1  \
# 109    Missense_Mutation  0.961  0.298893         p.Arg282Trp    282
# 115    Missense_Mutation  0.899  0.424779         p.Met246Thr    246
# 229    Missense_Mutation  0.567  0.058875         p.Arg248Trp    248
# 268    Missense_Mutation  0.989  0.231844         p.Pro223Leu    223
# 298    Missense_Mutation  1.000  0.494505         p.Arg175His    175
# ...                  ...    ...       ...                 ...    ...
# 29188       In_Frame_Ins  0.548  0.056352  p.Arg273_Cys277dup    273
# 29224  Missense_Mutation  1.000  0.082731         p.Glu285Lys    285
# 29226  Missense_Mutation  0.407  0.055229         p.Tyr163Cys    163
# 29248  Nonsense_Mutation  0.743  0.140078         p.Gln317Ter    317
# 29282  Missense_Mutation  0.889  0.174966         p.Leu330Ile    330
#
#                                     key_2               vc_2  ccf_2     vaf_2  \
# 109      P-0022536-T01-IM6_17_7577120_C_T  Missense_Mutation  1.000  0.314172
# 115      P-0001253-T01-IM3_17_7577570_C_A  Missense_Mutation  0.844  0.399038
# 229    P-0006754-T01-IM5_17_7579414_CC_TT  Nonsense_Mutation  1.000  0.104612
# 268      P-0028367-T01-IM6_17_7579378_G_C  Nonsense_Mutation  1.000  0.253644
# 298      P-0013783-T01-IM5_17_7579328_T_-    Frame_Shift_Del  0.988  0.461538
# ...                                   ...                ...    ...       ...
# 29188    P-0050446-T01-IM6_17_7578406_C_T  Missense_Mutation  0.862  0.088652
# 29224    P-0050559-T01-IM6_17_7578211_C_T  Missense_Mutation  0.590  0.047964
# 29226   P-0050639-T01-IM6_17_7578501_CA_-    Frame_Shift_Del  1.000  0.166667
# 29248    P-0050421-T01-IM6_17_7578479_G_A  Missense_Mutation  0.709  0.133676
# 29282    P-0050204-T01-IM6_17_7577504_G_T  Missense_Mutation  1.000  0.354992
#
#                  HGVSp_2 spot_2                             key_3  \
# 109          p.Arg273His    273                              None
# 115          p.Met237Ile    237                              None
# 229           p.Trp91Ter     91                              None
# 268          p.Tyr103Ter    103                              None
# 298    p.Lys120SerfsTer3    120                              None
# ...                  ...    ...                               ...
# 29188        p.Arg175His    175                              None
# 29224        p.Arg213Gln    213                              None
# 29226  p.Val143AlafsTer5    143  P-0050639-T01-IM6_17_7579715_A_-
# 29248        p.Pro151Ser    151                              None
# 29282        p.Asp259Glu    259  P-0050204-T01-IM6_17_7578212_G_A
#
#                     vc_3  ccf_3     vaf_3            HGVSp_3 spot_3  \
# 109                 None    NaN       NaN               None   None
# 115                 None    NaN       NaN               None   None
# 229                 None    NaN       NaN               None   None
# 268                 None    NaN       NaN               None   None
# 298                 None    NaN       NaN               None   None
# ...                  ...    ...       ...                ...    ...
# 29188               None    NaN       NaN               None   None
# 29224               None    NaN       NaN               None   None
# 29226    Frame_Shift_Del  0.898  0.121908  p.Glu28LysfsTer16     28
# 29248               None    NaN       NaN               None   None
# 29282  Nonsense_Mutation  1.000  0.700993        p.Arg213Ter    213
#
#                                   key_4               vc_4  ccf_4     vaf_4  \
# 109                                None               None    NaN       NaN
# 115                                None               None    NaN       NaN
# 229                                None               None    NaN       NaN
# 268                                None               None    NaN       NaN
# 298                                None               None    NaN       NaN
# ...                                 ...                ...    ...       ...
# 29188                              None               None    NaN       NaN
# 29224                              None               None    NaN       NaN
# 29226                              None               None    NaN       NaN
# 29248                              None               None    NaN       NaN
# 29282  P-0050204-T01-IM6_17_7578263_G_A  Nonsense_Mutation    1.0  0.339105
#
#            HGVSp_4 spot_4 key_5  vc_5  ccf_5  vaf_5 HGVSp_5 spot_5  \
# 109           None   None  None  None    NaN    NaN    None   None
# 115           None   None  None  None    NaN    NaN    None   None
# 229           None   None  None  None    NaN    NaN    None   None
# 268           None   None  None  None    NaN    NaN    None   None
# 298           None   None  None  None    NaN    NaN    None   None
# ...            ...    ...   ...   ...    ...    ...     ...    ...
# 29188         None   None  None  None    NaN    NaN    None   None
# 29224         None   None  None  None    NaN    NaN    None   None
# 29226         None   None  None  None    NaN    NaN    None   None
# 29248         None   None  None  None    NaN    NaN    None   None
# 29282  p.Arg196Ter    196  None  None    NaN    NaN    None   None
#
#        tp53_count  tcn  mcn  lcn  seg_length           cn_state   cf  wgd  \
# 109             2  2.0  1.0  1.0  80668564.0            DIPLOID  1.0 -1.0
# 115             2  2.0  1.0  1.0  41161397.0  DOUBLE LOSS AFTER  1.0  1.0
# 229             2  2.0  1.0  1.0  80668459.0            DIPLOID  1.0 -1.0
# 268             2  2.0  1.0  1.0  38397131.0            DIPLOID  1.0 -1.0
# 298             2  2.0  1.0  1.0  80668431.0  DOUBLE LOSS AFTER  1.0  1.0
# ...           ...  ...  ...  ...         ...                ...  ...  ...
# 29188           2  2.0  1.0  1.0  38389981.0            DIPLOID  1.0 -1.0
# 29224           2  2.0  1.0  1.0  80668611.0            DIPLOID  1.0 -1.0
# 29226           3  2.0  1.0  1.0  35946628.0  DOUBLE LOSS AFTER  1.0  1.0
# 29248           2  2.0  1.0  1.0  37534691.0            DIPLOID  1.0 -1.0
# 29282           4  2.0  1.0  1.0  80668431.0            DIPLOID  1.0 -1.0
#
#        mutation_count  gene_count   max_vaf  exp_nb_1  exp_nb_2  exp_nb_3  \
# 109                 5         4.0  0.337368  0.961389  1.010535       NaN
# 115                 5         4.0  0.424779  0.898702  0.844243       NaN
# 229                67        56.0  0.189802  0.567161  1.007756       NaN
# 268                11        10.0  0.479381  0.989252  1.082273       NaN
# 298                 9         6.0  0.940000  1.059001  0.988401       NaN
# ...               ...         ...       ...       ...       ...       ...
# 29188               5         4.0  0.320635  0.406103  0.638872       NaN
# 29224              15        13.0  0.694444  1.018230  0.590325       NaN
# 29226               7         5.0  0.310096  0.406643  1.227138  0.897589
# 29248              64        57.0  0.647910  0.765063  0.730099       NaN
# 29282             571       266.0  0.700993  0.877795  1.780972  3.516833
#
#        exp_nb_4  exp_nb_5           cn_group mut_cn_group      chr_comput  \
# 109         NaN       NaN          WILD_TYPE       >1muts    (5, 4, 1, 0)
# 115         NaN       NaN  DOUBLE LOSS AFTER       >1muts  (20, 2, 19, 1)
# 229         NaN       NaN          WILD_TYPE       >1muts    (5, 5, 0, 1)
# 268         NaN       NaN          WILD_TYPE       >1muts    (2, 1, 1, 0)
# 298         NaN       NaN  DOUBLE LOSS AFTER       >1muts  (19, 11, 8, 1)
# ...         ...       ...                ...          ...             ...
# 29188       NaN       NaN          WILD_TYPE       >1muts    (5, 3, 0, 2)
# 29224       NaN       NaN          WILD_TYPE       >1muts    (3, 1, 1, 1)
# 29226       NaN       NaN  DOUBLE LOSS AFTER       >1muts  (22, 15, 5, 2)
# 29248       NaN       NaN          WILD_TYPE       >1muts    (7, 4, 3, 0)
# 29282  1.701269       NaN          WILD_TYPE       >1muts    (8, 5, 3, 2)
#
#        chr_affected  chr_loss  chr_gain  chr_cnloh vc_group_1 vc_group_2  \
# 109               5         4         1          0   missense   missense
# 115              20         2        19          1   missense   missense
# 229               5         5         0          1   missense  truncated
# 268               2         1         1          0   missense  truncated
# 298              19        11         8          1   missense  truncated
# ...             ...       ...       ...        ...        ...        ...
# 29188             5         3         0          2   in_frame   missense
# 29224             3         1         1          1   missense   missense
# 29226            22        15         5          2   missense  truncated
# 29248             7         4         3          0  truncated   missense
# 29282             8         5         3          2   missense   missense
#
#       vc_group_3 vc_group_4 vc_group_5
# 109         None       None       None
# 115         None       None       None
# 229         None       None       None
# 268         None       None       None
# 298         None       None       None
# ...          ...        ...        ...
# 29188       None       None       None
# 29224       None       None       None
# 29226  truncated       None       None
# 29248       None       None       None
# 29282  truncated  truncated       None
#
# [697 rows x 69 columns]

# %%
print('Number of samples in the subgroup: ' + str(len(master_sub)))
# Out:
# Number of samples in the subgroup: 697

# %% [markdown]
# ### Distribution per Cancer Type

# %%
count = pd.DataFrame(pd.DataFrame(master_sub[['Cancer_Type']].groupby(['Cancer_Type']).size(), columns=['count']))#.groupby(['mut_cn_group','Cancer_Type']).sum()).unstack().sort_values(by=[('count',0)])
count = count[count['count']>=0]

count = count.sort_values(by=['count'], ascending=False)
display(count)

# We plot the table
get_ploth(count.index, 'count', count, 'Cancer Type', '','Number of samples per cancer type',figsize=(10,10), perc=True)
# Out:
#                                        count
# Cancer_Type
# Colorectal Cancer                        116
# Non-Small Cell Lung Cancer               110
# Glioma                                   101
# Bladder Cancer                            60
# Skin Cancer, Non-Melanoma                 44
# Cancer of Unknown Primary                 43
# Head and Neck Cancer                      39
# Endometrial Cancer                        35
# Esophagogastric Cancer                    28
# Melanoma                                  18
# Soft Tissue Sarcoma                       14
# Prostate Cancer                           14
# Breast Cancer                              9
# Germ Cell Tumor                            8
# Small Cell Lung Cancer                     7
# Pancreatic Cancer                          7
# Vaginal Cancer                             7
# Hepatobiliary Cancer                       6
# Uterine Sarcoma                            4
# Ovarian Cancer                             3
# Thyroid Cancer                             3
# Mature B-Cell Neoplasms                    2
# Mesothelioma                               2
# Miscellaneous Brain Tumor                  2
# Anal Cancer                                2
# Gastrointestinal Neuroendocrine Tumor      2
# Cervical Cancer                            2
# Small Bowel Cancer                         2
# Bone Cancer                                2
# B-Lymphoblastic Leukemia/Lymphoma          2
# Embryonal Tumor                            1
# Sex Cord Stromal Tumor                     1
# Ampullary Cancer                           1

# %% [markdown]
# ### Mutation count per Cancer Type

# %%
fig=plt.figure(figsize=(16,15))
fig.suptitle('Mutation/Gene Count per Cancer Type', fontsize=16, weight='bold')
ax1 = plt.subplot2grid(shape=(1,1), loc=(0,0), colspan=1)
ax1.set_xlim(0, 150)

data = master_sub[['tp53_count', 'Cancer_Type', 'mutation_count','gene_count']]
data['mutation_count_adjusted'] = data['mutation_count'] - data['tp53_count']

sns.boxplot(y="Cancer_Type", x="mutation_count_adjusted",data=data,ax=ax1, dodge=False, color='mediumpurple', order = count.index).set_title('Mutation Count per Cancer Type', weight='bold', fontsize=14)
# Out:
# Text(0.5, 1.0, 'Mutation Count per Cancer Type')

# %% [markdown]
# ### Categorizing based on the clonality
