# %% [markdown]
# # <span style='font-family:"Times New Roman"'> <span styel=''>**WHOLE GENOME DOUBLING ANALYSIS**
#
# *Emile Cohen*
#
#  *May 2020*

# %% [markdown]
# **Goal:** In this notebook, we analyse all MSK-Imoact Cohort to know the proportion of WGD Samples, the tp53 mutated samples. Then we output a diagram with important information.
#
# ---

# %%
# %run -i '../../../utils/setup_environment.ipy'

import warnings
warnings.filterwarnings('ignore')
from scipy.stats import fisher_exact, ranksums, chi2, norm
from statsmodels.sandbox.stats.multicomp import multipletests
import matplotlib.gridspec as gridspec

data_path = '../../../data/'
# Out:
# Setup environment... done!
# <span style="color:green">✅ Working on **mskimpact_env** conda environment.</span>

# %% [markdown]
# # MSK-Impact Cohort

# %% [markdown]
# ## Size

# %%
# Loading the data
maf_cohort = pd.read_csv(data_path + 'impact-facets-tp53/new_data_facets/msk_impact_facets_annotated.ccf.maf', sep='\t')
annotated_cohort = pd.read_csv(data_path + 'impact-facets-tp53/new_data_facets/msk_impact_facets_annotated.cohort.txt', sep='\t')
arm_level = pd.read_csv(data_path + 'impact-facets-tp53/new_data_facets/msk_impact_facets_annotated.arm_level.txt', sep='\t')
gene_level = pd.read_csv(data_path + 'impact-facets-tp53/new_data_facets/msk_impact_facets_annotated.gene_level_grepTP53.txt', sep='\t')

# %% [markdown]
# The following cell shows the size of the total cohort through the different input files. We see that the cohort is more than 40 000 samples but only 38 465 have mutational information.

# %%
img = WImage(filename='total_cohort.pdf', resolution=150)
img
# Out:
# <wand.image.Image: 5539cc3 'PDF' (544x261)>

# %% [markdown]
# ## WGD column
# The annotated_cohort have a column called *wgd*. On the other side, for the TP53 mutated cohort, we computed the WGD states by hand. Let's see if the WGD column is accurate.

# %%
#Loading the master_file
master = pd.read_pickle(data_path + 'merged_data/master_file.pkl')
#master = master[['Tumor_Id', 'wgd']]

# %%
annotated_cohort_wgd = annotated_cohort[['tumor_sample', 'wgd']]

# %%
# left merge 
merged = pd.merge(left=master, right=annotated_cohort_wgd, how='left', left_on='Tumor_Id', right_on='tumor_sample')
merged.head()
# Out:
#             Tumor_Id  wgd_x       tumor_sample  wgd_y
# 0  P-0034223-T01-IM6     -1  P-0034223-T01-IM6  False
# 1  P-0009819-T01-IM5     -1  P-0009819-T01-IM5  False
# 2  P-0025956-T01-IM6      1  P-0025956-T01-IM6   True
# 3  P-0027408-T01-IM6     -1  P-0027408-T01-IM6  False
# 4  P-0006554-T01-IM5     -1  P-0006554-T01-IM5  False

# %%
len(set(annotated_cohort[annotated_cohort['purity'] >= 0.2].tumor_sample))
# Out:
# 34491

# %% [markdown]
# Now the idea is to compare *wgd_x* and *wgd_y* to see if there are inconsistencies.

# %%
# We define a function to create a new column
def check_inconsistencies(x):
    if (x.wgd_x == 1 and x.wgd_y == True) or (x.wgd_x == -1 and x.wgd_y == False):
        return 0
    elif: return 1
    
merged['inconsistencies'] = merged.apply(check_inconsistencies, axis=1)

# %%
# now we sum the inconsistencies column to see if we have any inconsistency. We should have 0 for no inconsitencies at all.
merged.inconsistencies.sum()
# Out:
# 121

# %% [markdown]
# So we have 121 samples with problems: let's take a look.

# %%
merged[merged['inconsistencies'] == 1][~merged.wgd_y.isna()]
# Out:
#                 Tumor_Id  wgd_x       tumor_sample wgd_y  inconsistencies
# 2596   P-0011205-T03-IM6     -1  P-0011205-T03-IM6  True                1
# 3906   P-0035720-T01-IM6     -1  P-0035720-T01-IM6  True                1
# 4201   P-0020803-T02-IM6     -1  P-0020803-T02-IM6  True                1
# 6153   P-0022193-T02-IM6     -1  P-0022193-T02-IM6  True                1
# 11524  P-0016952-T02-IM6     -1  P-0016952-T02-IM6  True                1
# 20395  P-0005192-T01-IM5     -1  P-0005192-T01-IM5  True                1
# 21326  P-0018318-T01-IM6     -1  P-0018318-T01-IM6  True                1
# 23992  P-0031102-T06-IM6     -1  P-0031102-T06-IM6  True                1
# 26782  P-0046593-T02-IM6     -1  P-0046593-T02-IM6  True                1
# 27950  P-0031010-T03-IM6     -1  P-0031010-T03-IM6  True                1

# %% [markdown]
# We see that those inconsistencies come from the fact that some tumor samples have different Normal matched with one of them being with a WGD. They annotate the sample as a WGD sample.
#
# So let's filter annotated_cohort - keep the highest purity matched normal - and see if the inconsistencies are still present.

# %%
def normal_samp_duplicates_filter(df, sample_name, purity_name):
    '''
    This function aims to filter out the samples that have the same tumor id but different normal samples.
    We choose to keep only the one with the highest purity in case of duplicates.
    
    Arguments:
        - df: the dataframe we want to clean
        - sample_name: the name of the column containing the sample. Ex: P-0006554-T01-IM5_P-0006554-N01-IM5
        - purity_name: the name of the column containing the purity
    '''
    
    # We first restrain to the interesting columns
    sub_df = df[[sample_name, purity_name]]
    #Create the column with the tumor_id and set it as index to identify the duplicates
    sub_df['Tumor_Id'] = sub_df[sample_name].str[:17]
    sub_df = sub_df.set_index('Tumor_Id')
    # We use the duplicated() method to create a False/True Series if the sample is duplicated
    duplicates_series = sub_df[sample_name].str[:17].duplicated()
    # We then select only samples that are duplicated to obtain the list of duplicated samples
    duplicated_samples = list(duplicates_series[duplicates_series == True].index)

    # We put the sample_name column as Index
    sub_df = sub_df.set_index(sample_name)

    # We can now filter out the samples that are listed in duplicated_samples
    to_be_filtered = []
    for sample in duplicated_samples:
        to_be_filtered.append(sub_df[sub_df.index.str[:17] == sample][['purity']].idxmin()['purity'])
    
    #print(to_be_filtered)
    # Now we filter out the lines that are in the list
    df = df[~df[sample_name].isin(to_be_filtered)]
    
    return df

# %%
annotated_cohort_filt = normal_samp_duplicates_filter(annotated_cohort, 'sample_id', 'purity')
annotated_cohort_filt = normal_samp_duplicates_filter(annotated_cohort_filt, 'sample_id', 'purity')
# the last duplicated samples are samples with purity = NaN so we simply use deplicated method
annotated_cohort_filt = annotated_cohort_filt.drop_duplicates(subset='tumor_sample')

# %%
annotated_cohort_wgd = annotated_cohort_filt[['tumor_sample', 'wgd']]
merged = pd.merge(left=master, right=annotated_cohort_wgd, how='left', left_on='Tumor_Id', right_on='tumor_sample')
merged['inconsistencies'] = merged.apply(check_inconsistencies, axis=1)
merged[merged['inconsistencies'] == 1]#[~merged.wgd_y.isna()]
# Out:
#                 Tumor_Id  wgd_x       tumor_sample wgd_y  inconsistencies
# 495    P-0031435-T01-IM6     -1                NaN   NaN                1
# 1282   P-0010672-T02-IM5     -1                NaN   NaN                1
# 1855   P-0027242-T01-IM6     -1                NaN   NaN                1
# 2906   P-0013827-T01-IM5     -1                NaN   NaN                1
# 2957   P-0010083-T01-IM5     -1                NaN   NaN                1
# 3263   P-0020798-T01-IM6     -1                NaN   NaN                1
# 3271   P-0017938-T01-IM6     -1                NaN   NaN                1
# 3284   P-0031170-T01-IM6     -1                NaN   NaN                1
# 3898   P-0035720-T01-IM6     -1  P-0035720-T01-IM6  True                1
# 3980   P-0036528-T01-IM6     -1                NaN   NaN                1
# 5936   P-0017305-T01-IM5     -1                NaN   NaN                1
# 6401   P-0017240-T02-IM6     -1                NaN   NaN                1
# 6473   P-0016745-T01-IM6     -1                NaN   NaN                1
# 6480   P-0006119-T01-IM5     -1                NaN   NaN                1
# 6533   P-0025776-T01-IM6     -1                NaN   NaN                1
# 6540   P-0019560-T01-IM6     -1                NaN   NaN                1
# 7324   P-0011588-T01-IM5     -1                NaN   NaN                1
# 9995   P-0000328-T02-IM6     -1                NaN   NaN                1
# 10549  P-0019219-T01-IM6     -1                NaN   NaN                1
# 11679  P-0000416-T02-IM3     -1                NaN   NaN                1
# 12234  P-0027992-T01-IM6     -1                NaN   NaN                1
# 12546  P-0023638-T02-IM6     -1                NaN   NaN                1
# 12765  P-0014014-T01-IM6     -1                NaN   NaN                1
# 13272  P-0028566-T01-IM6     -1                NaN   NaN                1
# 13757  P-0015914-T01-IM6     -1                NaN   NaN                1
# 15355  P-0029600-T02-IM6     -1                NaN   NaN                1
# 15765  P-0022650-T01-IM6     -1                NaN   NaN                1
# 16231  P-0004094-T03-IM6     -1                NaN   NaN                1
# 16448  P-0026525-T02-IM6     -1                NaN   NaN                1
# 17460  P-0000244-T01-IM3     -1                NaN   NaN                1
# 17839  P-0014773-T01-IM6     -1                NaN   NaN                1
# 17950  P-0024980-T01-IM6     -1                NaN   NaN                1
# 17969  P-0000657-T01-IM3     -1                NaN   NaN                1
# 19907  P-0000801-T02-IM3     -1                NaN   NaN                1
# 19961  P-0001378-T01-IM3     -1                NaN   NaN                1
# 19965  P-0001401-T01-IM3     -1                NaN   NaN                1
# 20016  P-0001785-T01-IM3     -1                NaN   NaN                1
# 20108  P-0002550-T01-IM3     -1                NaN   NaN                1
# 20112  P-0002576-T01-IM3     -1                NaN   NaN                1
# 20132  P-0002742-T01-IM3     -1                NaN   NaN                1
# 20137  P-0002748-T01-IM3     -1                NaN   NaN                1
# 20138  P-0002750-T01-IM3     -1                NaN   NaN                1
# 20144  P-0002760-T01-IM3     -1                NaN   NaN                1
# 20169  P-0002936-T02-IM3     -1                NaN   NaN                1
# 20170  P-0002938-T02-IM3     -1                NaN   NaN                1
# 20171  P-0002940-T02-IM3     -1                NaN   NaN                1
# 20172  P-0002942-T02-IM3     -1                NaN   NaN                1
# 20173  P-0002944-T02-IM3     -1                NaN   NaN                1
# 20174  P-0002945-T02-IM3     -1                NaN   NaN                1
# 20175  P-0002946-T02-IM3     -1                NaN   NaN                1
# 20176  P-0002947-T02-IM3     -1                NaN   NaN                1
# 20178  P-0002953-T02-IM3     -1                NaN   NaN                1
# 20234  P-0003697-T01-IM5     -1                NaN   NaN                1
# 20238  P-0003702-T01-IM5     -1                NaN   NaN                1
# 20331  P-0004842-T02-IM5     -1                NaN   NaN                1
# 20362  P-0005192-T01-IM5     -1  P-0005192-T01-IM5  True                1
# 20404  P-0005666-T02-IM5     -1                NaN   NaN                1
# 20658  P-0007961-T01-IM5     -1                NaN   NaN                1
# 21085  P-0014831-T01-IM6     -1                NaN   NaN                1
# 21118  P-0015364-T01-IM6     -1                NaN   NaN                1
# 21147  P-0015881-T05-IM6     -1                NaN   NaN                1
# 21247  P-0017878-T01-IM6     -1                NaN   NaN                1
# 21352  P-0019732-T01-IM6     -1                NaN   NaN                1
# 21356  P-0019817-T01-IM6     -1                NaN   NaN                1
# 21402  P-0024195-T01-IM6     -1                NaN   NaN                1
# 21406  P-0031102-T01-IM6     -1                NaN   NaN                1
# 21706  P-0038201-T01-IM6     -1                NaN   NaN                1
# 22078  P-0039073-T01-IM6     -1                NaN   NaN                1
# 22185  P-0039361-T01-IM6     -1                NaN   NaN                1
# 23053  P-0040935-T02-IM6     -1                NaN   NaN                1
# 23118  P-0028971-T03-IM6     -1                NaN   NaN                1
# 23205  P-0041308-T01-IM6     -1                NaN   NaN                1
# 23218  P-0041349-T01-IM6     -1                NaN   NaN                1
# 23392  P-0040989-T01-IM6     -1                NaN   NaN                1
# 23393  P-0040989-T03-IM6     -1                NaN   NaN                1
# 23648  P-0042229-T01-IM6     -1                NaN   NaN                1
# 23779  P-0042670-T02-IM6     -1                NaN   NaN                1
# 24406  P-0043869-T01-IM6     -1                NaN   NaN                1
# 25605  P-0040699-T03-IM6     -1                NaN   NaN                1
# 25731  P-0020747-T02-IM6     -1                NaN   NaN                1
# 26045  P-0045498-T01-IM6     -1                NaN   NaN                1
# 26062  P-0045536-T01-IM6     -1                NaN   NaN                1
# 26234  P-0045745-T01-IM6     -1                NaN   NaN                1
# 26442  P-0046202-T02-IM6     -1                NaN   NaN                1
# 26789  P-0039879-T02-IM6     -1                NaN   NaN                1
# 26792  P-0046981-T01-IM6     -1                NaN   NaN                1
# 26879  P-0035894-T01-IM6     -1                NaN   NaN                1
# 27032  P-0047440-T01-IM6     -1                NaN   NaN                1
# 27419  P-0047819-T01-IM6     -1                NaN   NaN                1
# 27497  P-0047363-T02-IM6     -1                NaN   NaN                1
# 27620  P-0000088-T01-IM3     -1                NaN   NaN                1
# 27623  P-0040058-T01-IM6     -1                NaN   NaN                1
# 27650  P-0025278-T01-IM6     -1                NaN   NaN                1
# 27651  P-0026935-T03-IM6     -1                NaN   NaN                1
# 27665  P-0008769-T01-IM5     -1                NaN   NaN                1
# 27666  P-0008759-T01-IM5     -1                NaN   NaN                1
# 27667  P-0008493-T01-IM5     -1                NaN   NaN                1
# 27668  P-0008557-T01-IM5     -1                NaN   NaN                1
# 27669  P-0008531-T01-IM5     -1                NaN   NaN                1
# 27670  P-0008536-T01-IM5     -1                NaN   NaN                1
# 27671  P-0008670-T01-IM5     -1                NaN   NaN                1
# 27672  P-0008761-T01-IM5     -1                NaN   NaN                1
# 27674  P-0008488-T01-IM5     -1                NaN   NaN                1
# 27675  P-0008492-T01-IM5     -1                NaN   NaN                1
# 27676  P-0008679-T02-IM5     -1                NaN   NaN                1
# 27677  P-0008484-T01-IM5     -1                NaN   NaN                1
# 27678  P-0009175-T01-IM5     -1                NaN   NaN                1
# 27679  P-0008459-T01-IM5     -1                NaN   NaN                1
# 27680  P-0008758-T01-IM5     -1                NaN   NaN                1
# 27682  P-0008458-T01-IM5     -1                NaN   NaN                1
# 27683  P-0009324-T01-IM5     -1                NaN   NaN                1
# 27684  P-0008457-T01-IM5     -1                NaN   NaN                1
# 27685  P-0008558-T01-IM5     -1                NaN   NaN                1

# %% [markdown]
# **Conclusion:** We will keep the *wgd* column as the reference for wgd.

# %% [markdown]
# # Analysis

# %% [markdown]
# ## Filtering the annotated_data
# 1. We do not want duplicates in Tumor_Id
# 2. As maf_cohort is necessary to know if we have tp53 mutants or not, we will reduce our analysis to the samples of maf_cohort (loss of ~3 600 samples over 42 153)
# 3. Moreover, we need to access tp53 cn state, so we have to be sure all samples are in gene_level file
# 4. As we did for the TP53 cohort, we will filter samples with purity < 0.2 BUT we will rescue TP53 mutants with no purity a tp53_vaf > 0.15
# 5. We remove samples with INDETERMINATE copy number state

# %%
annotated_cohort = pd.read_csv(data_path + 'impact-facets-tp53/new_data_facets/msk_impact_facets_annotated.cohort.txt', sep='\t')
maf_cohort = pd.read_csv(data_path + 'impact-facets-tp53/new_data_facets/msk_impact_facets_annotated.ccf.maf', sep='\t')
gene_level = pd.read_csv(data_path + 'impact-facets-tp53/new_data_facets/msk_impact_facets_annotated.gene_level_grepTP53.txt', sep='\t')

maf_samples = list(set(maf_cohort.Tumor_Sample_Barcode))

annotated_cohort_filt = normal_samp_duplicates_filter(annotated_cohort, 'sample_id', 'purity')
annotated_cohort_filt = normal_samp_duplicates_filter(annotated_cohort_filt, 'sample_id', 'purity')
# the last duplicated samples are samples with purity = NaN so we simply use deplicated method
cohort = annotated_cohort_filt.drop_duplicates(subset='tumor_sample')

# We take only samples that are in maf_samples
cohort = cohort[cohort.tumor_sample.isin(maf_samples)]

# Finally we want to be able to accesss the TP53 locus copy number state, so we need to make sure all samples are
# in gene_level

# We remove the following samples that are not in gene_level file
cohort = cohort[~cohort.tumor_sample.isin(['P-0000157-T01-IM3','P-0000158-T01-IM3','P-0000204-T01-IM3','P-0000206-T01-IM3','P-0000273-T01-IM3','P-0000308-T01-IM3','P-0000320-T01-IM3','P-0000396-T01-IM3','P-0007206-T01-IM5','P-0011437-T01-IM5','P-0037557-T01-IM6','P-0043334-T01-IM6','P-0043373-T01-IM6','P-0043377-T01-IM6','P-0045294-T01-IM6','P-0045404-T01-IM6'])]


# Now we filter on purity

# We create a list for the interesting samples that we will integrate to our data
cohort_na_tp53 = maf_cohort[(maf_cohort.purity == 0.3) | (maf_cohort.purity.isna())][maf_cohort['Hugo_Symbol'] == 'TP53']
samples_maxvaf=[]
for sample in list(set(cohort_na_tp53.Tumor_Sample_Barcode)):
    sample_1 = maf_cohort[maf_cohort['Tumor_Sample_Barcode'] == sample]
    if max(sample_1.t_var_freq)>0.15:
        samples_maxvaf.append(sample)    
# we remove THE sample that have a tp53_vaf < 2%
samples_maxvaf.remove('P-0035205-T03-IM6')

# Samples with purity > 0.2
samples_purity = list(set(maf_cohort[maf_cohort['purity'] > 0.2].Tumor_Sample_Barcode))

samples = samples_maxvaf + samples_purity
samples.remove('P-0016457-T04-IM6')
samples.remove('P-0014703-T01-IM6')

cohort = cohort[cohort.tumor_sample.isin(samples)]

# OPTIONAL
# Removing INDETERMINATE tp53 CN state samples
gene_level_ = gene_level[gene_level['gene'] == 'TP53']
samples_ind = list(set(gene_level_[gene_level_['cn_state'] == 'INDETERMINATE']['sample']))

cohort = cohort[~cohort.sample_id.isin(samples_ind)]

# %%
print('Final size of our cohort: ' + str(len(list(cohort.tumor_sample))))

maf_cohort_study = maf_cohort[maf_cohort.Tumor_Sample_Barcode.isin(list(cohort.tumor_sample))]
print('\nWe verify that purity>0.2 in our maf_cohort file:')
print(maf_cohort_study[maf_cohort_study.Tumor_Sample_Barcode.isin(samples_purity)].purity.min())
# Out:
# Final size of our cohort: 30289
#
# We verify that purity>0.2 in our maf_cohort file:
# 0.200051999476184

# %% [markdown]
# Now we have unique tumor_sample, we can begin the analysis

# %% [markdown]
# ## WGD Proportion

# %%
print('Number of samples with WGD: ' + str(cohort[cohort['wgd'] == True].shape[0]) + ' - ' + str(round(100* cohort[cohort['wgd'] == True].shape[0]/cohort.shape[0],2))+ ' %')
print('Number of samples without WGD: ' + str(cohort[cohort['wgd'] == False].shape[0])  + ' - ' + str(round(100* cohort[cohort['wgd'] == False].shape[0]/cohort.shape[0],2))+ ' %')
# Out:
# Number of samples with WGD: 11350 - 37.47 %
# Number of samples without WGD: 18939 - 62.53 %

# %% [markdown]
# # Number of TP53 mutated samples in WGD setting
# From previous analysis we expect to see a very high proportion of TP53 mutated samples.

# %%
# We filter only WGD Samples
cohort_wgd = cohort[cohort['wgd'] == 1]

# We store tumor sample ids and matched normal sample ids to filter gene_level anf maf_cohort
samples_wgd = list(set(cohort_wgd.tumor_sample))
samples_matched_wgd = list(set(cohort_wgd.sample_id))

# %%
# We filter the maf_cohort on the wgd samples
maf_cohort_wgd = maf_cohort[maf_cohort.Tumor_Sample_Barcode.isin(samples_wgd)]

# %%
# We count the samples that has at least one tp53 mutation
total = len(set(maf_cohort_wgd.Tumor_Sample_Barcode))
n = len(set(maf_cohort_wgd[maf_cohort['Hugo_Symbol'] == 'TP53'].Tumor_Sample_Barcode))
print('Number of TP53 mutated samples in WGD setting: ' + str(n) + ' - ' + str(round(100*n/len(cohort_wgd),2)) + ' %')
print('Number of TP53 wild-type samples in WGD setting: ' + str(total - n) + ' - ' + str(100 -round(100*n/len(cohort_wgd),2)) + ' %')
# Out:
# Number of TP53 mutated samples in WGD setting: 7418 - 65.36 %
# Number of TP53 wild-type samples in WGD setting: 3932 - 34.64 %

# %% [markdown]
# # TP53 mutants Analysis
# TP53 mutants represent 65 % of all WGD samples. But what is the distribution of LOH samples? First we have to define what is a LOH setting.
#
# 1. We define LOH (Loss of Heterozygosity) as having lost the second allele, which in practice is traduced numerically by having a lcn (low copy number) of 0.

# %% [markdown]
# First, le's take a look at the different TP53 Copy Number states involved in our WGD cohort:

# %%
# We show the distribution of CN state withtin the WGD cohort
gene_level_tp53_wgd = gene_level[gene_level['gene'] == 'TP53'][gene_level['sample'].isin(samples_matched_wgd)]
gene_level_tp53_wgd['tumor_id'] = gene_level.apply(lambda x: x['sample'][:17], axis=1)

get_groupby(gene_level_tp53_wgd, 'cn_state', 'count').sort_values(by='count', ascending=False)
# Out:
#                      count
# cn_state
# LOSS BEFORE           4865
# CNLOH BEFORE & LOSS   1887
# LOSS AFTER            1278
# TETRAPLOID             652
# DOUBLE LOSS AFTER      533
# CNLOH BEFORE           464
# LOSS BEFORE & AFTER    422
# GAIN                   325
# CNLOH AFTER            146
# CNLOH                  144
# HOMDEL                 126
# DIPLOID                 91
# AMP (BALANCED)          90
# CNLOH BEFORE & GAIN     84
# AMP                     74
# HETLOSS                 48
# AMP (LOH)               43
# LOSS & GAIN             40
# CNLOH & GAIN            38

# %% [markdown]
# We identify here that we have 3 major CN states: *LOSS BEFORE*, *CNLOH BEFORE & LOSS* and *LOSS AFTER*.
# Moreover we identify the CN states leading to a LOH:
# * LOSS BEFORE
# * CNLOH BEFORE & LOSS
# * CNLOH BEFORE
# * LOSS BEFORE & AFTER
# * CNLOH BEFORE & GAIN
#
# So we're able to identify LOH samples and compute the proportion of LOH:

# %%
def get_loh(x):
    if gene_level_tp53_wgd[gene_level_tp53_wgd['sample'] == x.sample_id]['cn_state'].values[0] in ['LOSS BEFORE', 'CNLOH BEFORE & LOSS', 'CNLOH BEFORE', 'LOSS BEFORE & AFTER', 'CNLOH BEFORE & GAIN']:
        return True
    else: return False
                                                                                                                
# we create a new column named LOH in our cohort_wgd
cohort_wgd['LOH'] = cohort_wgd.apply(get_loh, axis=1)
get_groupby(cohort_wgd, 'LOH', 'count')

# %%
n_loh = len(set(cohort_wgd[cohort_wgd['LOH'] == True].tumor_sample))
n_noloh = len(set(cohort_wgd[cohort_wgd['LOH'] == False].tumor_sample))
total = len(set(cohort_wgd.tumor_sample)) 

print('Number of LOH samples in WGD cohort: ' + str(n_loh) + ' - ' + str(round(100*n_loh/total, 2)) + ' %')
print('Number of non LOH samples in WGD cohort: ' + str(n_noloh) + ' - ' + str(round(100*n_noloh/total, 2)) + ' %')
# Out:
# Number of LOH samples in WGD cohort: 7722 - 68.04 %
# Number of non LOH samples in WGD cohort: 3628 - 31.96 %

# %% [markdown]
# ## Plot of the number of mutations + LOH Status

# %%
# Mutation Count for all samples

# create a sample_mut_key to identify the duplicated mutations
# Create a mutation Key
maf_cohort_wgd['mut_key'] = maf_cohort_wgd.apply(lambda h: str(h.Chromosome)+'_'+str(h.Start_Position)+'_'+str(h.Reference_Allele)+'_'+str(h.Tumor_Seq_Allele2), axis=1) 
# Create a Patient_Id
maf_cohort_wgd['Patient_Id'] = maf_cohort_wgd.Tumor_Sample_Barcode.str[:9]
# Create a sample key to differentiate duplicates
maf_cohort_wgd['sample_mut_key'] = maf_cohort_wgd.apply(lambda h: h.Tumor_Sample_Barcode + h.mut_key, axis = 1)

def count_tp53_mut(x):
    sample_muts = maf_cohort_wgd[maf_cohort_wgd.Tumor_Sample_Barcode == x.tumor_sample][maf_cohort['Hugo_Symbol'] == 'TP53'].drop_duplicates(subset='sample_mut_key')
    return sample_muts.shape[0]

cohort_wgd['tp53_count'] = cohort_wgd.apply(count_tp53_mut, axis=1)
# Out:
#        Hugo_Symbol  Entrez_Gene_Id Center NCBI_Build Chromosome  \
# 7             KRAS            3845  MSKCC     GRCh37         12
# 8            STK11            6794  MSKCC     GRCh37         19
# 9            KEAP1            9817  MSKCC     GRCh37         19
# 10         SMARCA4            6597  MSKCC     GRCh37         19
# 11           PTPRT           11122  MSKCC     GRCh37         20
# ...            ...             ...    ...        ...        ...
# 339406        ELF3            1999  MSKCC     GRCh37          1
# 339407        KRAS            3845  MSKCC     GRCh37         12
# 339408        TP53            7157  MSKCC     GRCh37         17
# 339409       RNF43           54894  MSKCC     GRCh37         17
# 339410      DNMT3B            1789  MSKCC     GRCh37         20
#
#         Start_Position  End_Position Strand Variant_Classification  \
# 7             25398285      25398285      +      Missense_Mutation
# 8              1221314       1221314      +        Frame_Shift_Del
# 9             10602584      10602584      +      Missense_Mutation
# 10            11113836      11113836      +            Splice_Site
# 11            40735560      40735560      +      Missense_Mutation
# ...                ...           ...    ...                    ...
# 339406       201982345     201982346      +        Frame_Shift_Ins
# 339407        25398284      25398284      +      Missense_Mutation
# 339408         7577094       7577094      +      Missense_Mutation
# 339409        56440961      56440961      +      Missense_Mutation
# 339410        31374317      31374317      +      Nonsense_Mutation
#
#        Variant_Type Reference_Allele Tumor_Seq_Allele1 Tumor_Seq_Allele2  \
# 7               SNP                C                 C                 A
# 8               DEL                C                 C                 -
# 9               SNP                C                 C                 T
# 10              SNP                G                 G                 A
# 11              SNP                C                 C                 A
# ...             ...              ...               ...               ...
# 339406          INS                -                 -                 A
# 339407          SNP                C                 C                 A
# 339408          SNP                G                 G                 A
# 339409          SNP                C                 C                 G
# 339410          SNP                C                 C                 T
#
#        dbSNP_RS  dbSNP_Val_Status Tumor_Sample_Barcode  \
# 7         novel               NaN    P-0025956-T01-IM6
# 8         novel               NaN    P-0025956-T01-IM6
# 9         novel               NaN    P-0025956-T01-IM6
# 10        novel               NaN    P-0025956-T01-IM6
# 11        novel               NaN    P-0025956-T01-IM6
# ...         ...               ...                  ...
# 339406    novel               NaN    P-0049537-T01-IM6
# 339407    novel               NaN    P-0049537-T01-IM6
# 339408    novel               NaN    P-0049537-T01-IM6
# 339409    novel               NaN    P-0049537-T01-IM6
# 339410    novel               NaN    P-0049537-T01-IM6
#
#         Matched_Norm_Sample_Barcode Match_Norm_Seq_Allele1  \
# 7                               NaN                    NaN
# 8                               NaN                    NaN
# 9                               NaN                    NaN
# 10                              NaN                    NaN
# 11                              NaN                    NaN
# ...                             ...                    ...
# 339406                          NaN                    NaN
# 339407                          NaN                    NaN
# 339408                          NaN                    NaN
# 339409                          NaN                    NaN
# 339410                          NaN                    NaN
#
#        Match_Norm_Seq_Allele2  Tumor_Validation_Allele1  \
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
# 10                        NaN                       NaN
# 11                        NaN                       NaN
# ...                       ...                       ...
# 339406                    NaN                       NaN
# 339407                    NaN                       NaN
# 339408                    NaN                       NaN
# 339409                    NaN                       NaN
# 339410                    NaN                       NaN
#
#         Tumor_Validation_Allele2  Match_Norm_Validation_Allele1  \
# 7                            NaN                            NaN
# 8                            NaN                            NaN
# 9                            NaN                            NaN
# 10                           NaN                            NaN
# 11                           NaN                            NaN
# ...                          ...                            ...
# 339406                       NaN                            NaN
# 339407                       NaN                            NaN
# 339408                       NaN                            NaN
# 339409                       NaN                            NaN
# 339410                       NaN                            NaN
#
#         Match_Norm_Validation_Allele2  Verification_Status Validation_Status  \
# 7                                 NaN                  NaN           Unknown
# 8                                 NaN                  NaN           Unknown
# 9                                 NaN                  NaN           Unknown
# 10                                NaN                  NaN           Unknown
# 11                                NaN                  NaN           Unknown
# ...                               ...                  ...               ...
# 339406                            NaN                  NaN           Unknown
# 339407                            NaN                  NaN           Unknown
# 339408                            NaN                  NaN           Unknown
# 339409                            NaN                  NaN           Unknown
# 339410                            NaN                  NaN           Unknown
#
#        Mutation_Status  Sequencing_Phase  Sequence_Source  Validation_Method  \
# 7              SOMATIC               NaN              NaN                NaN
# 8              SOMATIC               NaN              NaN                NaN
# 9              SOMATIC               NaN              NaN                NaN
# 10             SOMATIC               NaN              NaN                NaN
# 11             SOMATIC               NaN              NaN                NaN
# ...                ...               ...              ...                ...
# 339406         SOMATIC               NaN              NaN                NaN
# 339407         SOMATIC               NaN              NaN                NaN
# 339408         SOMATIC               NaN              NaN                NaN
# 339409         SOMATIC               NaN              NaN                NaN
# 339410         SOMATIC               NaN              NaN                NaN
#
#              Score  BAM_File  Sequencer  Tumor_Sample_UUID  \
# 7       MSK-IMPACT       NaN        NaN                NaN
# 8       MSK-IMPACT       NaN        NaN                NaN
# 9       MSK-IMPACT       NaN        NaN                NaN
# 10      MSK-IMPACT       NaN        NaN                NaN
# 11      MSK-IMPACT       NaN        NaN                NaN
# ...            ...       ...        ...                ...
# 339406  MSK-IMPACT       NaN        NaN                NaN
# 339407  MSK-IMPACT       NaN        NaN                NaN
# 339408  MSK-IMPACT       NaN        NaN                NaN
# 339409  MSK-IMPACT       NaN        NaN                NaN
# 339410  MSK-IMPACT       NaN        NaN                NaN
#
#         Matched_Norm_Sample_UUID        HGVSc               HGVSp  \
# 7                            NaN      c.34G>T          p.Gly12Cys
# 8                            NaN    c.837delC   p.Pro281ArgfsTer6
# 9                            NaN     c.994G>A         p.Gly332Ser
# 10                           NaN  c.1943+1G>A                 NaN
# 11                           NaN    c.3313G>T        p.Ala1105Ser
# ...                          ...          ...                 ...
# 339406                       NaN    c.725dupA  p.His242GlnfsTer59
# 339407                       NaN      c.35G>T          p.Gly12Val
# 339408                       NaN     c.844C>T         p.Arg282Trp
# 339409                       NaN     c.376G>C         p.Ala126Pro
# 339410                       NaN     c.316C>T         p.Arg106Ter
#
#           HGVSp_Short    Transcript_ID Exon_Number  t_depth  t_ref_count  \
# 7              p.G12C  ENST00000256078         2/6    588.0        495.0
# 8         p.P281Rfs*6  ENST00000326873        6/10    615.0        492.0
# 9             p.G332S  ENST00000171111         3/6    641.0        523.0
# 10      p.X648_splice  ENST00000344626         NaN    445.0        371.0
# 11           p.A1105S  ENST00000373198       25/32    471.0        378.0
# ...               ...              ...         ...      ...          ...
# 339406   p.H242Qfs*59  ENST00000359651         6/8    819.0        517.0
# 339407         p.G12V  ENST00000256078         2/6    431.0        295.0
# 339408        p.R282W  ENST00000269305        8/11    553.0        285.0
# 339409        p.A126P  ENST00000407977        4/10    415.0        204.0
# 339410        p.R106*  ENST00000328111        5/23    556.0        387.0
#
#         t_alt_count  n_depth n_ref_count n_alt_count  \
# 7              93.0      908         908           0
# 8             123.0      885         884           1
# 9             118.0      471         471           0
# 10             74.0      362         361           1
# 11             93.0      349         349           0
# ...             ...      ...         ...         ...
# 339406        302.0      630         630           0
# 339407        136.0      313         313           0
# 339408        268.0      552         551           1
# 339409        211.0      496         496           0
# 339410        169.0      531         531           0
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            all_effects  \
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       KRAS,missense_variant,p.Gly12Cys,ENST00000311936,NM_004985.3;KRAS,missense_variant,p.Gly12Cys,ENST00000556131,;KRAS,missense_variant,p.Gly12Cys,ENST00000256078,NM_033360.2;KRAS,missense_variant,p.Gly12Cys,ENST00000557334,;
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                           STK11,frameshift_variant,p.Pro281ArgfsTer6,ENST00000326873,NM_000455.4;STK11,frameshift_variant,p.Pro37ArgfsTer6,ENST00000586243,;STK11,downstream_gene_variant,,ENST00000585851,;STK11,downstream_gene_variant,,ENST00000585748,;STK11,3_prime_UTR_variant,,ENST00000593219,;STK11,non_coding_transcript_exon_variant,,ENST00000589152,;STK11,non_coding_transcript_exon_variant,,ENST00000591133,;STK11,non_coding_transcript_exon_variant,,ENST00000586358,;STK11,upstream_gene_variant,,ENST00000585465,;,regulatory_region_variant,,ENSR00000377818,;
# 9                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        KEAP1,missense_variant,p.Gly332Ser,ENST00000171111,NM_203500.1;KEAP1,missense_variant,p.Gly332Ser,ENST00000393623,NM_012289.3;KEAP1,upstream_gene_variant,,ENST00000592478,;KEAP1,downstream_gene_variant,,ENST00000591419,;KEAP1,downstream_gene_variant,,ENST00000592055,;CTC-429L19.3,upstream_gene_variant,,ENST00000592671,;KEAP1,downstream_gene_variant,,ENST00000588024,;KEAP1,downstream_gene_variant,,ENST00000585845,;KEAP1,upstream_gene_variant,,ENST00000590593,;KEAP1,upstream_gene_variant,,ENST00000590237,;
# 10                                                                                                                                                                                                                                                                                                                                                                                                                             SMARCA4,splice_donor_variant,,ENST00000358026,NM_001128849.1;SMARCA4,splice_donor_variant,,ENST00000429416,NM_001128844.1;SMARCA4,splice_donor_variant,,ENST00000344626,NM_003072.3;SMARCA4,splice_donor_variant,,ENST00000413806,NM_001128845.1,NM_001128847.1;SMARCA4,splice_donor_variant,,ENST00000450717,NM_001128846.1,NM_001128848.1;SMARCA4,splice_donor_variant,,ENST00000590574,;SMARCA4,splice_donor_variant,,ENST00000589677,;SMARCA4,splice_donor_variant,,ENST00000541122,;SMARCA4,splice_donor_variant,,ENST00000444061,;SMARCA4,splice_donor_variant,,ENST00000591545,;
# 11                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           PTPRT,missense_variant,p.Ala1105Ser,ENST00000373198,NM_133170.3;PTPRT,missense_variant,p.Ala1076Ser,ENST00000373201,;PTPRT,missense_variant,p.Ala1089Ser,ENST00000373193,NM_007050.5;PTPRT,missense_variant,p.Ala1085Ser,ENST00000373190,;PTPRT,missense_variant,p.Ala1096Ser,ENST00000373184,;PTPRT,missense_variant,p.Ala1095Ser,ENST00000356100,;PTPRT,missense_variant,p.Ala1086Ser,ENST00000373187,;
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 339406                                                                                                                                                                                                                                                                                                                                 ELF3,frameshift_variant,p.His242GlnfsTer59,ENST00000359651,;ELF3,frameshift_variant,p.His242GlnfsTer59,ENST00000367284,NM_004433.4,NM_001114309.1;ELF3,frameshift_variant,p.His242GlnfsTer59,ENST00000367283,;ELF3,downstream_gene_variant,,ENST00000446188,;RP11-510N19.5,intron_variant,,ENST00000504773,;RP11-465N4.4,upstream_gene_variant,,ENST00000419190,;ELF3,non_coding_transcript_exon_variant,,ENST00000490203,;ELF3,non_coding_transcript_exon_variant,,ENST00000470384,;ELF3,downstream_gene_variant,,ENST00000495848,;ELF3,upstream_gene_variant,,ENST00000475698,;ELF3,downstream_gene_variant,,ENST00000498017,;ELF3,downstream_gene_variant,,ENST00000479874,;
# 339407                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  KRAS,missense_variant,p.Gly12Val,ENST00000311936,NM_004985.3;KRAS,missense_variant,p.Gly12Val,ENST00000556131,;KRAS,missense_variant,p.Gly12Val,ENST00000256078,NM_033360.2;KRAS,missense_variant,p.Gly12Val,ENST00000557334,;
# 339408  TP53,missense_variant,p.Arg282Trp,ENST00000420246,NM_001126114.2,NM_001276696.1;TP53,missense_variant,p.Arg282Trp,ENST00000455263,NM_001276695.1,NM_001126113.2;TP53,missense_variant,p.Arg282Trp,ENST00000269305,NM_001126112.2,NM_001276761.1,NM_001276760.1,NM_000546.5,NM_001126118.1;TP53,missense_variant,p.Arg282Trp,ENST00000445888,;TP53,missense_variant,p.Arg282Trp,ENST00000359597,;TP53,missense_variant,p.Arg150Trp,ENST00000509690,;TP53,intron_variant,,ENST00000413465,;TP53,downstream_gene_variant,,ENST00000508793,;TP53,downstream_gene_variant,,ENST00000604348,;TP53,downstream_gene_variant,,ENST00000503591,;TP53,downstream_gene_variant,,ENST00000514944,;TP53,upstream_gene_variant,,ENST00000576024,;TP53,downstream_gene_variant,,ENST00000574684,;TP53,non_coding_transcript_exon_variant,,ENST00000510385,;TP53,non_coding_transcript_exon_variant,,ENST00000504290,;TP53,non_coding_transcript_exon_variant,,ENST00000504937,;TP53,downstream_gene_variant,,ENST00000505014,;
# 339409                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             RNF43,missense_variant,p.Ala126Pro,ENST00000584437,;RNF43,missense_variant,p.Ala126Pro,ENST00000407977,;RNF43,missense_variant,p.Ala85Pro,ENST00000500597,;RNF43,missense_variant,p.Ala126Pro,ENST00000577716,NM_017763.4;RNF43,missense_variant,p.Ala85Pro,ENST00000583753,;RNF43,splice_region_variant,,ENST00000581868,;RNF43,splice_region_variant,,ENST00000577625,;BZRAP1-AS1,intron_variant,,ENST00000583841,;RNF43,upstream_gene_variant,,ENST00000582293,;
# 339410                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               DNMT3B,stop_gained,p.Arg106Ter,ENST00000328111,NM_006892.3;DNMT3B,stop_gained,p.Arg118Ter,ENST00000201963,NM_175850.2;DNMT3B,stop_gained,p.Arg106Ter,ENST00000353855,NM_175848.1;DNMT3B,stop_gained,p.Arg106Ter,ENST00000348286,NM_175849.1,NM_001207055.1;DNMT3B,stop_gained,p.Arg106Ter,ENST00000344505,;DNMT3B,intron_variant,,ENST00000443239,;DNMT3B,intron_variant,,ENST00000456297,NM_001207056.1;DNMT3B,intron_variant,,ENST00000375623,;
#
#        Allele             Gene          Feature Feature_type  \
# 7           A  ENSG00000133703  ENST00000256078   Transcript
# 8           -  ENSG00000118046  ENST00000326873   Transcript
# 9           T  ENSG00000079999  ENST00000171111   Transcript
# 10          A  ENSG00000127616  ENST00000344626   Transcript
# 11          A  ENSG00000196090  ENST00000373198   Transcript
# ...       ...              ...              ...          ...
# 339406      A  ENSG00000163435  ENST00000359651   Transcript
# 339407      A  ENSG00000133703  ENST00000256078   Transcript
# 339408      A  ENSG00000141510  ENST00000269305   Transcript
# 339409      G  ENSG00000108375  ENST00000407977   Transcript
# 339410      T  ENSG00000088305  ENST00000328111   Transcript
#
#                                    Consequence   cDNA_position  CDS_position  \
# 7                             missense_variant         98/1119        34/570
# 8                           frameshift_variant       2010/3328      837/1302
# 9                             missense_variant       1542/2955      994/1875
# 10                        splice_donor_variant          -/5392     1943/4944
# 11      missense_variant,splice_region_variant      3549/12746     3313/4383
# ...                                        ...             ...           ...
# 339406                      frameshift_variant  3916-3917/4994  724-725/1116
# 339407                        missense_variant         99/1119        35/570
# 339408                        missense_variant       1034/2579      844/1182
# 339409  missense_variant,splice_region_variant       1097/5516      376/2352
# 339410                             stop_gained        637/4336      316/2562
#
#        Protein_position Amino_acids    Codons  Existing_variation  ALLELE_NUM  \
# 7                12/189         G/C   Ggt/Tgt                 NaN           1
# 8               279/433         G/X    ggC/gg                 NaN           1
# 9               332/624         G/S   Ggc/Agc                 NaN           1
# 10             648/1647         NaN       NaN                 NaN           1
# 11            1105/1460         A/S   Gct/Tct                 NaN           1
# ...                 ...         ...       ...                 ...         ...
# 339406          242/371        H/QX  cac/cAac                 NaN           1
# 339407           12/189         G/V   gGt/gTt                 NaN           1
# 339408          282/393         R/W   Cgg/Tgg                 NaN           1
# 339409          126/783         A/P   Gct/Cct                 NaN           1
# 339410          106/853         R/*   Cga/Tga                 NaN           1
#
#         DISTANCE  STRAND_VEP   SYMBOL SYMBOL_SOURCE  HGNC_ID         BIOTYPE  \
# 7            NaN          -1     KRAS          HGNC   6407.0  protein_coding
# 8            NaN           1    STK11          HGNC  11389.0  protein_coding
# 9            NaN          -1    KEAP1          HGNC  23177.0  protein_coding
# 10           NaN           1  SMARCA4          HGNC  11100.0  protein_coding
# 11           NaN          -1    PTPRT          HGNC   9682.0  protein_coding
# ...          ...         ...      ...           ...      ...             ...
# 339406       NaN           1     ELF3          HGNC   3318.0  protein_coding
# 339407       NaN          -1     KRAS          HGNC   6407.0  protein_coding
# 339408       NaN          -1     TP53          HGNC  11998.0  protein_coding
# 339409       NaN          -1    RNF43          HGNC  18505.0  protein_coding
# 339410       NaN           1   DNMT3B          HGNC   2979.0  protein_coding
#
#        CANONICAL         CCDS             ENSP SWISSPROT  \
# 7            YES   CCDS8703.1  ENSP00000256078    P01116
# 8            YES  CCDS45896.1  ENSP00000324856    Q15831
# 9            YES  CCDS12239.1  ENSP00000171111    Q14145
# 10           NaN  CCDS12253.1  ENSP00000343896    P51532
# 11           NaN  CCDS68127.1  ENSP00000362294    O14522
# ...          ...          ...              ...       ...
# 339406       YES   CCDS1419.1  ENSP00000352673    P78545
# 339407       YES   CCDS8703.1  ENSP00000256078    P01116
# 339408       YES  CCDS11118.1  ENSP00000269305    P04637
# 339409       NaN  CCDS11607.1  ENSP00000385328    Q68DV7
# 339410       YES  CCDS13205.1  ENSP00000328547    Q9UBC3
#
#                                                                                                                                                                                 TREMBL  \
# 7                                                                                                                                                   Q9UM97,Q71SP6,P78460,L7RSL8,I1SRC5
# 8                                                                                                                                                                               Q9NS52
# 9                                                                                                                                                                 K7ESE0,K7EJD8,K7EJ49
# 10                                                                                                                                                                       B4DSI8,A7E2E1
# 11                                                                                                                                                                                 NaN
# ...                                                                                                                                                                                ...
# 339406                                                                                                                                                                             NaN
# 339407                                                                                                                                              Q9UM97,Q71SP6,P78460,L7RSL8,I1SRC5
# 339408  S5LQU8,Q761V2,Q6IT77,Q1HGV1,Q0PKT5,L0ES54,L0EQ05,K7PPA8,H2EHT1,G4Y083,E9PCY9,E7ESS1,E7EMR6,B5AKF6,B4DNI2,A4GWD0,A4GWB8,A4GWB5,A4GW97,A4GW76,A4GW75,A4GW74,A4GW67,A2I9Z1,A2I9Z0
# 339409                                                                                                                                                                             NaN
# 339410                                                                                                                                                                             NaN
#
#               UNIPARC  \
# 7       UPI0000133132
# 8       UPI0000136105
# 9       UPI000007139C
# 10      UPI000006F973
# 11      UPI00001AF6FA
# ...               ...
# 339406  UPI0000034E32
# 339407  UPI0000133132
# 339408  UPI000002ED67
# 339409  UPI000022A469
# 339410  UPI0000001046
#
#                                                                          RefSeq  \
# 7                                                                   NM_033360.2
# 8                                                                   NM_000455.4
# 9                                                                   NM_203500.1
# 10                                                                  NM_003072.3
# 11                                                                  NM_133170.3
# ...                                                                         ...
# 339406                                                                      NaN
# 339407                                                              NM_033360.2
# 339408  NM_001126112.2,NM_001276761.1,NM_001276760.1,NM_000546.5,NM_001126118.1
# 339409                                                                      NaN
# 339410                                                              NM_006892.3
#
#                      SIFT                  PolyPhen   EXON INTRON  \
# 7       deleterious(0.04)  probably_damaging(0.993)    2/6    NaN
# 8                     NaN                       NaN   6/10    NaN
# 9          deleterious(0)  probably_damaging(0.998)    3/6    NaN
# 10                    NaN                       NaN    NaN  12/34
# 11         deleterious(0)  probably_damaging(0.973)  25/32    NaN
# ...                   ...                       ...    ...    ...
# 339406                NaN                       NaN    6/8    NaN
# 339407     deleterious(0)  possibly_damaging(0.479)    2/6    NaN
# 339408     deleterious(0)  probably_damaging(0.997)   8/11    NaN
# 339409     deleterious(0)  probably_damaging(0.999)   4/10    NaN
# 339410                NaN                       NaN   5/23    NaN
#
#                                                                                                                                                                                                                                                                                                              DOMAINS  \
# 7       Gene3D:3.40.50.300,Pfam_domain:PF00071,Prints_domain:PR00449,PROSITE_profiles:PS51421,hmmpanther:PTHR24070,hmmpanther:PTHR24070:SF186,Low_complexity_(Seg):seg,SMART_domains:SM00173,SMART_domains:SM00174,SMART_domains:SM00175,SMART_domains:SM00176,Superfamily_domains:SSF52540,TIGRFAM_domain:TIGR00231
# 8                                                                                                                                                   Gene3D:1.10.510.10,Pfam_domain:PF00069,PROSITE_profiles:PS50011,hmmpanther:PTHR24347,hmmpanther:PTHR24347:SF1,SMART_domains:SM00220,Superfamily_domains:SSF56112
# 9                                                                                                                                                      hmmpanther:PTHR24412:SF162,hmmpanther:PTHR24412,Pfam_domain:PF01344,Gene3D:1k3iA02,PIRSF_domain:PIRSF037037,SMART_domains:SM00612,Superfamily_domains:0052715
# 10                                                                                                                                                                                                                                                                                                               NaN
# 11                                                  Gene3D:3.90.190.10,Pfam_domain:PF00102,Prints_domain:PR00700,PROSITE_patterns:PS00383,PROSITE_profiles:PS50055,PROSITE_profiles:PS50056,hmmpanther:PTHR19134,hmmpanther:PTHR19134:SF208,SMART_domains:SM00194,SMART_domains:SM00404,Superfamily_domains:SSF52799
# ...                                                                                                                                                                                                                                                                                                              ...
# 339406                                                                                                                                                                                                                                       hmmpanther:PTHR11849,hmmpanther:PTHR11849:SF13,Low_complexity_(Seg):seg
# 339407  Gene3D:3.40.50.300,Pfam_domain:PF00071,Prints_domain:PR00449,PROSITE_profiles:PS51421,hmmpanther:PTHR24070,hmmpanther:PTHR24070:SF186,Low_complexity_(Seg):seg,SMART_domains:SM00173,SMART_domains:SM00174,SMART_domains:SM00175,SMART_domains:SM00176,Superfamily_domains:SSF52540,TIGRFAM_domain:TIGR00231
# 339408                                                                                                                                                                       Gene3D:2.60.40.720,Pfam_domain:PF00870,Prints_domain:PR00386,hmmpanther:PTHR11447,hmmpanther:PTHR11447:SF6,Superfamily_domains:SSF49417
# 339409                                                                                                                                                                                                                                                                 hmmpanther:PTHR16200:SF2,hmmpanther:PTHR16200
# 339410                                                                                                                                                                                                                                                                 hmmpanther:PTHR23068:SF9,hmmpanther:PTHR23068
#
#         GMAF  AFR_MAF  AMR_MAF  ASN_MAF  EAS_MAF  EUR_MAF  SAS_MAF  AA_MAF  \
# 7        NaN      NaN      NaN      NaN      NaN      NaN      NaN     NaN
# 8        NaN      NaN      NaN      NaN      NaN      NaN      NaN     NaN
# 9        NaN      NaN      NaN      NaN      NaN      NaN      NaN     NaN
# 10       NaN      NaN      NaN      NaN      NaN      NaN      NaN     NaN
# 11       NaN      NaN      NaN      NaN      NaN      NaN      NaN     NaN
# ...      ...      ...      ...      ...      ...      ...      ...     ...
# 339406   NaN      NaN      NaN      NaN      NaN      NaN      NaN     NaN
# 339407   NaN      NaN      NaN      NaN      NaN      NaN      NaN     NaN
# 339408   NaN      NaN      NaN      NaN      NaN      NaN      NaN     NaN
# 339409   NaN      NaN      NaN      NaN      NaN      NaN      NaN     NaN
# 339410   NaN      NaN      NaN      NaN      NaN      NaN      NaN     NaN
#
#         EA_MAF  CLIN_SIG  SOMATIC  PUBMED  MOTIF_NAME  MOTIF_POS  \
# 7          NaN       NaN      NaN     NaN         NaN        NaN
# 8          NaN       NaN      NaN     NaN         NaN        NaN
# 9          NaN       NaN      NaN     NaN         NaN        NaN
# 10         NaN       NaN      NaN     NaN         NaN        NaN
# 11         NaN       NaN      NaN     NaN         NaN        NaN
# ...        ...       ...      ...     ...         ...        ...
# 339406     NaN       NaN      NaN     NaN         NaN        NaN
# 339407     NaN       NaN      NaN     NaN         NaN        NaN
# 339408     NaN       NaN      NaN     NaN         NaN        NaN
# 339409     NaN       NaN      NaN     NaN         NaN        NaN
# 339410     NaN       NaN      NaN     NaN         NaN        NaN
#
#         HIGH_INF_POS  MOTIF_SCORE_CHANGE    IMPACT  PICK        VARIANT_CLASS  \
# 7                NaN                 NaN  MODERATE   1.0                indel
# 8                NaN                 NaN      HIGH   1.0  sequence_alteration
# 9                NaN                 NaN  MODERATE   1.0                indel
# 10               NaN                 NaN      HIGH   NaN                indel
# 11               NaN                 NaN  MODERATE   NaN                indel
# ...              ...                 ...       ...   ...                  ...
# 339406           NaN                 NaN      HIGH   1.0            insertion
# 339407           NaN                 NaN  MODERATE   1.0                indel
# 339408           NaN                 NaN  MODERATE   1.0                indel
# 339409           NaN                 NaN  MODERATE   NaN                indel
# 339410           NaN                 NaN      HIGH   1.0                indel
#
#         TSL  HGVS_OFFSET  PHENO  MINIMISED  ExAC_AF  ExAC_AF_AFR  ExAC_AF_AMR  \
# 7       NaN          NaN    NaN        NaN      NaN          NaN          NaN
# 8       NaN          NaN    NaN        NaN      NaN          NaN          NaN
# 9       NaN          NaN    NaN        NaN      NaN          NaN          NaN
# 10      NaN          NaN    NaN        NaN      NaN          NaN          NaN
# 11      NaN          NaN    NaN        NaN      NaN          NaN          NaN
# ...     ...          ...    ...        ...      ...          ...          ...
# 339406  NaN          1.0    NaN        NaN      NaN          NaN          NaN
# 339407  NaN          NaN    NaN        NaN      NaN          NaN          NaN
# 339408  NaN          NaN    NaN        NaN      NaN          NaN          NaN
# 339409  NaN          NaN    NaN        NaN      NaN          NaN          NaN
# 339410  NaN          NaN    NaN        NaN      NaN          NaN          NaN
#
#         ExAC_AF_EAS  ExAC_AF_FIN  ExAC_AF_NFE  ExAC_AF_OTH  ExAC_AF_SAS  \
# 7               NaN          NaN          NaN          NaN          NaN
# 8               NaN          NaN          NaN          NaN          NaN
# 9               NaN          NaN          NaN          NaN          NaN
# 10              NaN          NaN          NaN          NaN          NaN
# 11              NaN          NaN          NaN          NaN          NaN
# ...             ...          ...          ...          ...          ...
# 339406          NaN          NaN          NaN          NaN          NaN
# 339407          NaN          NaN          NaN          NaN          NaN
# 339408          NaN          NaN          NaN          NaN          NaN
# 339409          NaN          NaN          NaN          NaN          NaN
# 339410          NaN          NaN          NaN          NaN          NaN
#
#         GENE_PHENO FILTER flanking_bps variant_id variant_qual  ExAC_AF_Adj  \
# 7              1.0    NaN          CCA          .            .          NaN
# 8              1.0    NaN         GGCC          .            .          NaN
# 9              NaN    NaN          CCC          .            .          NaN
# 10             1.0    NaN          GGT          .            .          NaN
# 11             1.0    NaN          GCA          .            .          NaN
# ...            ...    ...          ...        ...          ...          ...
# 339406         NaN    NaN          GCA          .            .          NaN
# 339407         1.0    NaN          ACC          .            .          NaN
# 339408         1.0    NaN          CGG          .            .          NaN
# 339409         1.0    NaN          GCC          .            .          NaN
# 339410         1.0    NaN          TCG          .            .          NaN
#
#        ExAC_AC_AN_Adj ExAC_AC_AN ExAC_AC_AN_AFR ExAC_AC_AN_AMR ExAC_AC_AN_EAS  \
# 7                 NaN        NaN            NaN            NaN            NaN
# 8                 NaN        NaN            NaN            NaN            NaN
# 9                 NaN        NaN            NaN            NaN            NaN
# 10                NaN        NaN            NaN            NaN            NaN
# 11                NaN        NaN            NaN            NaN            NaN
# ...               ...        ...            ...            ...            ...
# 339406            NaN        NaN            NaN            NaN            NaN
# 339407            NaN        NaN            NaN            NaN            NaN
# 339408            NaN        NaN            NaN            NaN            NaN
# 339409            NaN        NaN            NaN            NaN            NaN
# 339410            NaN        NaN            NaN            NaN            NaN
#
#        ExAC_AC_AN_FIN ExAC_AC_AN_NFE ExAC_AC_AN_OTH ExAC_AC_AN_SAS  \
# 7                 NaN            NaN            NaN            NaN
# 8                 NaN            NaN            NaN            NaN
# 9                 NaN            NaN            NaN            NaN
# 10                NaN            NaN            NaN            NaN
# 11                NaN            NaN            NaN            NaN
# ...               ...            ...            ...            ...
# 339406            NaN            NaN            NaN            NaN
# 339407            NaN            NaN            NaN            NaN
# 339408            NaN            NaN            NaN            NaN
# 339409            NaN            NaN            NaN            NaN
# 339410            NaN            NaN            NaN            NaN
#
#        ExAC_FILTER  Caller is-a-hotspot is-a-3d-hotspot  \
# 7              NaN     NaN            Y               Y
# 8              NaN     NaN          NaN             NaN
# 9              NaN     NaN          NaN             NaN
# 10             NaN     NaN          NaN             NaN
# 11             NaN     NaN          NaN             NaN
# ...            ...     ...          ...             ...
# 339406         NaN     NaN          NaN             NaN
# 339407         NaN     NaN            Y               Y
# 339408         NaN     NaN            Y               Y
# 339409         NaN     NaN          NaN             NaN
# 339410         NaN     NaN          NaN             NaN
#
#                 mutation_effect         oncogenic LEVEL_1 LEVEL_2A LEVEL_2B  \
# 7              Gain-of-function         Oncogenic     NaN      NaN      NaN
# 8       Likely Loss-of-function  Likely Oncogenic     NaN      NaN      NaN
# 9                           NaN               NaN     NaN      NaN      NaN
# 10      Likely Loss-of-function  Likely Oncogenic     NaN      NaN      NaN
# 11                          NaN               NaN     NaN      NaN      NaN
# ...                         ...               ...     ...      ...      ...
# 339406  Likely Loss-of-function  Likely Oncogenic     NaN      NaN      NaN
# 339407         Gain-of-function         Oncogenic     NaN      NaN      NaN
# 339408  Likely Loss-of-function  Likely Oncogenic     NaN      NaN      NaN
# 339409                      NaN               NaN     NaN      NaN      NaN
# 339410  Likely Loss-of-function  Likely Oncogenic     NaN      NaN      NaN
#
#        LEVEL_3A LEVEL_3B                             LEVEL_4 LEVEL_R1  \
# 7           NaN      NaN  Binimetinib,Cobimetinib,Trametinib      NaN
# 8           NaN      NaN                                 NaN      NaN
# 9           NaN      NaN                                 NaN      NaN
# 10          NaN      NaN                                 NaN      NaN
# 11          NaN      NaN                                 NaN      NaN
# ...         ...      ...                                 ...      ...
# 339406      NaN      NaN                                 NaN      NaN
# 339407      NaN      NaN  Binimetinib,Cobimetinib,Trametinib      NaN
# 339408      NaN      NaN                                 NaN      NaN
# 339409      NaN      NaN                                 NaN      NaN
# 339410      NaN      NaN                                 NaN      NaN
#
#        LEVEL_R2  LEVEL_R3 Highest_level  \
# 7           NaN       NaN       LEVEL_4
# 8           NaN       NaN           NaN
# 9           NaN       NaN           NaN
# 10          NaN       NaN           NaN
# 11          NaN       NaN           NaN
# ...         ...       ...           ...
# 339406      NaN       NaN           NaN
# 339407      NaN       NaN       LEVEL_4
# 339408      NaN       NaN           NaN
# 339409      NaN       NaN           NaN
# 339410      NaN       NaN           NaN
#
#                                                                                                                                                                                                                                                                                                                                                                                                                      citations  \
# 7                                  16051643;25705018;26841430;24256730;28783719;29247021;Bhagwat et al. Abstract# 4973, AACR 2017(http://cancerres.aacrjournals.org/content/77/13_Supplement/4973);Robarge et al. Abstract# DDT02-03, AACR 2014(http://cancerres.aacrjournals.org/content/74/19_Supplement/DDT02-03);Burrows et al. Abstract# 5168, AACR 2017(http://cancerres.aacrjournals.org/content/77/13_Supplement/5168)
# 8                                                                                                                                                                                                                                                                                                                                                                                 24652667;19892943;25079552;21516316;19340305
# 9                                                                                                                                                                                                                                                                                                                                                                                                                          NaN
# 10                                                                                                                                                                                                                                                                                                                                                                                24658002;24658001;24658004;25060813;18301784
# 11                                                                                                                                                                                                                                                                                                                                                                                                                         NaN
# ...                                                                                                                                                                                                                                                                                                                                                                                                                        ...
# 339406                                                                                                                                                                                                                                                                                                                                                                                              14976186;17148437;26806338
# 339407  20516123;20949621;30341394;25359494;20570890;12957286;20147967;28783719;29247021;Bhagwat et al. Abstract# 4973, AACR 2017(http://cancerres.aacrjournals.org/content/77/13_Supplement/4973);Robarge et al. Abstract# DDT02-03, AACR 2014(http://cancerres.aacrjournals.org/content/74/19_Supplement/DDT02-03);Burrows et al. Abstract# 5168, AACR 2017(http://cancerres.aacrjournals.org/content/77/13_Supplement/5168)
# 339408                                                                                                                                                                                                                                                                                                                                                                                                                21445056
# 339409                                                                                                                                                                                                                                                                                                                                                                                                                     NaN
# 339410                                                                                                                                                                                                                                                                                                                                                                                                                22133874
#
#         driver  tcn  lcn        cf    purity  t_var_freq  expected_alt_copies  \
# 7         True  4.0  2.0  0.138437  0.273767    0.158163                  1.0
# 8         True  2.0  0.0  0.183720  0.273767    0.200000                  1.0
# 9        False  2.0  0.0  0.183720  0.273767    0.184087                  1.0
# 10        True  2.0  0.0  0.183720  0.273767    0.166292                  1.0
# 11       False  2.0  0.0  0.183720  0.273767    0.197452                  1.0
# ...        ...  ...  ...       ...       ...         ...                  ...
# 339406    True  2.0  0.0  0.663312  0.663312    0.368742                  1.0
# 339407    True  2.0  0.0  0.655753  0.663312    0.315545                  1.0
# 339408    True  1.0  0.0  0.632827  0.663312    0.484629                  1.0
# 339409   False  1.0  0.0  0.663312  0.663312    0.508434                  1.0
# 339410    True  2.0  1.0  1.000000  0.663312    0.303957                  1.0
#
#         ccf_Mcopies  ccf_Mcopies_lower  ccf_Mcopies_upper  ccf_Mcopies_prob95  \
# 7             0.736              0.655              0.821        2.235549e-03
# 8             0.731              0.662              0.802        2.663028e-04
# 9             0.672              0.608              0.740        3.215666e-06
# 10            0.607              0.534              0.686        1.397430e-06
# 11            0.721              0.644              0.803        7.615616e-04
# ...             ...                ...                ...                 ...
# 339406        0.556              0.526              0.587        6.037271e-52
# 339407        0.476              0.436              0.517        3.623704e-40
# 339408        0.977              0.926              1.000        6.310788e-01
# 339409        1.000              0.961              1.000        7.951647e-01
# 339410        0.916              0.848              0.987        2.326712e-01
#
#         ccf_Mcopies_prob90  ccf_1copy  ccf_1copy_lower  ccf_1copy_upper  \
# 7             1.483415e-02      1.000            0.979            1.000
# 8             3.570729e-03      1.000            0.984            1.000
# 9             9.339940e-05      1.000            0.980            1.000
# 10            2.653238e-05      1.000            0.959            1.000
# 11            6.531934e-03      1.000            0.979            1.000
# ...                    ...        ...              ...              ...
# 339406        1.059852e-39      1.000            0.985            1.000
# 339407        2.625269e-32      0.951            0.873            1.000
# 339408        9.506046e-01      0.977            0.926            1.000
# 339409        9.822580e-01      1.000            0.961            1.000
# 339410        5.891686e-01      0.916            0.848            0.987
#
#         ccf_1copy_prob95  ccf_1copy_prob90  ccf_expected_copies  \
# 7               0.860769          0.984692                1.000
# 8               0.926527          0.996079                1.000
# 9               0.880435          0.989551                1.000
# 10              0.659996          0.904988                1.000
# 11              0.859171          0.984420                1.000
# ...                  ...               ...                  ...
# 339406          0.959714          0.999420                1.000
# 339407          0.367941          0.721743                0.951
# 339408          0.631079          0.950605                0.977
# 339409          0.795165          0.982258                1.000
# 339410          0.232671          0.589169                0.916
#
#         ccf_expected_copies_lower  ccf_expected_copies_upper  \
# 7                           0.979                      1.000
# 8                           0.984                      1.000
# 9                           0.980                      1.000
# 10                          0.959                      1.000
# 11                          0.979                      1.000
# ...                           ...                        ...
# 339406                      0.985                      1.000
# 339407                      0.873                      1.000
# 339408                      0.926                      1.000
# 339409                      0.961                      1.000
# 339410                      0.848                      0.987
#
#         ccf_expected_copies_prob95  ccf_expected_copies_prob90  \
# 7                         0.860769                    0.984692
# 8                         0.926527                    0.996079
# 9                         0.880435                    0.989551
# 10                        0.659996                    0.904988
# 11                        0.859171                    0.984420
# ...                            ...                         ...
# 339406                    0.959714                    0.999420
# 339407                    0.367941                    0.721743
# 339408                    0.631079                    0.950605
# 339409                    0.795165                    0.982258
# 339410                    0.232671                    0.589169
#
#                                                                                                     facets_fit  \
# 7       /juno/work/ccs/shared/resources/impact/facets/all/P-00259/P-0025956-T01-IM6_P-0025956-N01-IM6//default
# 8       /juno/work/ccs/shared/resources/impact/facets/all/P-00259/P-0025956-T01-IM6_P-0025956-N01-IM6//default
# 9       /juno/work/ccs/shared/resources/impact/facets/all/P-00259/P-0025956-T01-IM6_P-0025956-N01-IM6//default
# 10      /juno/work/ccs/shared/resources/impact/facets/all/P-00259/P-0025956-T01-IM6_P-0025956-N01-IM6//default
# 11      /juno/work/ccs/shared/resources/impact/facets/all/P-00259/P-0025956-T01-IM6_P-0025956-N01-IM6//default
# ...                                                                                                        ...
# 339406  /juno/work/ccs/shared/resources/impact/facets/all/P-00495/P-0049537-T01-IM6_P-0049537-N01-IM6//default
# 339407  /juno/work/ccs/shared/resources/impact/facets/all/P-00495/P-0049537-T01-IM6_P-0049537-N01-IM6//default
# 339408  /juno/work/ccs/shared/resources/impact/facets/all/P-00495/P-0049537-T01-IM6_P-0049537-N01-IM6//default
# 339409  /juno/work/ccs/shared/resources/impact/facets/all/P-00495/P-0049537-T01-IM6_P-0049537-N01-IM6//default
# 339410  /juno/work/ccs/shared/resources/impact/facets/all/P-00495/P-0049537-T01-IM6_P-0049537-N01-IM6//default
#
#         reviewer_set_purity  use_only_purity_run  use_edited_cncf  \
# 7                       NaN                False            False
# 8                       NaN                False            False
# 9                       NaN                False            False
# 10                      NaN                False            False
# 11                      NaN                False            False
# ...                     ...                  ...              ...
# 339406                  NaN                False            False
# 339407                  NaN                False            False
# 339408                  NaN                False            False
# 339409                  NaN                False            False
# 339410                  NaN                False            False
#
#                                                                                                                                                     cncf_file_used  \
# 7       /juno/work/ccs/shared/resources/impact/facets/all/P-00259/P-0025956-T01-IM6_P-0025956-N01-IM6//default/P-0025956-T01-IM6_P-0025956-N01-IM6_hisens.cncf.txt
# 8       /juno/work/ccs/shared/resources/impact/facets/all/P-00259/P-0025956-T01-IM6_P-0025956-N01-IM6//default/P-0025956-T01-IM6_P-0025956-N01-IM6_hisens.cncf.txt
# 9       /juno/work/ccs/shared/resources/impact/facets/all/P-00259/P-0025956-T01-IM6_P-0025956-N01-IM6//default/P-0025956-T01-IM6_P-0025956-N01-IM6_hisens.cncf.txt
# 10      /juno/work/ccs/shared/resources/impact/facets/all/P-00259/P-0025956-T01-IM6_P-0025956-N01-IM6//default/P-0025956-T01-IM6_P-0025956-N01-IM6_hisens.cncf.txt
# 11      /juno/work/ccs/shared/resources/impact/facets/all/P-00259/P-0025956-T01-IM6_P-0025956-N01-IM6//default/P-0025956-T01-IM6_P-0025956-N01-IM6_hisens.cncf.txt
# ...                                                                                                                                                            ...
# 339406  /juno/work/ccs/shared/resources/impact/facets/all/P-00495/P-0049537-T01-IM6_P-0049537-N01-IM6//default/P-0049537-T01-IM6_P-0049537-N01-IM6_hisens.cncf.txt
# 339407  /juno/work/ccs/shared/resources/impact/facets/all/P-00495/P-0049537-T01-IM6_P-0049537-N01-IM6//default/P-0049537-T01-IM6_P-0049537-N01-IM6_hisens.cncf.txt
# 339408  /juno/work/ccs/shared/resources/impact/facets/all/P-00495/P-0049537-T01-IM6_P-0049537-N01-IM6//default/P-0049537-T01-IM6_P-0049537-N01-IM6_hisens.cncf.txt
# 339409  /juno/work/ccs/shared/resources/impact/facets/all/P-00495/P-0049537-T01-IM6_P-0049537-N01-IM6//default/P-0049537-T01-IM6_P-0049537-N01-IM6_hisens.cncf.txt
# 339410  /juno/work/ccs/shared/resources/impact/facets/all/P-00495/P-0049537-T01-IM6_P-0049537-N01-IM6//default/P-0049537-T01-IM6_P-0049537-N01-IM6_hisens.cncf.txt
#
#           LOH          mut_key Patient_Id                    sample_mut_key
# 7        True  12_25398285_C_A  P-0025956  P-0025956-T01-IM612_25398285_C_A
# 8         NaN   19_1221314_C_-  P-0025956   P-0025956-T01-IM619_1221314_C_-
# 9         NaN  19_10602584_C_T  P-0025956  P-0025956-T01-IM619_10602584_C_T
# 10      False  19_11113836_G_A  P-0025956  P-0025956-T01-IM619_11113836_G_A
# 11       True  20_40735560_C_A  P-0025956  P-0025956-T01-IM620_40735560_C_A
# ...       ...              ...        ...                               ...
# 339406    NaN  1_201982345_-_A  P-0049537  P-0049537-T01-IM61_201982345_-_A
# 339407    NaN  12_25398284_C_A  P-0049537  P-0049537-T01-IM612_25398284_C_A
# 339408    NaN   17_7577094_G_A  P-0049537   P-0049537-T01-IM617_7577094_G_A
# 339409    NaN  17_56440961_C_G  P-0049537  P-0049537-T01-IM617_56440961_C_G
# 339410    NaN  20_31374317_C_T  P-0049537  P-0049537-T01-IM620_31374317_C_T
#
# [90478 rows x 170 columns]

# %%
# test to count the number of mutations per sample
sample_muts = maf_cohort_wgd[maf_cohort_wgd.Tumor_Sample_Barcode == 'P-0025956-T01-IM6'][maf_cohort_wgd.Tumor_Sample_Barcode == 'P-0023546-T02-IM6'][maf_cohort['Hugo_Symbol'] == 'TP53'].drop_duplicates(subset='sample_mut_key')
sample_muts.shape[0]
# Out:
# 0

# %%
maf_cohort_wgd[maf_cohort_wgd.Tumor_Sample_Barcode == 'P-0023546-T02-IM6'][maf_cohort_wgd.Tumor_Sample_Barcode == 'P-0023546-T02-IM6']
# Out:
#     Hugo_Symbol  Entrez_Gene_Id Center NCBI_Build Chromosome  Start_Position  \
# 111      CTNNB1            1499  MSKCC     GRCh37          3        41266098
# 112      PIK3CG            5294  MSKCC     GRCh37          7       106519962
# 113        TP53            7157  MSKCC     GRCh37         17         7578442
#
#      End_Position Strand Variant_Classification Variant_Type Reference_Allele  \
# 111      41266098      +      Missense_Mutation          SNP                A
# 112     106519962      +            Splice_Site          SNP                A
# 113       7578442      +      Missense_Mutation          SNP                T
#
#     Tumor_Seq_Allele1 Tumor_Seq_Allele2 dbSNP_RS  dbSNP_Val_Status  \
# 111                 A                 C    novel               NaN
# 112                 A                 T    novel               NaN
# 113                 T                 C    novel               NaN
#
#     Tumor_Sample_Barcode  Matched_Norm_Sample_Barcode Match_Norm_Seq_Allele1  \
# 111    P-0023546-T02-IM6                          NaN                    NaN
# 112    P-0023546-T02-IM6                          NaN                    NaN
# 113    P-0023546-T02-IM6                          NaN                    NaN
#
#     Match_Norm_Seq_Allele2  Tumor_Validation_Allele1  \
# 111                    NaN                       NaN
# 112                    NaN                       NaN
# 113                    NaN                       NaN
#
#      Tumor_Validation_Allele2  Match_Norm_Validation_Allele1  \
# 111                       NaN                            NaN
# 112                       NaN                            NaN
# 113                       NaN                            NaN
#
#      Match_Norm_Validation_Allele2  Verification_Status Validation_Status  \
# 111                            NaN                  NaN           Unknown
# 112                            NaN                  NaN           Unknown
# 113                            NaN                  NaN           Unknown
#
#     Mutation_Status  Sequencing_Phase  Sequence_Source  Validation_Method  \
# 111         SOMATIC               NaN              NaN                NaN
# 112         SOMATIC               NaN              NaN                NaN
# 113         SOMATIC               NaN              NaN                NaN
#
#           Score  BAM_File  Sequencer  Tumor_Sample_UUID  \
# 111  MSK-IMPACT       NaN        NaN                NaN
# 112  MSK-IMPACT       NaN        NaN                NaN
# 113  MSK-IMPACT       NaN        NaN                NaN
#
#      Matched_Norm_Sample_UUID        HGVSc        HGVSp    HGVSp_Short  \
# 111                       NaN      c.95A>C   p.Asp32Ala         p.D32A
# 112                       NaN  c.2392-2A>T          NaN  p.X798_splice
# 113                       NaN     c.488A>G  p.Tyr163Cys        p.Y163C
#
#        Transcript_ID Exon_Number  t_depth  t_ref_count  t_alt_count  n_depth  \
# 111  ENST00000349496        3/15    386.0        339.0         47.0      390
# 112  ENST00000359195         NaN    208.0        188.0         20.0      244
# 113  ENST00000269305        5/11    490.0        178.0        312.0      744
#
#     n_ref_count n_alt_count  \
# 111         390           0
# 112         243           1
# 113         744           0
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  all_effects  \
# 111                                                                                                                                                                                                                                                                                                                                                    CTNNB1,missense_variant,p.Asp32Ala,ENST00000349496,NM_001904.3;CTNNB1,missense_variant,p.Asp32Ala,ENST00000396185,NM_001098209.1;CTNNB1,missense_variant,p.Asp32Ala,ENST00000396183,NM_001098210.1;CTNNB1,missense_variant,p.Asp25Ala,ENST00000453024,;CTNNB1,missense_variant,p.Asp32Ala,ENST00000405570,;CTNNB1,missense_variant,p.Asp32Ala,ENST00000450969,;CTNNB1,missense_variant,p.Asp32Ala,ENST00000431914,;CTNNB1,missense_variant,p.Asp32Ala,ENST00000441708,;CTNNB1,missense_variant,p.Asp25Ala,ENST00000426215,;CTNNB1,downstream_gene_variant,,ENST00000433400,;CTNNB1,non_coding_transcript_exon_variant,,ENST00000488914,;,regulatory_region_variant,,ENSR00000203589,;
# 112                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              PIK3CG,splice_acceptor_variant,,ENST00000359195,NM_002649.2,NM_001282427.1;PIK3CG,splice_acceptor_variant,,ENST00000496166,NM_001282426.1;PIK3CG,splice_acceptor_variant,,ENST00000440650,;PIK3CG,splice_acceptor_variant,,ENST00000473541,;PIK3CG,upstream_gene_variant,,ENST00000466738,;
# 113  TP53,missense_variant,p.Tyr163Cys,ENST00000420246,NM_001126114.2,NM_001276696.1;TP53,missense_variant,p.Tyr163Cys,ENST00000455263,NM_001276695.1,NM_001126113.2;TP53,missense_variant,p.Tyr163Cys,ENST00000269305,NM_001126112.2,NM_001276761.1,NM_001276760.1,NM_000546.5,NM_001126118.1;TP53,missense_variant,p.Tyr163Cys,ENST00000445888,;TP53,missense_variant,p.Tyr163Cys,ENST00000359597,;TP53,missense_variant,p.Tyr163Cys,ENST00000413465,;TP53,missense_variant,p.Tyr31Cys,ENST00000509690,;TP53,missense_variant,p.Tyr163Cys,ENST00000508793,;TP53,missense_variant,p.Tyr70Cys,ENST00000514944,;TP53,downstream_gene_variant,,ENST00000604348,;TP53,downstream_gene_variant,,ENST00000503591,;TP53,upstream_gene_variant,,ENST00000576024,;TP53,upstream_gene_variant,,ENST00000574684,;TP53,non_coding_transcript_exon_variant,,ENST00000510385,;TP53,non_coding_transcript_exon_variant,,ENST00000504290,;TP53,non_coding_transcript_exon_variant,,ENST00000504937,;TP53,non_coding_transcript_exon_variant,,ENST0000050...
#
#     Allele             Gene          Feature Feature_type  \
# 111      C  ENSG00000168036  ENST00000349496   Transcript
# 112      T  ENSG00000105851  ENST00000359195   Transcript
# 113      C  ENSG00000141510  ENST00000269305   Transcript
#
#                  Consequence cDNA_position CDS_position Protein_position  \
# 111         missense_variant      375/3729      95/2346           32/781
# 112  splice_acceptor_variant        -/5377    2392/3309         798/1102
# 113         missense_variant      678/2579     488/1182          163/393
#
#     Amino_acids   Codons  Existing_variation  ALLELE_NUM  DISTANCE  \
# 111         D/A  gAc/gCc                 NaN           1       NaN
# 112         NaN      NaN                 NaN           1       NaN
# 113         Y/C  tAc/tGc                 NaN           1       NaN
#
#      STRAND_VEP  SYMBOL SYMBOL_SOURCE  HGNC_ID         BIOTYPE CANONICAL  \
# 111           1  CTNNB1          HGNC   2514.0  protein_coding       YES
# 112           1  PIK3CG          HGNC   8978.0  protein_coding       YES
# 113          -1    TP53          HGNC  11998.0  protein_coding       YES
#
#             CCDS             ENSP SWISSPROT  \
# 111   CCDS2694.1  ENSP00000344456    P35222
# 112   CCDS5739.1  ENSP00000352121    P48736
# 113  CCDS11118.1  ENSP00000269305    P04637
#
#                                                                                                                                                                              TREMBL  \
# 111                                                                                                                                       G9GAG7,E9PDF9,E7EV28,E7EMJ5,C9IZ65,B4DGU4
# 112                                                                                                                                                                   Q24M88,E9PDN7
# 113  S5LQU8,Q761V2,Q6IT77,Q1HGV1,Q0PKT5,L0ES54,L0EQ05,K7PPA8,H2EHT1,G4Y083,E9PCY9,E7ESS1,E7EMR6,B5AKF6,B4DNI2,A4GWD0,A4GWB8,A4GWB5,A4GW97,A4GW76,A4GW75,A4GW74,A4GW67,A2I9Z1,A2I9Z0
#
#            UNIPARC  \
# 111  UPI000012862F
# 112  UPI00000746B8
# 113  UPI000002ED67
#
#                                                                       RefSeq  \
# 111                                                              NM_001904.3
# 112                                               NM_002649.2,NM_001282427.1
# 113  NM_001126112.2,NM_001276761.1,NM_001276760.1,NM_000546.5,NM_001126118.1
#
#                SIFT                  PolyPhen  EXON INTRON  \
# 111  deleterious(0)  probably_damaging(0.959)  3/15    NaN
# 112             NaN                       NaN   NaN   5/10
# 113  deleterious(0)  probably_damaging(0.999)  5/11    NaN
#
#                                                                                                                                      DOMAINS  \
# 111                                                                                           hmmpanther:PTHR23315,hmmpanther:PTHR23315:SF53
# 112                                                                                                                                      NaN
# 113  Gene3D:2.60.40.720,Pfam_domain:PF00870,Prints_domain:PR00386,hmmpanther:PTHR11447,hmmpanther:PTHR11447:SF6,Superfamily_domains:SSF49417
#
#      GMAF  AFR_MAF  AMR_MAF  ASN_MAF  EAS_MAF  EUR_MAF  SAS_MAF  AA_MAF  \
# 111   NaN      NaN      NaN      NaN      NaN      NaN      NaN     NaN
# 112   NaN      NaN      NaN      NaN      NaN      NaN      NaN     NaN
# 113   NaN      NaN      NaN      NaN      NaN      NaN      NaN     NaN
#
#      EA_MAF  CLIN_SIG  SOMATIC  PUBMED  MOTIF_NAME  MOTIF_POS  HIGH_INF_POS  \
# 111     NaN       NaN      NaN     NaN         NaN        NaN           NaN
# 112     NaN       NaN      NaN     NaN         NaN        NaN           NaN
# 113     NaN       NaN      NaN     NaN         NaN        NaN           NaN
#
#      MOTIF_SCORE_CHANGE    IMPACT  PICK VARIANT_CLASS  TSL  HGVS_OFFSET  \
# 111                 NaN  MODERATE   1.0           SNV  NaN          NaN
# 112                 NaN      HIGH   1.0           SNV  NaN          NaN
# 113                 NaN  MODERATE   1.0         indel  NaN          NaN
#
#      PHENO  MINIMISED  ExAC_AF  ExAC_AF_AFR  ExAC_AF_AMR  ExAC_AF_EAS  \
# 111    NaN        1.0      NaN          NaN          NaN          NaN
# 112    NaN        1.0      NaN          NaN          NaN          NaN
# 113    NaN        NaN      NaN          NaN          NaN          NaN
#
#      ExAC_AF_FIN  ExAC_AF_NFE  ExAC_AF_OTH  ExAC_AF_SAS  GENE_PHENO FILTER  \
# 111          NaN          NaN          NaN          NaN         1.0    NaN
# 112          NaN          NaN          NaN          NaN         NaN    NaN
# 113          NaN          NaN          NaN          NaN         1.0    NaN
#
#     flanking_bps variant_id variant_qual  ExAC_AF_Adj ExAC_AC_AN_Adj  \
# 111          GAC          .            .          NaN            NaN
# 112          CAG          .            .          NaN            NaN
# 113          GTA          .            .          NaN            NaN
#
#     ExAC_AC_AN ExAC_AC_AN_AFR ExAC_AC_AN_AMR ExAC_AC_AN_EAS ExAC_AC_AN_FIN  \
# 111        NaN            NaN            NaN            NaN            NaN
# 112        NaN            NaN            NaN            NaN            NaN
# 113        NaN            NaN            NaN            NaN            NaN
#
#     ExAC_AC_AN_NFE ExAC_AC_AN_OTH ExAC_AC_AN_SAS ExAC_FILTER  Caller  \
# 111            NaN            NaN            NaN         NaN     NaN
# 112            NaN            NaN            NaN         NaN     NaN
# 113            NaN            NaN            NaN         NaN     NaN
#
#     is-a-hotspot is-a-3d-hotspot   mutation_effect         oncogenic LEVEL_1  \
# 111            Y             NaN  Gain-of-function  Likely Oncogenic     NaN
# 112          NaN             NaN               NaN               NaN     NaN
# 113            Y               Y  Loss-of-function  Likely Oncogenic     NaN
#
#     LEVEL_2A LEVEL_2B LEVEL_3A LEVEL_3B LEVEL_4 LEVEL_R1 LEVEL_R2  LEVEL_R3  \
# 111      NaN      NaN      NaN      NaN     NaN      NaN      NaN       NaN
# 112      NaN      NaN      NaN      NaN     NaN      NaN      NaN       NaN
# 113      NaN      NaN      NaN      NaN     NaN      NaN      NaN       NaN
#
#     Highest_level                                             citations  \
# 111           NaN                                              15829978
# 112           NaN                                                   NaN
# 113           NaN  25584008;8023157;11900253;15077194;23246812;15037740
#
#      driver  tcn  lcn        cf    purity  t_var_freq  expected_alt_copies  \
# 111    True  6.0  3.0  0.312907  0.312907    0.121762                  1.0
# 112   False  3.0  1.0  0.312907  0.312907    0.096154                  1.0
# 113    True  2.0  0.0  0.312907  0.312907    0.636735                  4.0
#
#      ccf_Mcopies  ccf_Mcopies_lower  ccf_Mcopies_upper  ccf_Mcopies_prob95  \
# 111        0.422              0.357              0.493        2.583183e-13
# 112        0.355              0.273              0.451        3.536964e-09
# 113        1.000              0.997              1.000        9.999955e-01
#
#      ccf_Mcopies_prob90  ccf_1copy  ccf_1copy_lower  ccf_1copy_upper  \
# 111        1.732627e-11      1.000            0.944            1.000
# 112        4.038132e-08      0.711            0.546            0.902
# 113        1.000000e+00      1.000            0.997            1.000
#
#      ccf_1copy_prob95  ccf_1copy_prob90  ccf_expected_copies  \
# 111          0.545539          0.816613                1.000
# 112          0.040386          0.099892                0.711
# 113          1.000000          1.000000                1.000
#
#      ccf_expected_copies_lower  ccf_expected_copies_upper  \
# 111                      0.944                      1.000
# 112                      0.546                      0.902
# 113                      0.972                      1.000
#
#      ccf_expected_copies_prob95  ccf_expected_copies_prob90  \
# 111                    0.545539                    0.816613
# 112                    0.040386                    0.099892
# 113                    0.913083                    0.998538
#
#                                                                                                  facets_fit  \
# 111  /juno/work/ccs/shared/resources/impact/facets/all/P-00235/P-0023546-T02-IM6_P-0023546-N01-IM6//default
# 112  /juno/work/ccs/shared/resources/impact/facets/all/P-00235/P-0023546-T02-IM6_P-0023546-N01-IM6//default
# 113  /juno/work/ccs/shared/resources/impact/facets/all/P-00235/P-0023546-T02-IM6_P-0023546-N01-IM6//default
#
#      reviewer_set_purity  use_only_purity_run  use_edited_cncf  \
# 111                  NaN                False            False
# 112                  NaN                False            False
# 113                  NaN                False            False
#
#                                                                                                                                                  cncf_file_used  \
# 111  /juno/work/ccs/shared/resources/impact/facets/all/P-00235/P-0023546-T02-IM6_P-0023546-N01-IM6//default/P-0023546-T02-IM6_P-0023546-N01-IM6_hisens.cncf.txt
# 112  /juno/work/ccs/shared/resources/impact/facets/all/P-00235/P-0023546-T02-IM6_P-0023546-N01-IM6//default/P-0023546-T02-IM6_P-0023546-N01-IM6_hisens.cncf.txt
# 113  /juno/work/ccs/shared/resources/impact/facets/all/P-00235/P-0023546-T02-IM6_P-0023546-N01-IM6//default/P-0023546-T02-IM6_P-0023546-N01-IM6_hisens.cncf.txt
#
#        LOH
# 111    NaN
# 112  False
# 113   True

# %%
master = pd.read_pickle(data_path + 'merged_data/master_file.pkl')
# We eliminate unmatched samples
master = master[master['Somatic_Status']!='Unmatched']
#We eliminate samples with too low purity
samples_cutoff = list(master[master['purity'] > 0.20]['Tumor_Id'])
samples_na = list(master[master['purity'].isna()]['Tumor_Id'])
samples_cutoff = samples_cutoff + samples_na
master_cutoff = master[master.Tumor_Id.isin(samples_cutoff)]

# %%
master_cutoff[master_cutoff['tp53_count'] >=1 ][master_cutoff['wgd'] == 1].shape[0]
# Out:
# 5895

# %%
# We will merge maf_cohort and gene_level in order to count the samples that have at least one tp53 event (either
# tp53 mutation or tp53 CN event)
# We add the WGD information to know if DIPLOID or TETRAPLOID is our baseline in terms of tp53 CN

# First we select the columns
maf_cohort_merge = maf_cohort_wgd[['Tumor_Sample_Barcode', 'Hugo_Symbol']]
gene_level_merge = gene_level_tp53_wgd[['tumor_id', 'cn_state']]
cohort=cohort[['tumor_sample', 'wgd']]

# We merge
tp53_hit = pd.merge(maf_cohort_merge, gene_level_merge, how='left', left_on='Tumor_Sample_Barcode', right_on='tumor_id')
tp53_hit = pd.merge(tp53_hit, cohort, how='left', left_on='Tumor_Sample_Barcode', right_on='tumor_sample')

# %%
tp53_hit.columns = ['tumor_id', 'Hugo_Symbol', 'tumor_id_bis', 'tp53_cn_state', 'tumor_id_ter', 'wgd']
tp53_hit = tp53_hit.drop(['tumor_id_bis', 'tumor_id_ter'], axis=1)
# Out:
#                 tumor_id Hugo_Symbol tp53_cn_state   wgd
# 0      P-0025956-T01-IM6        KRAS    LOSS AFTER  True
# 1      P-0025956-T01-IM6       STK11    LOSS AFTER  True
# 2      P-0025956-T01-IM6       KEAP1    LOSS AFTER  True
# 3      P-0025956-T01-IM6     SMARCA4    LOSS AFTER  True
# 4      P-0025956-T01-IM6       PTPRT    LOSS AFTER  True
# ...                  ...         ...           ...   ...
# 90473  P-0049537-T01-IM6        ELF3       HETLOSS  True
# 90474  P-0049537-T01-IM6        KRAS       HETLOSS  True
# 90475  P-0049537-T01-IM6        TP53       HETLOSS  True
# 90476  P-0049537-T01-IM6       RNF43       HETLOSS  True
# 90477  P-0049537-T01-IM6      DNMT3B       HETLOSS  True
#
# [90478 rows x 4 columns]

# %%
# Here we want to know the number of samples havimg only a tp53 copy number hit
# So we have to retrieve the tp53 mutated samples and remove it 
samples_tp53 = list(set(maf_cohort_wgd[maf_cohort['Hugo_Symbol'] == 'TP53'].Tumor_Sample_Barcode))
tp53_hit_no_mut = tp53_hit[~tp53_hit.tumor_id.isin(samples_tp53)]

# Now we count the number of tp53_cn_hit samples
n_cn_hits = len(set(tp53_hit_no_mut[tp53_hit_no_mut.tp53_cn_hit == 1].tumor_id))
n_cn_hits
# Out:
# 3405

# %%
len(set(tp53_hit[tp53_hit['tp53_hit'] == 1].tumor_id)) /
# Out:
# 10823
