# %% [markdown]
# # <span style='font-family:"Times New Roman"'> <span styel=''>**WHOLE GENOME DOUBLING ANALYSIS**
#
# *Emile Cohen*
#
#  *May 2020*
#
# **Goal:** In this notebook, we discover the non-WGD cohort, its main metrics, through the master.
#
# ---

# %%
# %run -i '../../../utils/setup_environment.ipy'

import warnings
warnings.filterwarnings('ignore')
from scipy.stats import fisher_exact, ranksums, chi2, norm
from statsmodels.sandbox.stats.multicomp import multipletests
import matplotlib.gridspec as gridspec
import pickle

data_path = '../../../data/'
data_wgd = data_path + 'impact-facets-tp53/processed/wgd/'
data_no_wgd = data_path + 'impact-facets-tp53/processed/no_wgd/'
# Out:
# Setup environment... done!
# <span style="color:green">✅ Working on **mskimpact_env** conda environment.</span>

# %%
# Load the master
master_no_wgd = pd.read_pickle(data_path + 'impact-facets-tp53/processed/no_wgd/master_no_wgd.pkl')
master_no_wgd.head()
# Out:
#                              Sample_Id           Tumor_Id Patient_Id  \
# 0  P-0034223-T01-IM6_P-0034223-N01-IM6  P-0034223-T01-IM6  P-0034223
# 1  P-0009819-T01-IM5_P-0009819-N01-IM5  P-0009819-T01-IM5  P-0009819
# 2  P-0027609-T01-IM6_P-0027609-N01-IM6  P-0027609-T01-IM6  P-0027609
# 3  P-0027408-T01-IM6_P-0027408-N01-IM6  P-0027408-T01-IM6  P-0027408
# 4  P-0006554-T01-IM5_P-0006554-N01-IM5  P-0006554-T01-IM5  P-0006554
#
#                   Cancer_Type          Cancer_Type_Detailed  \
# 0               Breast Cancer     Invasive Breast Carcinoma
# 1             Prostate Cancer       Prostate Adenocarcinoma
# 2           Colorectal Cancer          Colon Adenocarcinoma
# 3  Non-Small Cell Lung Cancer    Non-Small Cell Lung Cancer
# 4                      Glioma  Anaplastic Oligodendroglioma
#
#    Patient_Current_Age Sample_Type    purity    ploidy  \
# 0                 63.0  Metastasis  0.946448  2.241830
# 1                 72.0     Primary  0.278140  2.681075
# 2                 40.0  Metastasis  0.300000  2.110732
# 3                 67.0  Metastasis  0.275073  1.811066
# 4                 55.0     Primary  0.775152  1.910719
#
#    Overall_Survival_Months Overall_Survival_Status  MSI_Score MSI_Type  \
# 0                      NaN                  LIVING       0.55   Stable
# 1                   23.441                  LIVING       0.00   Stable
# 2                   23.014                  LIVING       0.00   Stable
# 3                   22.586                  LIVING       0.27   Stable
# 4                   26.170                  LIVING       1.30   Stable
#
#    TMB_Score                         tp53_key_1          tp53_vc_1  \
# 0        5.3                               None               None
# 1        1.0                               None               None
# 2        3.5    P-0027609-T01-IM617_7577548_C_T  Missense_Mutation
# 3       17.6  P-0027408-T01-IM617_7578409_CT_TC  Missense_Mutation
# 4       46.2                               None               None
#
#    tp53_ccf_1  tp53_vaf_1 tp53_HGVSp_1 tp53_spot_1 tp53_key_2 tp53_vc_2  \
# 0         NaN         NaN         None        None       None      None
# 1         NaN         NaN         None        None       None      None
# 2        0.79    0.118574  p.Gly245Ser         245       None      None
# 3        1.00    0.168901  p.Arg174Glu         174       None      None
# 4         NaN         NaN         None        None       None      None
#
#    tp53_ccf_2  tp53_vaf_2 tp53_HGVSp_2 tp53_spot_2 tp53_key_3 tp53_vc_3  \
# 0         NaN         NaN         None        None       None      None
# 1         NaN         NaN         None        None       None      None
# 2         NaN         NaN         None        None       None      None
# 3         NaN         NaN         None        None       None      None
# 4         NaN         NaN         None        None       None      None
#
#    tp53_ccf_3  tp53_vaf_3 tp53_HGVSp_3 tp53_spot_3 tp53_key_4 tp53_vc_4  \
# 0         NaN         NaN         None        None       None      None
# 1         NaN         NaN         None        None       None      None
# 2         NaN         NaN         None        None       None      None
# 3         NaN         NaN         None        None       None      None
# 4         NaN         NaN         None        None       None      None
#
#    tp53_ccf_4  tp53_vaf_4 tp53_HGVSp_4 tp53_spot_4 tp53_key_5 tp53_vc_5  \
# 0         NaN         NaN         None        None       None      None
# 1         NaN         NaN         None        None       None      None
# 2         NaN         NaN         None        None       None      None
# 3         NaN         NaN         None        None       None      None
# 4         NaN         NaN         None        None       None      None
#
#    tp53_ccf_5  tp53_vaf_5 tp53_HGVSp_5 tp53_spot_5  tp53_count  tp53_tcn  \
# 0         NaN         NaN         None        None           0         2
# 1         NaN         NaN         None        None           0         2
# 2         NaN         NaN         None        None           1         2
# 3         NaN         NaN         None        None           1         1
# 4         NaN         NaN         None        None           0         2
#
#    tp53_mcn  tp53_lcn  tp53_seg_length tp53_cn_state   tp53_cf    wgd  \
# 0       1.0       1.0         80668592       DIPLOID  1.000000  False
# 1       1.0       1.0         80668300       DIPLOID  1.000000  False
# 2       1.0       1.0         18461192       DIPLOID  1.000000  False
# 3       1.0       0.0         26256025       HETLOSS  0.275073  False
# 4       1.0       1.0         40254480       DIPLOID  1.000000  False
#
#    gene_count  mutation_count   max_vaf  tp53_exp_nb_1  tp53_exp_nb_2  \
# 0           6               6  0.901899            NaN            NaN
# 1           1               1  0.148014            NaN            NaN
# 2           4               4  0.286364       0.790492            NaN
# 3          18              20  0.192475       1.059141            NaN
# 4          39              47  0.706897            NaN            NaN
#
#    tp53_exp_nb_3  tp53_exp_nb_4  tp53_exp_nb_5  tp53_res_1  tp53_res_2  \
# 0            NaN            NaN            NaN         NaN         NaN
# 1            NaN            NaN            NaN         NaN         NaN
# 2            NaN            NaN            NaN    1.209508         NaN
# 3            NaN            NaN            NaN   -0.059141         NaN
# 4            NaN            NaN            NaN         NaN         NaN
#
#    tp53_res_3  tp53_res_4  tp53_res_5 tp53_vc_group_1 tp53_vc_group_2  \
# 0         NaN         NaN         NaN            None            None
# 1         NaN         NaN         NaN            None            None
# 2         NaN         NaN         NaN         hotspot            None
# 3         NaN         NaN         NaN        missense            None
# 4         NaN         NaN         NaN            None            None
#
#   tp53_vc_group_3 tp53_vc_group_4 tp53_vc_group_5 tp53_first_group  \
# 0            None            None            None        WILD_TYPE
# 1            None            None            None        WILD_TYPE
# 2            None            None            None        WILD_TYPE
# 3            None            None            None             LOSS
# 4            None            None            None        WILD_TYPE
#
#     tp53_group tp53_res_group  loh_status  chr_affected  chr_loss  chr_gain  \
# 0         None           None       False           3.0       2.0       2.0
# 1         None           None       False           4.0       4.0       0.0
# 2  1_WILD_TYPE       tp53_res       False           4.0       0.0       4.0
# 3     >=1_LOSS    no_tp53_res       False          12.0      11.0       3.0
# 4         None           None       False           5.0       4.0       1.0
#
#    chr_cnloh  frac_genome_altered
# 0        0.0                0.080
# 1        0.0                0.137
# 2        0.0                0.138
# 3        0.0                0.444
# 4        0.0                0.173

# %%
# Let's see the distribution of tp53_groups
get_groupby(master_no_wgd, 'tp53_group', 'count').sort_values(by='count', ascending=False)
# Out:
#              count
# tp53_group
# >=1_LOSS      3841
# 0_HETLOSS     2641
# 1_WILD_TYPE   1548
# >=1_cnLOH      780
# >1muts         517
# HOMDEL         289

# %%
get_groupby(master_no_wgd[master_no_wgd.tp53_group.isna()], 'tp53_cn_state', 'count').sort_values(by='count', ascending=False)
# Out:
#                 count
# tp53_cn_state
# DIPLOID          8447
# GAIN              353
# CNLOH             152
# CNLOH & GAIN       57
# TETRAPLOID         50
# AMP                25
# AMP (BALANCED)      5
# AMP (LOH)           1

# %% [markdown]
# # Master CutOff
# We have to cutoff the master in order to clean subgroups:
# * 1_WILD_TYPE has a low purity distribution so we have to put a threshold
# * We need to clesan 1_WILD_TYPE to be sure that there are TP53 residuals

# %%
# The following function allows to filter the non_WGD cohort, the 1_WT subgroup
def non_wgd_load_and_cut(path):
    master_no_wgd = pd.read_pickle(path)
    master_cutoff = master_no_wgd
    master_cutoff.drop(master_cutoff[master_cutoff['tp53_group'] == '1_WILD_TYPE'][master_cutoff['purity'] <= 0.3][master_cutoff['tp53_vaf_1'] <= 0.15].index , inplace=True)
    master_cutoff.drop(master_cutoff[master_cutoff['tp53_group']=='1_WILD_TYPE'][master_cutoff['tp53_cn_state']=='DIPLOID'][master_cutoff['tp53_vaf_1']>0.6].index, inplace=True)
    master_cutoff.drop(master_cutoff[master_cutoff['tp53_group']=='1_WILD_TYPE'][master_cutoff['tp53_res_1']<0.5].index, inplace=True)

    return master_cutoff

# %%
master = non_wgd_load_and_cut(data_path + 'impact-facets-tp53/processed/no_wgd/master_no_wgd.pkl')

# %% [markdown]
# Let's have a look at our subgroups now:

# %%
get_groupby(master, 'tp53_group', 'count').sort_values(by='count', ascending=False)
# Out:
#              count
# tp53_group
# >=1_LOSS      3841
# 0_HETLOSS     2641
# >=1_cnLOH      780
# 1_WILD_TYPE    688
# >1muts         517
# HOMDEL         289

# %% [markdown]
# # Plot mutations LOH

# %%
# First we need to groupby our cohort_wgd file to have the size of the different groups
loh_tp53count = pd.DataFrame(master[['tp53_count', 'loh_status']].groupby(['tp53_count', 'loh_status']).size()).unstack()
loh_tp53count = loh_tp53count.fillna(0)
loh_tp53count.columns=['NO LOH', 'LOH']
loh_tp53count.loc['>=2'] = [loh_tp53count['NO LOH'][2:].sum(),loh_tp53count['LOH'][2:].sum()]
loh_tp53count = loh_tp53count.drop([2,3,4,5],axis=0)
display(loh_tp53count)

sns.set_style("whitegrid", {'grid.color': '1.'})
fig = plt.figure(figsize=(11,5))
ax = plt.subplot2grid(shape=(1,1), loc=(0,0), colspan=1)
h = loh_tp53count.plot(kind = 'bar', stacked=True, ax=ax)
ax.set_xticklabels(['0', '1','>=2'], rotation=0)
ax.legend(['NO LOH', 'LOH'], fontsize=14)
ax.set_title('# of TP53 muts in non WGD cohort - colorcoded by LOH state',weight='bold', fontsize=20)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
# Out:
#              NO LOH    LOH
# tp53_count
# 0           11657.0  164.0
# 1            4533.0  799.0
# >=2           666.0   27.0
