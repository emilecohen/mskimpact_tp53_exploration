# %% [markdown]
# # <span style='font-family:"Times New Roman"'> <span styel=''>**PLAYGROUND**
# *Emile Cohen*
#
#  *February 2020*

# %%
# %run -i '../../utils/setup_environment.ipy'

import warnings
warnings.filterwarnings('ignore')

data_path = '../../data/'
# Out:
# Setup environment... done!
# <span style="color:green">✅ Working on **mskimpact_env** conda environment.</span>

# %%
gene_level = pd.read_csv(data_path + 'impact-facets-tp53/raw/default_qc_pass.gene_level_TP53.txt', sep='\t')
arm_level = pd.read_csv(data_path + 'impact-facets-tp53/raw/default_qc_pass.arm_level.txt', sep='\t')
cohort = pd.read_csv(data_path + 'impact-facets-tp53/raw/default_qc_pass.cohort.txt', sep='\t')
tp53 = pd.read_csv(data_path + 'impact-facets-tp53/raw/default_qc_pass.ccf_TP53.maf', sep='\t')

# %%
# Create a Patient_Id
gene_level['Patient_Id'] = gene_level['sample'].str[:9]
arm_level['Patient_Id'] = arm_level['sample'].str[:9]
cohort['Patient_Id'] = cohort['sample_id'].str[:9]
tp53['Patient_Id'] = tp53['Tumor_Sample_Barcode'].str[:9]

# %%
# In this cell we compare the different files in term of number of patients
arm_patients = set(arm_level['Patient_Id'])
gene_patients = set(gene_level['Patient_Id'])
tp53_patients = set(tp53['Patient_Id'])
cohort_patients = set(cohort['Patient_Id'])

print('Total cohort size: ' + str(len(set(cohort['sample_id'])))+' samples / ' +  str(len(cohort_patients))+' patients')
print('Tp53 mutated subcohort size: ' + str(len(set(tp53['Tumor_Sample_Barcode'])))+' samples / ' + str(len(tp53_patients))+' patients')


print('\n\n* Patients in arm_level but not in gene_level:\n' + str(arm_patients - gene_patients))
print('\n* Patients in tp53 but not in arm_level:\n'+str(tp53_patients - arm_patients))
print('\n* Patients in tp53 but not in gene_level:\n'+str(tp53_patients - gene_patients))
print('\n* Patients in cohort but not in gene_level:\n'+str(len(cohort_patients - gene_patients)) + ' patients out of 27 021')
print('\n* Patients in cohort but not in arm_level:\n'+str(len(cohort_patients - arm_patients)) + ' patients out of 27 021')
# Out:
# Total cohort size: 29304 samples / 27021 patients
# Tp53 mutated subcohort size: 12731 samples / 11982 patients
#
#
# * Patients in arm_level but not in gene_level:
# {'P-0043334', 'P-0043486', 'P-0000308', 'P-0043373', 'P-0000206', 'P-0000273', 'P-0007206'}
#
# * Patients in tp53 but not in arm_level:
# set()
#
# * Patients in tp53 but not in gene_level:
# {'P-0043373', 'P-0043334'}
#
# * Patients in cohort but not in gene_level:
# 446 patients out of 27 021
#
# * Patients in cohort but not in arm_level:
# 439 patients out of 27 021

# %%
no_mut_info = {'P-0039198', 'P-0040035', 'P-0001612', 'P-0022915', 'P-0013827', 'P-0003228', 'P-0005453', 'P-0037125', 'P-0042811', 'P-0023426', 'P-0017885', 'P-0019431', 'P-0049616', 'P-0005684', 'P-0043507', 'P-0002748', 'P-0014469', 'P-0003729', 'P-0024195', 'P-0047393', 'P-0002301', 'P-0022371', 'P-0020911', 'P-0029847', 'P-0018724', 'P-0026356',
'P-0047440', 'P-0020195', 'P-0048332', 'P-0033040', 'P-0000640', 'P-0017061', 'P-0024662', 'P-0036395', 'P-0006185', 'P-0042229', 'P-0008192', 'P-0037684', 'P-0047303', 'P-0007011', 'P-0036217', 'P-0021344', 'P-0026497', 'P-0012190', 'P-0012388', 'P-0048873', 'P-0006427', 'P-0015999', 'P-0002370', 'P-0021759', 'P-0030239', 'P-0005983', 'P-0031797', 'P-0045183', 'P-0022523', 'P-0016274', 'P-0025884', 'P-0015982', 'P-0014773', 'P-0040091', 'P-0037586', 'P-0044928', 'P-0030613', 'P-0027769', 'P-0006536', 'P-0031313', 'P-0048663', 'P-0047437', 'P-0043486', 'P-0020292', 'P-0011375', 'P-0031706', 'P-0006991', 'P-0015336', 'P-0011292', 'P-0042406', 'P-0019990', 'P-0032909', 'P-0020089', 'P-0044485', 'P-0019237', 'P-0019408', 'P-0027222', 'P-0037540', 'P-0003622', 'P-0050070', 'P-0005840', 'P-0040950', 'P-0031631', 'P-0023095', 'P-0039701', 'P-0028602', 'P-0028991', 'P-0000857', 'P-0037109', 'P-0014915', 'P-0007395', 'P-0002807', 'P-0045311', 'P-0041267', 'P-0005595', 'P-0017657', 'P-0039879', 'P-0007644', 'P-0038212', 'P-0039207', 'P-0008432', 'P-0002919', 'P-0028386', 'P-0005077', 'P-0031652', 'P-0017968', 'P-0019115', 'P-0014163', 'P-0002889', 'P-0041237', 'P-0014850', 'P-0038034', 'P-0001838', 'P-0002082', 'P-0014316', 'P-0000915', 'P-0040922', 'P-0046885', 'P-0031796', 'P-0002772', 'P-0001436', 'P-0001854', 'P-0000153', 'P-0028355', 'P-0002822', 'P-0048654', 'P-0036776', 'P-0017423', 'P-0029655', 'P-0022647', 'P-0002121', 'P-0011006', 'P-0014568', 'P-0047136', 'P-0001355', 'P-0006917', 'P-0047968', 'P-0010127', 'P-0022045', 'P-0015453', 'P-0010408', 'P-0013914', 'P-0008298', 'P-0018319', 'P-0003263', 'P-0019074', 'P-0020563', 'P-0005515', 'P-0033148', 'P-0018993', 'P-0016559', 'P-0013444', 'P-0011576', 'P-0017269', 'P-0001378', 'P-0005746', 'P-0027573', 'P-0023842', 'P-0017306', 'P-0010780', 'P-0047462', 'P-0001816', 'P-0029626', 'P-0000585', 'P-0003355'}
print(len(no_mut_info - tp53_patients))
# Out:
# 922

# %%
# Adding a tp53_mutated column to gene_level to know if the patient has a mutation
gene_level['mutated_tp53'] = gene_level.Patient_Id.apply(lambda x: 1 if x in tp53_patients else 0)

# %%
cohort.head(3)
# Out:
#                              sample_id  \
# 0  P-0034223-T01-IM6_P-0034223-N01-IM6
# 1  P-0009819-T01-IM5_P-0009819-N01-IM5
# 2  P-0025956-T01-IM6_P-0025956-N01-IM6
#
#                                                                                sample_path  \
# 0  /juno/work/ccs/resources/impact/facets/all/P-00342/P-0034223-T01-IM6_P-0034223-N01-IM6/
# 1  /juno/work/ccs/resources/impact/facets/all/P-00098/P-0009819-T01-IM5_P-0009819-N01-IM5/
# 2  /juno/work/ccs/resources/impact/facets/all/P-00259/P-0025956-T01-IM6_P-0025956-N01-IM6/
#
#                        tumor_sample_id  \
# 0  P-0034223-T01-IM6_P-0034223-N01-IM6
# 1  P-0009819-T01-IM5_P-0009819-N01-IM5
# 2  P-0025956-T01-IM6_P-0025956-N01-IM6
#
#                                                                                       path  \
# 0  /juno/work/ccs/resources/impact/facets/all/P-00342/P-0034223-T01-IM6_P-0034223-N01-IM6/
# 1  /juno/work/ccs/resources/impact/facets/all/P-00098/P-0009819-T01-IM5_P-0009819-N01-IM5/
# ...

# %%
#arm_level[arm_level['Patient_Id'] =='P-0005425']

# %%
#arm_level[arm_level['Patient_Id'] =='P-0017322']

# %%
h = arm_level[arm_level['cn_state'] == 'TETRAPLOID']#[arm_level['lcn'] == 0]
h#[h['tcn']=='5']
# Out:
#                                       sample  arm  tcn  lcn  cn_length  \
# 205      P-0036909-T01-IM6_P-0036909-N01-IM6   5p    4    2   46187138
# 206      P-0036909-T01-IM6_P-0036909-N01-IM6   5q    4    2  134316509
# 209      P-0036909-T01-IM6_P-0036909-N01-IM6   7p    4    2   54681931
# 213      P-0036909-T01-IM6_P-0036909-N01-IM6  10p    4    2   37744888
# 222      P-0036909-T01-IM6_P-0036909-N01-IM6  17q    4    2   58520144
# ...                                      ...  ...  ...  ...        ...
# 1054187  P-0050223-T02-IM6_P-0050223-N02-IM6  20q    4    2   36553581
# 1054188  P-0050223-T02-IM6_P-0050223-N02-IM6  21q    4    2   34964871
# 1054189  P-0050223-T02-IM6_P-0050223-N02-IM6  22q    4    2   34009600
# 1054190  P-0050223-T02-IM6_P-0050223-N02-IM6  23p    4    2   58180912
# 1054191  P-0050223-T02-IM6_P-0050223-N02-IM6  23q    4    2   94232438
#
#          arm_length  frac_of_arm    cn_state Patient_Id
# 205        46187138         1.00  TETRAPLOID  P-0036909
# ...

# %%
h = gene_level[gene_level['cn_state'] == 'INDETERMINATE']#[gene_level['tcn'] == 8]
h#[h['tcn']=='5']
# Out:
#                                     sample  gene  chrom  gene_start  gene_end  \
# 3      P-0006554-T01-IM5_P-0006554-N01-IM5  TP53     17     7565097   7590868
# 14     P-0018241-T01-IM6_P-0018241-N01-IM6  TP53     17     7565097   7590868
# 26     P-0028849-T02-IM6_P-0028849-N01-IM6  TP53     17     7565097   7590868
# 27     P-0025071-T02-IM6_P-0025071-N01-IM6  TP53     17     7565097   7590868
# 67     P-0023318-T01-IM6_P-0023318-N01-IM6  TP53     17     7565097   7590868
# ...                                    ...   ...    ...         ...       ...
# 28723  P-0050621-T01-IM6_P-0050621-N01-IM6  TP53     17     7565097   7590868
# 28738  P-0050666-T01-IM6_P-0050666-N01-IM6  TP53     17     7565097   7590868
# 28757  P-0050746-T01-IM6_P-0050746-N01-IM6  TP53     17     7565097   7590868
# 28775  P-0050661-T01-IM6_P-0050661-N01-IM6  TP53     17     7565097   7590868
# 28776  P-0050654-T01-IM6_P-0050654-N01-IM6  TP53     17     7565097   7590868
#
# ...

# %%
gene_level[['Patient_Id','cn_state']].groupby(['cn_state']).size()
# Out:
# cn_state
# AMP                       44
# AMP (BALANCED)            30
# AMP (LOH)                 13
# CNLOH                    993
# CNLOH & GAIN              76
# CNLOH AFTER               81
# CNLOH BEFORE             193
# CNLOH BEFORE & GAIN       28
# CNLOH BEFORE & LOSS     1054
# DIPLOID                10551
# DOUBLE LOSS AFTER        551
# GAIN                     544
# HETLOSS                 6575
# HOMDEL                   296
# INDETERMINATE           2015
# LOSS & GAIN               19
# LOSS AFTER              1015
# LOSS BEFORE             3900
# LOSS BEFORE & AFTER      346
# TETRAPLOID               462
# dtype: int64

# %%
gene_level
# Out:
#                                     sample  gene  chrom  gene_start  gene_end  \
# 0      P-0034223-T01-IM6_P-0034223-N01-IM6  TP53     17     7565097   7590868
# 1      P-0009819-T01-IM5_P-0009819-N01-IM5  TP53     17     7565097   7590868
# 2      P-0027408-T01-IM6_P-0027408-N01-IM6  TP53     17     7565097   7590868
# 3      P-0006554-T01-IM5_P-0006554-N01-IM5  TP53     17     7565097   7590868
# 4      P-0036980-T01-IM6_P-0036980-N01-IM6  TP53     17     7565097   7590868
# ...                                    ...   ...    ...         ...       ...
# 28781  P-0050644-T01-IM6_P-0050644-N01-IM6  TP53     17     7565097   7590868
# 28782  P-0050741-T01-IM6_P-0050741-N01-IM6  TP53     17     7565097   7590868
# 28783  P-0050747-T01-IM6_P-0050747-N01-IM6  TP53     17     7565097   7590868
# 28784  P-0050652-T01-IM6_P-0050652-N01-IM6  TP53     17     7565097   7590868
# 28785  P-0050745-T01-IM6_P-0050745-N01-IM6  TP53     17     7565097   7590868
#
# ...

# %%
set(gene_level['filter'])
# Out:
# {'PASS', 'RESCUE', 'unfocal_amp', 'unfocal_amp;subclonal_amp', 'unfocal_del'}

# %%
gene_level_filtered = gene_level[gene_level['Patient_Id'].isin(tp53_patients)]
gene_level_filtered[['Patient_Id','cn_state']].groupby(['cn_state']).size()
# Out:
# cn_state
# AMP                      12
# AMP (BALANCED)            4
# AMP (LOH)                12
# CNLOH                   803
# CNLOH & GAIN             61
# CNLOH AFTER              43
# CNLOH BEFORE            175
# CNLOH BEFORE & GAIN      26
# CNLOH BEFORE & LOSS     898
# DIPLOID                1829
# DOUBLE LOSS AFTER       152
# GAIN                     94
# HETLOSS                3780
# HOMDEL                   72
# INDETERMINATE          1223
# LOSS & GAIN              16
# LOSS AFTER              280
# LOSS BEFORE            3141
# LOSS BEFORE & AFTER     228
# TETRAPLOID               85
# dtype: int64

# %%
display(arm_level)
display(arm_level[['Patient_Id','cn_state']].groupby(['cn_state']).size())
# Out:
#                                       sample  arm  tcn  lcn  cn_length  \
# 0        P-0034223-T01-IM6_P-0034223-N01-IM6   1p    2    1  120534257
# 1        P-0034223-T01-IM6_P-0034223-N01-IM6   1q    4    1  101461100
# 2        P-0034223-T01-IM6_P-0034223-N01-IM6   2p    2    1   87764506
# 3        P-0034223-T01-IM6_P-0034223-N01-IM6   2q    2    1  150656179
# 4        P-0034223-T01-IM6_P-0034223-N01-IM6   3p    2    1   89055004
# ...                                      ...  ...  ...  ...        ...
# 1054392  P-0050745-T01-IM6_P-0050745-N01-IM6  20p    1    0   22619186
# 1054393  P-0050745-T01-IM6_P-0050745-N01-IM6  21q    2    1   34965021
# 1054394  P-0050745-T01-IM6_P-0050745-N01-IM6  22q    2    1   33089916
# 1054395  P-0050745-T01-IM6_P-0050745-N01-IM6  23p    1    0   58181062
# 1054396  P-0050745-T01-IM6_P-0050745-N01-IM6  23q    1    0   94232438
#
#          arm_length  frac_of_arm cn_state Patient_Id
# 0         120534257         1.00  DIPLOID  P-0034223
# ...

# %%
# Out:
# Index(['Hugo_Symbol', 'Entrez_Gene_Id', 'Center', 'NCBI_Build', 'Chromosome',
#        'Start_Position', 'End_Position', 'Strand', 'Variant_Classification',
#        'Variant_Type',
#        ...
#        'ccf_expected_copies_upper', 'ccf_expected_copies_prob95',
#        'ccf_expected_copies_prob90', 'facets_fit', 'facets_suite_qc',
#        'reviewer_set_purity', 'use_only_purity_run', 'use_edited_cncf',
#        'cncf_file_used', 'Patient_Id'],
#       dtype='object', length=168)

# %%
patients_false = list(set(arm_level[arm_level['cn_state'].str.startswith('FALSE')]['Patient_Id']))
patients_true = list(set(arm_level[arm_level['cn_state'].str.startswith('TRUE')]['Patient_Id']))

gene_level[gene_level['Patient_Id'].isin(patients_true)][['Patient_Id','cn_state']]
# Out:
#       Patient_Id             cn_state
# 18     P-0018837  CNLOH BEFORE & LOSS
# 45     P-0012448          LOSS BEFORE
# 73     P-0033313         CNLOH BEFORE
# 96     P-0034290               HOMDEL
# 114    P-0010338                 GAIN
# ...          ...                  ...
# 28655  P-0050486          LOSS BEFORE
# 28668  P-0050455  CNLOH BEFORE & LOSS
# 28683  P-0013150  CNLOH BEFORE & LOSS
# 28686  P-0000941          LOSS BEFORE
# 28765  P-0050749           LOSS AFTER
#
# [864 rows x 2 columns]

# %%
set(arm_level.cn_state)
# Out:
# {'AMP',
#  'AMP (BALANCED)',
#  'AMP (LOH)',
#  'CNLOH',
#  'CNLOH & GAIN',
#  'CNLOH AFTER',
#  'CNLOH BEFORE',
#  'CNLOH BEFORE & GAIN',
#  'CNLOH BEFORE & LOSS',
#  'DIPLOID',
#  'DOUBLE LOSS AFTER',
#  'FALSE:10:1',
#  'FALSE:10:11',
#  'FALSE:10:2',
#  'FALSE:10:9',
#  'FALSE:11:0',
#  'FALSE:11:1',
#  'FALSE:11:11',
#  'FALSE:12:1',
#  'FALSE:13:0',
#  'FALSE:13:12',
#  'FALSE:13:9',
#  'FALSE:14:14',
#  'FALSE:15:1',
#  'FALSE:16:11',
#  'FALSE:17:15',
#  'FALSE:18:14',
#  'FALSE:24:3',
#  'FALSE:25:20',
#  'FALSE:27:0',
#  'FALSE:29:23',
#  'FALSE:2:3',
#  'FALSE:42:30',
#  'FALSE:4:4',
#  'FALSE:5:4',
#  'FALSE:5:5',
#  'FALSE:6:4',
#  'FALSE:6:5',
#  'FALSE:72:60',
#  'FALSE:7:0',
#  'FALSE:7:1',
#  'FALSE:7:2',
#  'FALSE:7:3',
#  'FALSE:7:6',
#  'FALSE:8:0',
#  'FALSE:8:1',
#  'FALSE:8:2',
#  'FALSE:8:3',
#  'FALSE:8:7',
#  'FALSE:9:0',
#  'FALSE:9:1',
#  'FALSE:9:2',
#  'FALSE:9:3',
#  'FALSE:9:8',
#  'GAIN',
#  'HETLOSS',
#  'HOMDEL',
#  'LOSS & GAIN',
#  'LOSS AFTER',
# ...

# %%
arm_level[arm_level['cn_state'] == 'TRUE:10:1']
# Out:
#                                      sample  arm  tcn  lcn  cn_length  \
# 43203   P-0027111-T01-IM6_P-0027111-N01-IM6  12p   11    1   31563007
# 220426  P-0026359-T01-IM6_P-0026359-N01-IM6   1q   11    1  125135116
# 379517  P-0033764-T01-IM6_P-0033764-N01-IM6   5p   11    1   21470028
# 379553  P-0033764-T02-IM6_P-0033764-N01-IM6   5p   11    1   23086498
# 409665  P-0021700-T01-IM6_P-0021700-N01-IM6   8q   11    1   98085293
# 563250  P-0032796-T01-IM6_P-0032796-N01-IM6  12p   11    1   32017199
# 676183  P-0030810-T01-IM6_P-0030810-N01-IM6   8q   11    1   97536520
# 932728  P-0022170-T01-IM6_P-0022170-N01-IM6  12p   11    1   34462144
#
#         arm_length  frac_of_arm   cn_state Patient_Id
# 43203     31563007          1.0  TRUE:10:1  P-0027111
# 220426   125135116          1.0  TRUE:10:1  P-0026359
# 379517    21470028          1.0  TRUE:10:1  P-0033764
# 379553    23086498          1.0  TRUE:10:1  P-0033764
# 409665    98085293          1.0  TRUE:10:1  P-0021700
# ...

# %%
arm_level[arm_level['cn_state'] == 'FALSE:10:1']
# Out:
#                                      sample arm  tcn  lcn  cn_length  \
# 71585   P-0022199-T01-IM6_P-0022199-N01-IM6  8p   11    1   43273637
# 71586   P-0022199-T01-IM6_P-0022199-N01-IM6  8q   11    1  102347613
# 140934  P-0023460-T01-IM6_P-0023460-N01-IM6  6p   11    1   50971393
# 281930  P-0025404-T01-IM6_P-0025404-N01-IM6  6p   11    1   54242450
# 972537  P-0046601-T01-IM6_P-0046601-N01-IM6  8q   11    1   98085311
#
#         arm_length  frac_of_arm    cn_state Patient_Id
# 71585     43273637         1.00  FALSE:10:1  P-0022199
# 71586    102347613         1.00  FALSE:10:1  P-0022199
# 140934    55166159         0.92  FALSE:10:1  P-0023460
# 281930    58436766         0.93  FALSE:10:1  P-0025404
# 972537    98085311         1.00  FALSE:10:1  P-0046601

# %%
arm_level[arm_level['Patient_Id'] == 'P-0036909']
# Out:
#                                   sample  arm  tcn  lcn  cn_length  \
# 198  P-0036909-T01-IM6_P-0036909-N01-IM6   1q    3    1  125713866
# 199  P-0036909-T01-IM6_P-0036909-N01-IM6   2p    3    1   87764506
# 200  P-0036909-T01-IM6_P-0036909-N01-IM6   2q    3    1  150656187
# 201  P-0036909-T01-IM6_P-0036909-N01-IM6   3p    2    1   89054954
# 202  P-0036909-T01-IM6_P-0036909-N01-IM6   3q    2    1  106857923
# 203  P-0036909-T01-IM6_P-0036909-N01-IM6   4p    3    1   48257567
# 204  P-0036909-T01-IM6_P-0036909-N01-IM6   4q    3    1  140602433
# 205  P-0036909-T01-IM6_P-0036909-N01-IM6   5p    4    2   46187138
# 206  P-0036909-T01-IM6_P-0036909-N01-IM6   5q    4    2  134316509
# 207  P-0036909-T01-IM6_P-0036909-N01-IM6   6p    3    0   40918585
# 208  P-0036909-T01-IM6_P-0036909-N01-IM6   6q    2    0  111968817
# 209  P-0036909-T01-IM6_P-0036909-N01-IM6   7p    4    2   54681931
# 210  P-0036909-T01-IM6_P-0036909-N01-IM6   8p    1    0   42529591
# ...

# %%
arm_level['arm_key'] = pd.Series([i+'_'+j for i,j in zip(arm_level['sample'], arm_level.arm)])
h = arm_level.arm_key.duplicated()
# Out:
# []

# %%
cohort[cohort.tumor_sample_id.str[:17] == 'P-0027408-T01-IM6']
# Out:
#                              sample_id  \
# 3  P-0027408-T01-IM6_P-0027408-N01-IM6
#
#                                                                                sample_path  \
# 3  /juno/work/ccs/resources/impact/facets/all/P-00274/P-0027408-T01-IM6_P-0027408-N01-IM6/
#
#                        tumor_sample_id  \
# 3  P-0027408-T01-IM6_P-0027408-N01-IM6
#
#                                                                                       path  \
# 3  /juno/work/ccs/resources/impact/facets/all/P-00274/P-0027408-T01-IM6_P-0027408-N01-IM6/
#
#   fit_name purity_run_version  \
# 3  default             0.5.14
#
#                                                                                                                             purity_run_prefix  \
# 3  /juno/work/ccs/resources/impact/facets/all/P-00274/P-0027408-T01-IM6_P-0027408-N01-IM6//default/P-0027408-T01-IM6_P-0027408-N01-IM6_purity
#
#    purity_run_Seed  purity_run_cval  purity_run_nhet  purity_run_Purity  \
# ...

# %%
tp53#[tp53['tcn'] == 2][tp53['lcn'] == 1]
# Out:
#       Hugo_Symbol  Entrez_Gene_Id Center NCBI_Build  Chromosome  \
# 0            TP53            7157  MSKCC     GRCh37          17
# 1            TP53            7157  MSKCC     GRCh37          17
# 2            TP53            7157  MSKCC     GRCh37          17
# 3            TP53            7157  MSKCC     GRCh37          17
# 4            TP53            7157  MSKCC     GRCh37          17
# ...           ...             ...    ...        ...         ...
# 13882        TP53            7157  MSKCC     GRCh37          17
# 13883        TP53            7157  MSKCC     GRCh37          17
# 13884        TP53            7157  MSKCC     GRCh37          17
# 13885        TP53            7157  MSKCC     GRCh37          17
# 13886        TP53            7157  MSKCC     GRCh37          17
#
#        Start_Position  End_Position Strand Variant_Classification  \
# 0             7578409       7578410      +      Missense_Mutation
# ...

# %%
gene_level['cf.em'].isna().sum()
# Out:
# 1235

# %%
arm_level.describe()
# Out:
#                 tcn           lcn     cn_length    arm_length   frac_of_arm
# count  1.054397e+06  1.054397e+06  1.054397e+06  1.054397e+06  1.054397e+06
# mean   2.277556e+00  8.517304e-01  6.780569e+07  6.832681e+07  9.931666e-01
# std    1.009089e+00  5.631941e-01  3.526842e+07  3.556711e+07  2.859970e-02
# min    0.000000e+00  0.000000e+00  3.384000e+03  3.384000e+03  8.000000e-01
# 25%    2.000000e+00  1.000000e+00  3.631102e+07  3.631103e+07  1.000000e+00
# 50%    2.000000e+00  1.000000e+00  5.843689e+07  5.843697e+07  1.000000e+00
# 75%    3.000000e+00  1.000000e+00  9.423239e+07  9.423247e+07  1.000000e+00
# max    1.320000e+02  6.000000e+01  1.508278e+08  1.508278e+08  1.000000e+00

# %%
gene_level
# Out:
#                                     sample  gene  chrom  gene_start  gene_end  \
# 0      P-0034223-T01-IM6_P-0034223-N01-IM6  TP53     17     7565097   7590868
# 1      P-0009819-T01-IM5_P-0009819-N01-IM5  TP53     17     7565097   7590868
# 2      P-0027408-T01-IM6_P-0027408-N01-IM6  TP53     17     7565097   7590868
# 3      P-0006554-T01-IM5_P-0006554-N01-IM5  TP53     17     7565097   7590868
# 4      P-0036980-T01-IM6_P-0036980-N01-IM6  TP53     17     7565097   7590868
# ...                                    ...   ...    ...         ...       ...
# 28781  P-0050644-T01-IM6_P-0050644-N01-IM6  TP53     17     7565097   7590868
# 28782  P-0050741-T01-IM6_P-0050741-N01-IM6  TP53     17     7565097   7590868
# 28783  P-0050747-T01-IM6_P-0050747-N01-IM6  TP53     17     7565097   7590868
# 28784  P-0050652-T01-IM6_P-0050652-N01-IM6  TP53     17     7565097   7590868
# 28785  P-0050745-T01-IM6_P-0050745-N01-IM6  TP53     17     7565097   7590868
#
# ...

# %%
arm_level.duplicated(['sample', 'arm']).sum()
# Out:
# 0

# %%
gen = gene_level[['sample', 'cn_state']]
gen
# Out:
#                                     sample       cn_state
# 0      P-0034223-T01-IM6_P-0034223-N01-IM6        DIPLOID
# 1      P-0009819-T01-IM5_P-0009819-N01-IM5        HETLOSS
# 2      P-0027408-T01-IM6_P-0027408-N01-IM6        HETLOSS
# 3      P-0006554-T01-IM5_P-0006554-N01-IM5  INDETERMINATE
# 4      P-0036980-T01-IM6_P-0036980-N01-IM6        DIPLOID
# ...                                    ...            ...
# 28781  P-0050644-T01-IM6_P-0050644-N01-IM6        DIPLOID
# 28782  P-0050741-T01-IM6_P-0050741-N01-IM6        HETLOSS
# 28783  P-0050747-T01-IM6_P-0050747-N01-IM6        HETLOSS
# 28784  P-0050652-T01-IM6_P-0050652-N01-IM6        DIPLOID
# 28785  P-0050745-T01-IM6_P-0050745-N01-IM6        HETLOSS
#
# [28786 rows x 2 columns]

# %%
arm = arm_level[['sample', 'arm', 'cn_state']][arm_level['arm'].isin(['17p'])]

# %%
diff_gene_arm = []
for sample, cn_state in zip(list(gen['sample']),list(gen['cn_state'])):
    if cn_state not in list(arm[arm['sample'] == sample]['cn_state']):
        diff_gene_arm.append(sample)

# %%
len(diff_gene_arm)
# Out:
# 6865

# %%
gene_level[gene_level['sample'] == 'P-0009819-T01-IM5_P-0009819-N01-IM5'][['sample', 'gene', 'seg_length','cn_state']]
# Out:
#                                 sample  gene  seg_length cn_state
# 1  P-0009819-T01-IM5_P-0009819-N01-IM5  TP53  80668309.0  HETLOSS

# %%
arm_level = arm_level[arm_level['sample'] == 'P-0009819-T01-IM5_P-0009819-N01-IM5'][arm_level['arm'] == '17p']

arm_level
# Out:
#                                  sample  arm  tcn  lcn  cn_length  arm_length  \
# 67  P-0009819-T01-IM5_P-0009819-N01-IM5  17p    2    1   22148282    22148282
#
#     frac_of_arm cn_state
# 67          1.0  DIPLOID

# %%
arm_bis = arm_level[['sample', 'arm', 'cn_state']]
inconsistent = []
for sample in list(gen['sample']):
    if 'HETLOSS' in list(arm_bis[arm_bis['sample'] == sample]['cn_state']) and 'LOSS AFTER' in list(arm_bis[arm_bis['sample'] == sample]['cn_state']):
        inconsistent.append(sample)
        print(sample)

# %%
arm_bis[arm_bis['sample'] == 'P-0036909-T01-IM6_P-0036909-N01-IM6']#['cn_state']
# Out:
#                                   sample  arm             cn_state
# 198  P-0036909-T01-IM6_P-0036909-N01-IM6   1q           LOSS AFTER
# 199  P-0036909-T01-IM6_P-0036909-N01-IM6   2p           LOSS AFTER
# 200  P-0036909-T01-IM6_P-0036909-N01-IM6   2q           LOSS AFTER
# 201  P-0036909-T01-IM6_P-0036909-N01-IM6   3p    DOUBLE LOSS AFTER
# 202  P-0036909-T01-IM6_P-0036909-N01-IM6   3q    DOUBLE LOSS AFTER
# 203  P-0036909-T01-IM6_P-0036909-N01-IM6   4p           LOSS AFTER
# 204  P-0036909-T01-IM6_P-0036909-N01-IM6   4q           LOSS AFTER
# 205  P-0036909-T01-IM6_P-0036909-N01-IM6   5p           TETRAPLOID
# 206  P-0036909-T01-IM6_P-0036909-N01-IM6   5q           TETRAPLOID
# 207  P-0036909-T01-IM6_P-0036909-N01-IM6   6p  CNLOH BEFORE & LOSS
# 208  P-0036909-T01-IM6_P-0036909-N01-IM6   6q          LOSS BEFORE
# 209  P-0036909-T01-IM6_P-0036909-N01-IM6   7p           TETRAPLOID
# 210  P-0036909-T01-IM6_P-0036909-N01-IM6   8p  LOSS BEFORE & AFTER
# ...

# %%
arm_level[arm_level['sample'] == 'P-0050741-T01-IM6_P-0050741-N01-IM6']
# Out:
#                                       sample  arm  tcn  lcn  cn_length  \
# 1054270  P-0050741-T01-IM6_P-0050741-N01-IM6   1p    2    1  120534257
# 1054271  P-0050741-T01-IM6_P-0050741-N01-IM6   1q    2    1  125713766
# 1054272  P-0050741-T01-IM6_P-0050741-N01-IM6   2p    2    1   87764304
# 1054273  P-0050741-T01-IM6_P-0050741-N01-IM6   3p    1    0   76881121
# 1054274  P-0050741-T01-IM6_P-0050741-N01-IM6   3q    3    1  106857896
# 1054275  P-0050741-T01-IM6_P-0050741-N01-IM6   4p    2    1   48257537
# 1054276  P-0050741-T01-IM6_P-0050741-N01-IM6   4q    2    1  140602483
# 1054277  P-0050741-T01-IM6_P-0050741-N01-IM6   5p    2    1   46187291
# 1054278  P-0050741-T01-IM6_P-0050741-N01-IM6   5q    2    1  134122009
# 1054279  P-0050741-T01-IM6_P-0050741-N01-IM6   6p    2    1   58437159
# 1054280  P-0050741-T01-IM6_P-0050741-N01-IM6   6q    2    1  112040880
# 1054281  P-0050741-T01-IM6_P-0050741-N01-IM6   7p    2    1   57723509
# ...

# %%
arm_level[arm_level['sample'] == 'P-0004584-T01-IM5_P-0004584-N01-IM5']
# Out:
#                                    sample  arm  tcn  lcn  cn_length  \
# 3634  P-0004584-T01-IM5_P-0004584-N01-IM5   1p    2    1  119047281
# 3635  P-0004584-T01-IM5_P-0004584-N01-IM5   1q    2    1  124442466
# 3636  P-0004584-T01-IM5_P-0004584-N01-IM5   2p    2    1   87609082
# 3637  P-0004584-T01-IM5_P-0004584-N01-IM5   2q    2    1  150474821
# 3638  P-0004584-T01-IM5_P-0004584-N01-IM5   3p    2    1   89055013
# 3639  P-0004584-T01-IM5_P-0004584-N01-IM5   3q    2    1  106846296
# 3640  P-0004584-T01-IM5_P-0004584-N01-IM5   4p    2    1   48257537
# 3641  P-0004584-T01-IM5_P-0004584-N01-IM5   4q    2    1  140602483
# 3642  P-0004584-T01-IM5_P-0004584-N01-IM5   5p    2    1   46187180
# 3643  P-0004584-T01-IM5_P-0004584-N01-IM5   5q    2    1  134122009
# 3644  P-0004584-T01-IM5_P-0004584-N01-IM5   6p    2    1   58436991
# 3645  P-0004584-T01-IM5_P-0004584-N01-IM5   6q    2    1  111968834
# 3646  P-0004584-T01-IM5_P-0004584-N01-IM5   7p    3    1   52022531
# ...

# %%
arm_level['chr'] = arm_level.arm.str.extract('(\d+)')
arm_level['key'] = arm_level['sample'] + arm_level['chr'] + arm_level['cn_state']

# %%
dup= arm_level[arm_level.duplicated(['key'])]
dup
# Out:
#                                       sample  arm  tcn  lcn  cn_length  \
# 3        P-0034223-T01-IM6_P-0034223-N01-IM6   2q    2    1  150656179
# 5        P-0034223-T01-IM6_P-0034223-N01-IM6   3q    2    1  106857923
# 7        P-0034223-T01-IM6_P-0034223-N01-IM6   4q    2    1  140602481
# 9        P-0034223-T01-IM6_P-0034223-N01-IM6   5q    2    1  134121897
# 11       P-0034223-T01-IM6_P-0034223-N01-IM6   6q    2    1  111968888
# ...                                      ...  ...  ...  ...        ...
# 1054375  P-0050652-T01-IM6_P-0050652-N01-IM6  19q    2    1   34414606
# 1054377  P-0050652-T01-IM6_P-0050652-N01-IM6  20q    2    1   35957681
# 1054381  P-0050652-T01-IM6_P-0050652-N01-IM6  23q    1    0   94229551
# 1054391  P-0050745-T01-IM6_P-0050745-N01-IM6  18q    2    1   59002752
# 1054396  P-0050745-T01-IM6_P-0050745-N01-IM6  23q    1    0   94232438
#
#          arm_length  frac_of_arm cn_state chr  \
# 3         150656179          1.0  DIPLOID   2
# ...

# %%
dup[dup['chr'] == '17'][dup['cn_state'] == 'HETLOSS']
# Out:
#                                       sample  arm  tcn  lcn  cn_length  \
# 3662     P-0004584-T01-IM5_P-0004584-N01-IM5  17q    1    0   58520003
# 4121     P-0019265-T01-IM6_P-0019265-N01-IM6  17q    1    0   58520144
# 4533     P-0024097-T01-IM6_P-0024097-N01-IM6  17q    1    0   58544844
# 5241     P-0016019-T01-IM6_P-0016019-N01-IM6  17q    1    0   58520144
# 5418     P-0023315-T01-IM6_P-0023315-N01-IM6  17q    1    0   58520094
# ...                                      ...  ...  ...  ...        ...
# 1053176  P-0050667-T01-IM6_P-0050667-N01-IM6  17q    1    0   58520094
# 1053317  P-0050664-T01-IM6_P-0050664-N01-IM6  17q    1    0   58520211
# 1053535  P-0050655-T01-IM6_P-0050655-N01-IM6  17q    1    0   58520211
# 1053762  P-0050436-T01-IM6_P-0050436-N01-IM6  17q    1    0   58520018
# 1053952  P-0050651-T01-IM6_P-0050651-N01-IM6  17q    1    0   58520040
#
#          arm_length  frac_of_arm cn_state chr  \
# 3662       58520003          1.0  HETLOSS  17
# ...

# %%
set(gene_level.cn_state)
# Out:
# {'AMP',
#  'AMP (BALANCED)',
#  'AMP (LOH)',
#  'CNLOH',
#  'CNLOH & GAIN',
#  'CNLOH AFTER',
#  'CNLOH BEFORE',
#  'CNLOH BEFORE & GAIN',
#  'CNLOH BEFORE & LOSS',
#  'DIPLOID',
#  'DOUBLE LOSS AFTER',
#  'GAIN',
#  'HETLOSS',
#  'HOMDEL',
#  'INDETERMINATE',
#  'LOSS & GAIN',
#  'LOSS AFTER',
#  'LOSS BEFORE',
#  'LOSS BEFORE & AFTER',
#  'TETRAPLOID'}

# %%
# Out:
#                                       sample  arm  tcn  lcn  cn_length  \
# 0        P-0034223-T01-IM6_P-0034223-N01-IM6   1p    2    1  120534257
# 1        P-0034223-T01-IM6_P-0034223-N01-IM6   1q    4    1  101461100
# 2        P-0034223-T01-IM6_P-0034223-N01-IM6   2p    2    1   87764506
# 3        P-0034223-T01-IM6_P-0034223-N01-IM6   2q    2    1  150656179
# 4        P-0034223-T01-IM6_P-0034223-N01-IM6   3p    2    1   89055004
# ...                                      ...  ...  ...  ...        ...
# 1054392  P-0050745-T01-IM6_P-0050745-N01-IM6  20p    1    0   22619186
# 1054393  P-0050745-T01-IM6_P-0050745-N01-IM6  21q    2    1   34965021
# 1054394  P-0050745-T01-IM6_P-0050745-N01-IM6  22q    2    1   33089916
# 1054395  P-0050745-T01-IM6_P-0050745-N01-IM6  23p    1    0   58181062
# 1054396  P-0050745-T01-IM6_P-0050745-N01-IM6  23q    1    0   94232438
#
#          arm_length  frac_of_arm cn_state chr  \
# 0         120534257         1.00  DIPLOID   1
# ...

# %%
h = arm_level.groupby(['sample', 'cn_state']).count()

# %%
[(sample, cn_state) for (sample, cn_state) in list(h.index)]
# Out:
# [('P-0000004-T01-IM3_P-0000004-N01-IM3', 'AMP'),
#  ('P-0000004-T01-IM3_P-0000004-N01-IM3', 'AMP (BALANCED)'),
#  ('P-0000004-T01-IM3_P-0000004-N01-IM3', 'CNLOH AFTER'),
#  ('P-0000004-T01-IM3_P-0000004-N01-IM3', 'CNLOH BEFORE & LOSS'),
#  ('P-0000004-T01-IM3_P-0000004-N01-IM3', 'DOUBLE LOSS AFTER'),
#  ('P-0000004-T01-IM3_P-0000004-N01-IM3', 'GAIN'),
#  ('P-0000004-T01-IM3_P-0000004-N01-IM3', 'LOSS AFTER'),
#  ('P-0000004-T01-IM3_P-0000004-N01-IM3', 'LOSS BEFORE'),
#  ('P-0000004-T01-IM3_P-0000004-N01-IM3', 'LOSS BEFORE & AFTER'),
#  ('P-0000004-T01-IM3_P-0000004-N01-IM3', 'TETRAPLOID'),
#  ('P-0000012-T02-IM3_P-0000012-N01-IM3', 'CNLOH AFTER'),
#  ('P-0000012-T02-IM3_P-0000012-N01-IM3', 'CNLOH BEFORE & LOSS'),
#  ('P-0000012-T02-IM3_P-0000012-N01-IM3', 'DOUBLE LOSS AFTER'),
#  ('P-0000012-T02-IM3_P-0000012-N01-IM3', 'LOSS & GAIN'),
#  ('P-0000012-T02-IM3_P-0000012-N01-IM3', 'LOSS AFTER'),
#  ('P-0000012-T02-IM3_P-0000012-N01-IM3', 'LOSS BEFORE'),
# ...

# %%
from tqdm import tqdm
from multiprocessing import Pool

L = []
#for sample in tqdm([sample for (sample, cn_state) in list(h.index)]):
def print_sample(sample):
    for cn_state_1 in ['DIPLOID', 'HETLOSS', 'CNLOH']:
        for cn_state_2 in ['CNLOH BEFORE & GAIN','CNLOH AFTER', 'LOSS AFTER', 'LOSS BEFORE & AFTER']:
            if (sample, cn_state_1) in list(h.index) and (sample, cn_state_2) in list(h.index):
                L.append(sample)
                
pool = Pool()  # Create a multiprocessing Pool
for _ in tqdm(pool.imap_unordered(print_sample, [sample for (sample, cn_state) in list(h.index)]), total=len(list(h.index))):
    pass
# Out:
#   0%|          | 0/134585 [00:00<?, ?it/s]
#
#
#   0%|          | 295/134585 [01:30<9:20:38,  3.99it/s]
#
#
#
#   0%|          | 1/134585 [00:02<88:59:42,  2.38s/it]
#
#
#
#   0%|          | 13/134585 [00:17<76:03:00,  2.03s/it]
#
#
#
#   0%|          | 59/134585 [00:17<53:21:04,  1.43s/it]
#
#
#
#   0%|          | 62/134585 [00:18<41:35:58,  1.11s/it]
#
#
#
#   0%|          | 65/134585 [00:19<29:58:17,  1.25it/s]
#
#
#
#   0%|          | 67/134585 [00:20<29:46:04,  1.26it/s]
#
#
#
#   0%|          | 69/134585 [00:20<22:18:40,  1.67it/s]
#
#
#
#   0%|          | 72/134585 [00:21<16:20:42,  2.29it/s]
#
#
#
#   0%|          | 74/134585 [00:21<15:12:54,  2.46it/s]
#
#
#
#   0%|          | 76/134585 [00:21<11:12:55,  3.33it/s]
#
#
#
#   0%|          | 78/134585 [00:22<10:40:15,  3.50it/s]
#
#
#
#   0%|          | 79/134585 [00:23<20:56:23,  1.78it/s]
#
#
#
#   0%|          | 80/134585 [00:23<16:52:07,  2.21it/s]
#
#
#
#   0%|          | 81/134585 [00:23<12:56:53,  2.89it/s]
#
#
#
# ...

# %%
list(set(arm_level[arm_level['cn_state'] == 'TETRAPLOID']['sample']))
# Out:
# ['P-0000416-T02-IM3_P-0000416-N01-IM3',
#  'P-0025664-T01-IM6_P-0025664-N01-IM6',
#  'P-0017292-T01-IM6_P-0017292-N01-IM6',
#  'P-0009076-T04-IM6_P-0009076-N01-IM6',
#  'P-0014009-T01-IM5_P-0014009-N01-IM5',
#  'P-0006808-T01-IM5_P-0006808-N01-IM5',
#  'P-0000859-T01-IM3_P-0000859-N01-IM3',
#  'P-0001755-T01-IM3_P-0001755-N01-IM3',
#  'P-0032377-T01-IM6_P-0032377-N01-IM6',
#  'P-0039268-T01-IM6_P-0039268-N01-IM6',
#  'P-0001484-T01-IM3_P-0001484-N01-IM3',
#  'P-0014990-T01-IM6_P-0014990-N01-IM6',
#  'P-0010162-T01-IM5_P-0010162-N01-IM5',
#  'P-0042882-T01-IM6_P-0042882-N01-IM6',
#  'P-0004248-T02-IM5_P-0004248-N01-IM5',
#  'P-0002179-T01-IM3_P-0002179-N01-IM3',
#  'P-0015477-T01-IM6_P-0015477-N01-IM6',
#  'P-0010172-T01-IM5_P-0010172-N01-IM5',
#  'P-0002915-T01-IM3_P-0002915-N01-IM3',
#  'P-0021905-T02-IM6_P-0021905-N01-IM6',
#  'P-0003754-T01-IM5_P-0003754-N01-IM5',
#  'P-0050393-T01-IM6_P-0050393-N01-IM6',
#  'P-0041418-T01-IM6_P-0041418-N01-IM6',
# ...

# %%
for sample in a:
    if 'DIPLOID' in list(arm_level[arm_level['sample'] == a]['cn_state']):
        print(sample)

# %%
arm_level[arm_level['sample'] == 'P-0042107-T01-IM6_P-0042107-N01-IM6']['cn_state']
# Out:
# 865076      CNLOH BEFORE
# 865077       LOSS BEFORE
# 865078       LOSS BEFORE
# 865079       LOSS BEFORE
# 865080       LOSS BEFORE
# 865081        TETRAPLOID
# 865082        TETRAPLOID
# 865083    AMP (BALANCED)
# 865084         AMP (LOH)
# 865085       LOSS BEFORE
# 865086        TETRAPLOID
# 865087        TETRAPLOID
# 865088       LOSS BEFORE
# 865089       LOSS BEFORE
# 865090        LOSS AFTER
# 865091        LOSS AFTER
# 865092       LOSS BEFORE
# 865093       LOSS BEFORE
# 865094       LOSS BEFORE
# 865095       LOSS BEFORE
# 865096        TETRAPLOID
# 865097        TETRAPLOID
# 865098       LOSS BEFORE
# 865099        TETRAPLOID
# 865100       LOSS BEFORE
# 865101       LOSS BEFORE
# 865102       LOSS BEFORE
# 865103        TETRAPLOID
# 865104        TETRAPLOID
# 865105        TETRAPLOID
# 865106        TETRAPLOID
# 865107        TETRAPLOID
# 865108        TETRAPLOID
# 865109        TETRAPLOID
# 865110      CNLOH BEFORE
# 865111       LOSS BEFORE
# ...

# %%
gene_level
# Out:
#                                     sample  gene  chrom  gene_start  gene_end  \
# 0      P-0034223-T01-IM6_P-0034223-N01-IM6  TP53     17     7565097   7590868
# 1      P-0009819-T01-IM5_P-0009819-N01-IM5  TP53     17     7565097   7590868
# 2      P-0027408-T01-IM6_P-0027408-N01-IM6  TP53     17     7565097   7590868
# 3      P-0006554-T01-IM5_P-0006554-N01-IM5  TP53     17     7565097   7590868
# 4      P-0036980-T01-IM6_P-0036980-N01-IM6  TP53     17     7565097   7590868
# ...                                    ...   ...    ...         ...       ...
# 28781  P-0050644-T01-IM6_P-0050644-N01-IM6  TP53     17     7565097   7590868
# 28782  P-0050741-T01-IM6_P-0050741-N01-IM6  TP53     17     7565097   7590868
# 28783  P-0050747-T01-IM6_P-0050747-N01-IM6  TP53     17     7565097   7590868
# 28784  P-0050652-T01-IM6_P-0050652-N01-IM6  TP53     17     7565097   7590868
# 28785  P-0050745-T01-IM6_P-0050745-N01-IM6  TP53     17     7565097   7590868
#
# ...

# %%
from tqdm import tqdm
copy_number_state =  pd.read_pickle(data_path + 'merged_data/copy_number.pkl')

samples_wgd = list(set(copy_number_state[copy_number_state['wgd']==1]['Sample_Id']))

inconsistencies = []
for sample in tqdm(samples_wgd):
    lookup_table = arm_level[arm_level['sample'] == sample]
    if 'DIPLOID' in list(lookup_table['cn_state']):
        inconsistencies.append(sample)
# Out:
# 100%|██████████| 9286/9286 [07:55<00:00, 19.54it/s]

# %%
inconsistencies
# Out:
# []

# %%
float(copy_number_state[copy_number_state['Sample_Id'] == 'P-0008398-T05-IM6_P-0008398-N01-IM6']['wgd']) == 1
# Out:
# False

# %%
h = arm_level[arm_level['sample'] == 'P-0032161-T02-IM6_P-0032161-N01-IM6']
h1 = 101461100 + 33258581 + 31302129 + 54904790
h_tot = h.arm_length.sum()
h1/h_tot
# Out:
# 0.08127826148252341

# %%
h
# Out:
#                                   sample  arm  tcn  lcn  cn_length  \
# 747  P-0032161-T02-IM6_P-0032161-N01-IM6   1p    2    1  120534257
# 748  P-0032161-T02-IM6_P-0032161-N01-IM6   1q    2    1  125135066
# 749  P-0032161-T02-IM6_P-0032161-N01-IM6   2p    2    1   87764304
# 750  P-0032161-T02-IM6_P-0032161-N01-IM6   2q    2    1  150656153
# 751  P-0032161-T02-IM6_P-0032161-N01-IM6   3q    2    1  106857330
# 752  P-0032161-T02-IM6_P-0032161-N01-IM6   4p    2    1   48257467
# 753  P-0032161-T02-IM6_P-0032161-N01-IM6   4q    2    1  140602433
# 754  P-0032161-T02-IM6_P-0032161-N01-IM6   5p    2    1   46375261
# 755  P-0032161-T02-IM6_P-0032161-N01-IM6   5q    2    1  134121988
# 756  P-0032161-T02-IM6_P-0032161-N01-IM6   6p    2    1   58436804
# 757  P-0032161-T02-IM6_P-0032161-N01-IM6   6q    2    1  111968817
# 758  P-0032161-T02-IM6_P-0032161-N01-IM6   7p    2    1   56783431
# 759  P-0032161-T02-IM6_P-0032161-N01-IM6   7q    2    1  100396824
# ...
