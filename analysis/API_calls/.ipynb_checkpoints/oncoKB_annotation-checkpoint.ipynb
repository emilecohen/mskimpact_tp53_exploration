# %% [markdown]
# # <span style='font-family:"Times New Roman"'> <span styel=''> **OncoKB Annotation**
#
# ## <span style='font-family:"Times New Roman"'> <span styel=''> *Emile Cohen*
# *March 2020*

# %% [markdown]
# **Goal:** In this notebook, we call the OncoKB API to get the annotation at variant level for MSK-Impact cohort.
#
# ---

# %%
# %run -i '../../utils/setup_environment.ipy'

import warnings
import requests
import click
import os
import json
import time
warnings.filterwarnings('ignore')

data_path = '../../data/'
# Out:
# Setup environment... done!
# <span style="color:green">✅ Working on **mskimpact_env** conda environment.</span>

# %% [markdown]
# ---
# For that we need a token to access the API, that could be found after logging in in OncoKB (https://www.oncokb.org/dataAccess) in *Account Settings*.
#
# My Token is : **f08eeec6-fe2e-4414-9352-df71e2c1db32**
#
# ---

# %%
def retry_request(method, **kwargs):
    """Retry request operation multiple times."""
    url = kwargs.get('url') or ""
    click.secho(f"Querying to {url}", fg="green")
    for i in [0.2, 1, 5, 10, 60, 90, 120, 300]:  # attempt some retries
        try:
            error = None
            response = getattr(requests, method)(verify=False, **kwargs)
        except requests.exceptions.RequestException as request_error:  # pragma: no cover
            error = request_error
            response = None
        if response is not None and not str(response.status_code).startswith("50"):
            break
        else:  # pragma: no cover
            msg = f"Request to {url} failed with error: {error}, retrying in {i}s..."
            click.secho(msg, fg="yellow", err=True)
            time.sleep(i)
    return response


ONCOKB_ENDPOINTS = {
    "api_info": "https://www.oncokb.org/api/v1/info",
    "cancer_genes": "https://www.oncokb.org/api/v1/utils/cancerGeneList",
    "annotate": "https://www.oncokb.org/api/v1/annotate/mutations/byGenomicChange",
}


def oncokb_query(endpoint, method="get", data=None):
    """Make authenticated calls to newest oncokb api to gen cancer genes."""
    oncokb_token = "f08eeec6-fe2e-4414-9352-df71e2c1db32"
    if not oncokb_token:
        raise click.UsageError(
            "oncoKb authentication token is missing. "
            "Add it as enviromental variable:"
            "\n\texport ONCOKB_TOKEN=<your-oncokb-token>"
            "\nOr add them to a .env file."
        )
    headers = {
        "Authorization": f"Bearer {oncokb_token}",
        "Content-Type": "application/json",
    }
    response = retry_request(method, url=endpoint, headers=headers, data=data)
    if not response.ok:
        raise click.UsageError(f"OncoKb query failed. Reason: {response.reason}")
    return json.loads(response.content)


def get_oncokb_treatments(df, genomic_cols, tumor_type):
    """Return df with extra columns for Drug and Evidence Level."""
    chrom_col, start_col, end_col, ref_col, alt_col = genomic_cols
    genomic_changes = [
        [v[chrom_col], v[start_col], v[end_col], v[ref_col], v[alt_col]]
        for v in df.T.to_dict().values()
    ]
    data = [
        {
            "genomicLocation": ",".join(map(str, i)),
            "tumorType": tumor_type,
            "id": "",
            "evidenceTypes": [],
        }
        for i in genomic_changes
    ]
    annotated_variants = oncokb_query(
        ONCOKB_ENDPOINTS["annotate"], method="post", data=json.dumps(data)
    )
    return annotated_variants


def annotate_variants(df): 
    data = [
    {
      "genomicLocation": "{},{},{},{},{}".format(
        v["Chromosome"], int(v["Start_Position"]), int(v["End_Position"]), v["Reference_Allele"], v["Variant_Allele"]
      ),
      "tumorType": v["Cancer_Type"],
      "id": "",
      "evidenceTypes": [],
    }
    for v in df.T.to_dict().values()
    ]
    print(data[:1])
    
    return oncokb_query(
      ONCOKB_ENDPOINTS["annotate"], method="post", data=json.dumps(data[:1])
  )

def get_oncokb_genes():
    """Get list of genes and biomarker incindence levels from oncokb."""
    return oncokb_query(ONCOKB_ENDPOINTS["cancer_genes"])

# %% [markdown]
# ### Use Chunks and Multiprocessing to download faster

# %%
from math import ceil
chunck_size= 10_000
annotated_variants = []
for i in range(0, ceil(len(df) / chunk_size)):
    chunks = df[(i * chunk_size) : (2i * chunk_size - 1)]
    ...
    annotated_variants.append(response)

# %%
maf_cohort = pd.read_pickle(data_path + 'merged_data/maf_cohort.pkl')
maf_cohort = maf_cohort.dropna(subset=["Chromosome", "Start_Position", "End_Position", "Reference_Allele", "Variant_Allele"])

# %%
# %%time
query = annotate_variants(maf_cohort)
# Out:
# [{'genomicLocation': '3,178936091,178936091,G,A', 'tumorType': 'Breast Cancer', 'id': '', 'evidenceTypes': []}]
# Querying to https://www.oncokb.org/api/v1/annotate/mutations/byGenomicChange
# CPU times: user 23.9 s, sys: 620 ms, total: 24.5 s
# Wall time: 24.9 s

# %%
query
# Out:
# [{'query': {'id': None,
#    'type': 'regular',
#    'hugoSymbol': 'PIK3CA',
#    'entrezGeneId': 5290,
#    'alteration': 'E545K',
#    'alterationType': None,
#    'svType': None,
#    'tumorType': 'breast cancer',
#    'consequence': 'missense_variant',
#    'proteinStart': 545,
#    'proteinEnd': 545,
#    'hgvs': None},
#   'geneExist': True,
#   'variantExist': True,
#   'alleleExist': True,
#   'oncogenic': 'Oncogenic',
#   'mutationEffect': {'knownEffect': 'Gain-of-function',
#    'description': '',
#    'citations': {'pmids': ['16322248',
#      '30206110',
#      '20593314',
#      '16432179',
#      '26627007',
#      '17376864',
#      '30093452'],
#     'abstracts': []}},
#   'highestSensitiveLevel': 'LEVEL_1',
#   'highestResistanceLevel': None,
#   'highestDiagnosticImplicationLevel': None,
#   'highestPrognosticImplicationLevel': None,
#   'otherSignificantSensitiveLevels': [],
#   'otherSignificantResistanceLevels': [],
#   'hotspot': True,
#   'geneSummary': 'PIK3CA, the catalytic subunit of PI3-kinase, is frequently mutated in a diverse range of cancers including breast, endometrial and cervical cancers.',
#   'variantSummary': 'The PIK3CA E545K mutation is known to be oncogenic.',
#   'tumorTypeSummary': 'The alpha-selective PI3-kinase inhibitor alpelisib in combination with the Estrogen Receptor (ER)-antagonist fulvestrant is FDA-approved for the treatment of patients with PIK3CA-mutant ER+/HER2- breast cancer.',
#   'prognosticSummary': '',
#   'diagnosticSummary': '',
#   'diagnosticImplications': [],
#   'prognosticImplications': [],
#   'treatments': [{'alterations': ['Oncogenic Mutations'],
#     'drugs': [{'ncitCode': 'C1379',
#       'drugName': 'Fulvestrant',
#       'uuid': 'b25af9e9-2195-4f16-90ea-7c21fcf3882d',
#       'synonyms': ['ICI 182,780',
#        'ICI 182780',
#        'FULVESTRANT',
#        'Faslodex(ICI 182,780)',
#        'ZD9238',
#        '"7a-[9-[(4,4,5,5,5,-Pentafluoropentyl)sulphinyl]nonyl]-estra-1,3,5(10)-triene-3,17b-diol',
#        'Faslodex',
#        'fulvestrant"',
#        'Fulvestrant']},
#      {'ncitCode': 'C94214',
#       'drugName': 'Alpelisib',
#       'uuid': 'd76cc0eb-d098-4133-95a5-5f59fad65f80',
#       'synonyms': ['BYL719',
#        'ALPELISIB',
#        'Alpelisib',
#        'Phosphoinositide 3-kinase Inhibitor BYL719']}],
#     'approvedIndications': [],
#     'fdaApproved': None,
#     'level': 'LEVEL_1',
#     'levelAssociatedCancerType': {'id': None,
#      'code': None,
#      'color': None,
#      'name': None,
#      'mainType': {'id': None, 'name': 'Breast Cancer', 'tumorForm': 'SOLID'},
#      'tissue': None,
#      'children': {},
#      'parent': None,
#      'level': None,
#      'tumorForm': None},
#     'pmids': ['25877889', '31091374', '30543347'],
#     'abstracts': [],
#     'description': ''},
#    {'alterations': ['Oncogenic Mutations'],
#     'drugs': [{'ncitCode': 'C96796',
#       'drugName': 'Copanlisib',
#       'uuid': '1d03f52d-27dd-4412-a69a-6ef35ab9c4b3',
#       'synonyms': ['BAY 80-6946',
#        'Copanlisib',
#        'PI3K Inhibitor BAY 80-6946',
#        'COPANLISIB']},
#      {'ncitCode': 'C1379',
#       'drugName': 'Fulvestrant',
#       'uuid': 'b25af9e9-2195-4f16-90ea-7c21fcf3882d',
#       'synonyms': ['ICI 182,780',
#        'ICI 182780',
#        'FULVESTRANT',
#        'Faslodex(ICI 182,780)',
#        'ZD9238',
#        '"7a-[9-[(4,4,5,5,5,-Pentafluoropentyl)sulphinyl]nonyl]-estra-1,3,5(10)-triene-3,17b-diol',
#        'Faslodex',
#        'fulvestrant"',
#        'Fulvestrant']}],
#     'approvedIndications': [],
#     'fdaApproved': None,
#     'level': 'LEVEL_3A',
#     'levelAssociatedCancerType': {'id': None,
#      'code': None,
#      'color': None,
#      'name': None,
#      'mainType': {'id': None, 'name': 'Breast Cancer', 'tumorForm': 'SOLID'},
#      'tissue': None,
#      'children': {},
#      'parent': None,
#      'level': None,
#      'tumorForm': None},
#     'pmids': ['27672108'],
#     'abstracts': [{'link': 'https://cancerres.aacrjournals.org/content/79/13_Supplement/3438',
#       'abstract': 'De et al. Abstract# 3438, AACR 2019'},
#      {'link': 'https://cancerres.aacrjournals.org/content/77/4_Supplement/P3-04-15',
#       'abstract': "O'Brien, NA et al. Abstract P3-04-15. Cancer Research, 2017"},
#      {'link': 'https://cancerres.aacrjournals.org/content/79/4_Supplement/P2-03-08',
#       'abstract': 'De et al. Abstract# P2-03-08, SABCS 2018'}],
#     'description': ''},
#    {'alterations': ['Oncogenic Mutations'],
#     'drugs': [{'ncitCode': 'C132166',
#       'drugName': 'GDC-0077',
#       'uuid': 'bf186346-59d9-4b34-8ee0-75093aa1271e',
#       'synonyms': ['RO 7113755',
#        'GDC 0077',
#        'RG 6114',
#        'GDC0077',
#        'PI3K Inhibitor GDC0077',
#        'RG-6114',
#        'RG6114']}],
#     'approvedIndications': [],
#     'fdaApproved': None,
#     'level': 'LEVEL_3A',
#     'levelAssociatedCancerType': {'id': None,
#      'code': None,
#      'color': None,
#      'name': None,
#      'mainType': {'id': None, 'name': 'Breast Cancer', 'tumorForm': 'SOLID'},
#      'tissue': None,
#      'children': {},
#      'parent': None,
#      'level': None,
#      'tumorForm': None},
#     'pmids': [],
#     'abstracts': [{'link': 'http://cancerres.aacrjournals.org/content/77/13_Supplement/156',
#       'abstract': 'Edgar et al. Abstract# 156, AACR 2017'},
#      {'link': 'http://www.abstractsonline.com/pp8/#!/4292/presentation/11034',
#       'abstract': 'Staben et al. Abstract# DDT02-01, AACR 2017'}],
#     'description': ''}],
#   'dataVersion': 'v2.1',
#   'lastUpdate': '01/07/2020',
#   'vus': False}]

# %%
maf_cohort
maf_cohort = maf_cohort.dropna(subset=["Chromosome", "Start_Position", "End_Position", "Reference_Allele", "Variant_Allele"])
# Out:
#                                   Sample_Id           Tumor_Id    purity  \
# 0       P-0034223-T01-IM6_P-0034223-N01-IM6  P-0034223-T01-IM6  0.941111
# 1       P-0034223-T01-IM6_P-0034223-N01-IM6  P-0034223-T01-IM6  0.941111
# 2       P-0034223-T01-IM6_P-0034223-N01-IM6  P-0034223-T01-IM6  0.941111
# 3       P-0034223-T01-IM6_P-0034223-N01-IM6  P-0034223-T01-IM6  0.941111
# 4       P-0034223-T01-IM6_P-0034223-N01-IM6  P-0034223-T01-IM6  0.941111
# ...                                     ...                ...       ...
# 260808  P-0050745-T01-IM6_P-0050745-N01-IM6  P-0050745-T01-IM6  0.597798
# 260809  P-0050745-T01-IM6_P-0050745-N01-IM6  P-0050745-T01-IM6  0.597798
# 260810  P-0050745-T01-IM6_P-0050745-N01-IM6  P-0050745-T01-IM6  0.597798
# 260811  P-0050745-T01-IM6_P-0050745-N01-IM6  P-0050745-T01-IM6  0.597798
# 260812  P-0050745-T01-IM6_P-0050745-N01-IM6  P-0050745-T01-IM6  0.597798
#
#           ploidy   dipLogR  frac_loh Patient_Id  Patient_Current_Age  \
# 0       2.241830 -0.155483     0.062  P-0034223                 63.0
# 1       2.241830 -0.155483     0.062  P-0034223                 63.0
# 2       2.241830 -0.155483     0.062  P-0034223                 63.0
# 3       2.241830 -0.155483     0.062  P-0034223                 63.0
# 4       2.241830 -0.155483     0.062  P-0034223                 63.0
# ...          ...       ...       ...        ...                  ...
# 260808  1.808634  0.084975     0.560  P-0050745                 68.0
# 260809  1.808634  0.084975     0.560  P-0050745                 68.0
# 260810  1.808634  0.084975     0.560  P-0050745                 68.0
# 260811  1.808634  0.084975     0.560  P-0050745                 68.0
# 260812  1.808634  0.084975     0.560  P-0050745                 68.0
#
#           Cancer_Type              Cancer_Type_Detailed  \
# 0       Breast Cancer         Invasive Breast Carcinoma
# 1       Breast Cancer         Invasive Breast Carcinoma
# 2       Breast Cancer         Invasive Breast Carcinoma
# 3       Breast Cancer         Invasive Breast Carcinoma
# 4       Breast Cancer         Invasive Breast Carcinoma
# ...               ...                               ...
# 260808  Breast Cancer  Breast Invasive Ductal Carcinoma
# 260809  Breast Cancer  Breast Invasive Ductal Carcinoma
# 260810  Breast Cancer  Breast Invasive Ductal Carcinoma
# 260811  Breast Cancer  Breast Invasive Ductal Carcinoma
# 260812  Breast Cancer  Breast Invasive Ductal Carcinoma
#
#                Ethnicity_Category     Sex  Mutation_Count Sample_Type  \
# 0                             NaN  Female             6.0  Metastasis
# 1                             NaN  Female             6.0  Metastasis
# 2                             NaN  Female             6.0  Metastasis
# 3                             NaN  Female             6.0  Metastasis
# 4                             NaN  Female             6.0  Metastasis
# ...                           ...     ...             ...         ...
# 260808  Non-Spanish; Non-Hispanic  Female             6.0     Primary
# 260809  Non-Spanish; Non-Hispanic  Female             6.0     Primary
# 260810  Non-Spanish; Non-Hispanic  Female             6.0     Primary
# 260811  Non-Spanish; Non-Hispanic  Female             6.0     Primary
# 260812  Non-Spanish; Non-Hispanic  Female             6.0     Primary
#
#         samples_per_patient Overall Survival Status  \
# 0                       1.0                  LIVING
# 1                       1.0                  LIVING
# 2                       1.0                  LIVING
# 3                       1.0                  LIVING
# 4                       1.0                  LIVING
# ...                     ...                     ...
# 260808                  1.0                  LIVING
# 260809                  1.0                  LIVING
# 260810                  1.0                  LIVING
# 260811                  1.0                  LIVING
# 260812                  1.0                  LIVING
#
#         Overall Survival (Months)  MSI Score  \
# 0                             NaN       0.55
# 1                             NaN       0.55
# 2                             NaN       0.55
# 3                             NaN       0.55
# 4                             NaN       0.55
# ...                           ...        ...
# 260808                      1.841       1.85
# 260809                      1.841       1.85
# 260810                      1.841       1.85
# 260811                      1.841       1.85
# 260812                      1.841       1.85
#
#                                                                                  gene  \
# 0        {'entrezGeneId': 5290, 'hugoGeneSymbol': 'PIK3CA', 'type': 'protein-coding'}
# 1         {'entrezGeneId': 2064, 'hugoGeneSymbol': 'ERBB2', 'type': 'protein-coding'}
# 2         {'entrezGeneId': 9641, 'hugoGeneSymbol': 'IKBKE', 'type': 'protein-coding'}
# 3          {'entrezGeneId': 6926, 'hugoGeneSymbol': 'TBX3', 'type': 'protein-coding'}
# 4         {'entrezGeneId': 3169, 'hugoGeneSymbol': 'FOXA1', 'type': 'protein-coding'}
# ...                                                                               ...
# 260808   {'entrezGeneId': 5290, 'hugoGeneSymbol': 'PIK3CA', 'type': 'protein-coding'}
# 260809  {'entrezGeneId': 63978, 'hugoGeneSymbol': 'PRDM14', 'type': 'protein-coding'}
# 260810    {'entrezGeneId': 54880, 'hugoGeneSymbol': 'BCOR', 'type': 'protein-coding'}
# 260811     {'entrezGeneId': 5058, 'hugoGeneSymbol': 'PAK1', 'type': 'protein-coding'}
# 260812  {'entrezGeneId': 220032, 'hugoGeneSymbol': 'GDPD4', 'type': 'protein-coding'}
#
#          Gene_Id Variant_Classification      proteinChange  Start_Position  \
# 0         5290.0      Missense_Mutation              E545K     178936091.0
# 1         2064.0      Missense_Mutation              L755S      37880220.0
# 2         9641.0      Missense_Mutation               R27H     206646650.0
# 3         6926.0        Frame_Shift_Ins          S321Vfs*6     115114257.0
# 4         3169.0      Missense_Mutation              C227Y      38061309.0
# ...          ...                    ...                ...             ...
# 260808    5290.0      Missense_Mutation              A987D     178951905.0
# 260809   63978.0      Missense_Mutation              D375H      70978530.0
# 260810   54880.0      Missense_Mutation              Q231E      39933908.0
# 260811    5058.0                 Fusion  GDPD4-PAK1 fusion            -1.0
# 260812  220032.0                 Fusion  GDPD4-PAK1 fusion            -1.0
#
#         End_Position Reference_Allele Variant_Allele Chromosome Hugo_Symbol  \
# 0        178936091.0                G              A          3      PIK3CA
# 1         37880220.0                T              C         17       ERBB2
# 2        206646650.0                G              A          1       IKBKE
# 3        115114258.0                -              T         12        TBX3
# 4         38061309.0                C              T         14       FOXA1
# ...              ...              ...            ...        ...         ...
# 260808   178951905.0                C              A          3      PIK3CA
# 260809    70978530.0                C              G          8      PRDM14
# 260810    39933908.0                G              C         23        BCOR
# 260811          -1.0               NA                        NA        PAK1
# 260812          -1.0               NA                        NA       GDPD4
#
#         alt_count  ref_count           mut_key  \
# 0           284.0      334.0   3_178936091_G_A
# 1           224.0      262.0   17_37880220_T_C
# 2           252.0     1027.0   1_206646650_G_A
# 3           358.0      384.0  12_115114257_-_T
# 4           410.0      462.0   14_38061309_C_T
# ...           ...        ...               ...
# 260808      158.0      409.0   3_178951905_C_A
# 260809      185.0      261.0    8_70978530_C_G
# 260810      274.0      333.0   23_39933908_G_C
# 260811       -1.0       -1.0         NA_-1_NA_
# 260812       -1.0       -1.0         NA_-1_NA_
#
#                             sample_mut_key mut_spot       vaf
# 0        P-0034223-T01-IM6_3_178936091_G_A      545  0.459547
# 1        P-0034223-T01-IM6_17_37880220_T_C      755  0.460905
# 2        P-0034223-T01-IM6_1_206646650_G_A       27  0.197029
# 3       P-0034223-T01-IM6_12_115114257_-_T      321   0.48248
# 4        P-0034223-T01-IM6_14_38061309_C_T      227  0.470183
# ...                                    ...      ...       ...
# 260808   P-0050745-T01-IM6_3_178951905_C_A      987   0.27866
# 260809    P-0050745-T01-IM6_8_70978530_C_G      375  0.414798
# 260810   P-0050745-T01-IM6_23_39933908_G_C      231    0.4514
# 260811         P-0050745-T01-IM6_NA_-1_NA_        4      None
# 260812         P-0050745-T01-IM6_NA_-1_NA_        4      None
#
# [260813 rows x 34 columns]

# %%
maf_cohort
# Out:
#                                   Sample_Id           Tumor_Id    purity  \
# 0       P-0034223-T01-IM6_P-0034223-N01-IM6  P-0034223-T01-IM6  0.941111
# 1       P-0034223-T01-IM6_P-0034223-N01-IM6  P-0034223-T01-IM6  0.941111
# 2       P-0034223-T01-IM6_P-0034223-N01-IM6  P-0034223-T01-IM6  0.941111
# 3       P-0034223-T01-IM6_P-0034223-N01-IM6  P-0034223-T01-IM6  0.941111
# 4       P-0034223-T01-IM6_P-0034223-N01-IM6  P-0034223-T01-IM6  0.941111
# ...                                     ...                ...       ...
# 260808  P-0050745-T01-IM6_P-0050745-N01-IM6  P-0050745-T01-IM6  0.597798
# 260809  P-0050745-T01-IM6_P-0050745-N01-IM6  P-0050745-T01-IM6  0.597798
# 260810  P-0050745-T01-IM6_P-0050745-N01-IM6  P-0050745-T01-IM6  0.597798
# 260811  P-0050745-T01-IM6_P-0050745-N01-IM6  P-0050745-T01-IM6  0.597798
# 260812  P-0050745-T01-IM6_P-0050745-N01-IM6  P-0050745-T01-IM6  0.597798
#
#           ploidy   dipLogR  frac_loh Patient_Id  Patient_Current_Age  \
# 0       2.241830 -0.155483     0.062  P-0034223                 63.0
# 1       2.241830 -0.155483     0.062  P-0034223                 63.0
# 2       2.241830 -0.155483     0.062  P-0034223                 63.0
# 3       2.241830 -0.155483     0.062  P-0034223                 63.0
# 4       2.241830 -0.155483     0.062  P-0034223                 63.0
# ...          ...       ...       ...        ...                  ...
# 260808  1.808634  0.084975     0.560  P-0050745                 68.0
# 260809  1.808634  0.084975     0.560  P-0050745                 68.0
# 260810  1.808634  0.084975     0.560  P-0050745                 68.0
# 260811  1.808634  0.084975     0.560  P-0050745                 68.0
# 260812  1.808634  0.084975     0.560  P-0050745                 68.0
#
#           Cancer_Type              Cancer_Type_Detailed  \
# 0       Breast Cancer         Invasive Breast Carcinoma
# 1       Breast Cancer         Invasive Breast Carcinoma
# 2       Breast Cancer         Invasive Breast Carcinoma
# 3       Breast Cancer         Invasive Breast Carcinoma
# 4       Breast Cancer         Invasive Breast Carcinoma
# ...               ...                               ...
# 260808  Breast Cancer  Breast Invasive Ductal Carcinoma
# 260809  Breast Cancer  Breast Invasive Ductal Carcinoma
# 260810  Breast Cancer  Breast Invasive Ductal Carcinoma
# 260811  Breast Cancer  Breast Invasive Ductal Carcinoma
# 260812  Breast Cancer  Breast Invasive Ductal Carcinoma
#
#                Ethnicity_Category     Sex  Mutation_Count Sample_Type  \
# 0                             NaN  Female             6.0  Metastasis
# 1                             NaN  Female             6.0  Metastasis
# 2                             NaN  Female             6.0  Metastasis
# 3                             NaN  Female             6.0  Metastasis
# 4                             NaN  Female             6.0  Metastasis
# ...                           ...     ...             ...         ...
# 260808  Non-Spanish; Non-Hispanic  Female             6.0     Primary
# 260809  Non-Spanish; Non-Hispanic  Female             6.0     Primary
# 260810  Non-Spanish; Non-Hispanic  Female             6.0     Primary
# 260811  Non-Spanish; Non-Hispanic  Female             6.0     Primary
# 260812  Non-Spanish; Non-Hispanic  Female             6.0     Primary
#
#         samples_per_patient Overall Survival Status  \
# 0                       1.0                  LIVING
# 1                       1.0                  LIVING
# 2                       1.0                  LIVING
# 3                       1.0                  LIVING
# 4                       1.0                  LIVING
# ...                     ...                     ...
# 260808                  1.0                  LIVING
# 260809                  1.0                  LIVING
# 260810                  1.0                  LIVING
# 260811                  1.0                  LIVING
# 260812                  1.0                  LIVING
#
#         Overall Survival (Months)  MSI Score  \
# 0                             NaN       0.55
# 1                             NaN       0.55
# 2                             NaN       0.55
# 3                             NaN       0.55
# 4                             NaN       0.55
# ...                           ...        ...
# 260808                      1.841       1.85
# 260809                      1.841       1.85
# 260810                      1.841       1.85
# 260811                      1.841       1.85
# 260812                      1.841       1.85
#
#                                                                                  gene  \
# 0        {'entrezGeneId': 5290, 'hugoGeneSymbol': 'PIK3CA', 'type': 'protein-coding'}
# 1         {'entrezGeneId': 2064, 'hugoGeneSymbol': 'ERBB2', 'type': 'protein-coding'}
# 2         {'entrezGeneId': 9641, 'hugoGeneSymbol': 'IKBKE', 'type': 'protein-coding'}
# 3          {'entrezGeneId': 6926, 'hugoGeneSymbol': 'TBX3', 'type': 'protein-coding'}
# 4         {'entrezGeneId': 3169, 'hugoGeneSymbol': 'FOXA1', 'type': 'protein-coding'}
# ...                                                                               ...
# 260808   {'entrezGeneId': 5290, 'hugoGeneSymbol': 'PIK3CA', 'type': 'protein-coding'}
# 260809  {'entrezGeneId': 63978, 'hugoGeneSymbol': 'PRDM14', 'type': 'protein-coding'}
# 260810    {'entrezGeneId': 54880, 'hugoGeneSymbol': 'BCOR', 'type': 'protein-coding'}
# 260811     {'entrezGeneId': 5058, 'hugoGeneSymbol': 'PAK1', 'type': 'protein-coding'}
# 260812  {'entrezGeneId': 220032, 'hugoGeneSymbol': 'GDPD4', 'type': 'protein-coding'}
#
#          Gene_Id Variant_Classification      proteinChange  Start_Position  \
# 0         5290.0      Missense_Mutation              E545K     178936091.0
# 1         2064.0      Missense_Mutation              L755S      37880220.0
# 2         9641.0      Missense_Mutation               R27H     206646650.0
# 3         6926.0        Frame_Shift_Ins          S321Vfs*6     115114257.0
# 4         3169.0      Missense_Mutation              C227Y      38061309.0
# ...          ...                    ...                ...             ...
# 260808    5290.0      Missense_Mutation              A987D     178951905.0
# 260809   63978.0      Missense_Mutation              D375H      70978530.0
# 260810   54880.0      Missense_Mutation              Q231E      39933908.0
# 260811    5058.0                 Fusion  GDPD4-PAK1 fusion            -1.0
# 260812  220032.0                 Fusion  GDPD4-PAK1 fusion            -1.0
#
#         End_Position Reference_Allele Variant_Allele Chromosome Hugo_Symbol  \
# 0        178936091.0                G              A          3      PIK3CA
# 1         37880220.0                T              C         17       ERBB2
# 2        206646650.0                G              A          1       IKBKE
# 3        115114258.0                -              T         12        TBX3
# 4         38061309.0                C              T         14       FOXA1
# ...              ...              ...            ...        ...         ...
# 260808   178951905.0                C              A          3      PIK3CA
# 260809    70978530.0                C              G          8      PRDM14
# 260810    39933908.0                G              C         23        BCOR
# 260811          -1.0               NA                        NA        PAK1
# 260812          -1.0               NA                        NA       GDPD4
#
#         alt_count  ref_count           mut_key  \
# 0           284.0      334.0   3_178936091_G_A
# 1           224.0      262.0   17_37880220_T_C
# 2           252.0     1027.0   1_206646650_G_A
# 3           358.0      384.0  12_115114257_-_T
# 4           410.0      462.0   14_38061309_C_T
# ...           ...        ...               ...
# 260808      158.0      409.0   3_178951905_C_A
# 260809      185.0      261.0    8_70978530_C_G
# 260810      274.0      333.0   23_39933908_G_C
# 260811       -1.0       -1.0         NA_-1_NA_
# 260812       -1.0       -1.0         NA_-1_NA_
#
#                             sample_mut_key mut_spot       vaf
# 0        P-0034223-T01-IM6_3_178936091_G_A      545  0.459547
# 1        P-0034223-T01-IM6_17_37880220_T_C      755  0.460905
# 2        P-0034223-T01-IM6_1_206646650_G_A       27  0.197029
# 3       P-0034223-T01-IM6_12_115114257_-_T      321   0.48248
# 4        P-0034223-T01-IM6_14_38061309_C_T      227  0.470183
# ...                                    ...      ...       ...
# 260808   P-0050745-T01-IM6_3_178951905_C_A      987   0.27866
# 260809    P-0050745-T01-IM6_8_70978530_C_G      375  0.414798
# 260810   P-0050745-T01-IM6_23_39933908_G_C      231    0.4514
# 260811         P-0050745-T01-IM6_NA_-1_NA_        4      None
# 260812         P-0050745-T01-IM6_NA_-1_NA_        4      None
#
# [259743 rows x 34 columns]
