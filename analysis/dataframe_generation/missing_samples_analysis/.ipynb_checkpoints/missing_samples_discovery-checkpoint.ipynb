# %% [markdown]
# # <span style='font-family:"Times New Roman"'> <span styel=''>**ANALYSE MISSING SAMPLES (NA)**
# *Emile Cohen*
#
#  *April 2020*

# %% [markdown]
# **Goal:** In this notebook, we compute numbers, general distributions for the samples that are missing purity but have a tp53 mutation.
#
# The notebook is composed of 2 parts:
#
# ---

# %%
# %run -i '../../../utils/setup_environment.ipy'

import warnings
warnings.filterwarnings('ignore')
from scipy.stats import fisher_exact, ranksums, chi2, norm
from statsmodels.sandbox.stats.multicomp import multipletests
import matplotlib.gridspec as gridspec
from itertools import cycle, islice

data_path = '../../../data/'
# Out:
# Setup environment... done!
# <span style="color:green">✅ Working on **mskimpact_env** conda environment.</span>

# %% [markdown]
# # Loading the data

# %%
maf_cohort = pd.read_csv(data_path + 'impact-facets-tp53/new_data_facets/msk_impact_facets_annotated.ccf.maf', sep='\t')
#gene_level = pd.read_csv(data_path + 'impact-facets-tp53/new_data_facets/msk_impact_facets_annotated.ccf.maf', sep='\t')
arm_level = pd.read_csv(data_path + 'impact-facets-tp53/new_data_facets/msk_impact_facets_annotated.arm_level.txt', sep='\t')
annotated_cohort = pd.read_csv(data_path + 'impact-facets-tp53/new_data_facets/msk_impact_facets_annotated.cohort.txt', sep='\t')

# %%
maf_cohort.head()
# Out:
#   Hugo_Symbol  Entrez_Gene_Id Center NCBI_Build Chromosome  Start_Position  \
# 0       IKBKE            9641  MSKCC     GRCh37          1       206646650
# 1      PIK3CA            5290  MSKCC     GRCh37          3       178936091
# 2        TBX3            6926  MSKCC     GRCh37         12       115114257
# 3       FOXA1            3169  MSKCC     GRCh37         14        38061309
# 4        CDH1             999  MSKCC     GRCh37         16        68835773
#
#    End_Position Strand Variant_Classification Variant_Type Reference_Allele  \
# 0     206646650      +      Missense_Mutation          SNP                G
# 1     178936091      +      Missense_Mutation          SNP                G
# 2     115114258      +        Frame_Shift_Ins          INS                -
# 3      38061309      +      Missense_Mutation          SNP                C
# 4      68835774      +        Frame_Shift_Ins          INS                -
#
#   Tumor_Seq_Allele1 Tumor_Seq_Allele2 dbSNP_RS  dbSNP_Val_Status  \
# 0                 G                 A    novel               NaN
# 1                 G                 A    novel               NaN
# 2                 -                 T    novel               NaN
# 3                 C                 T    novel               NaN
# 4                 -                TG    novel               NaN
#
#   Tumor_Sample_Barcode  Matched_Norm_Sample_Barcode Match_Norm_Seq_Allele1  \
# 0    P-0034223-T01-IM6                          NaN                    NaN
# 1    P-0034223-T01-IM6                          NaN                    NaN
# 2    P-0034223-T01-IM6                          NaN                    NaN
# 3    P-0034223-T01-IM6                          NaN                    NaN
# 4    P-0034223-T01-IM6                          NaN                    NaN
#
#   Match_Norm_Seq_Allele2  Tumor_Validation_Allele1  Tumor_Validation_Allele2  \
# 0                    NaN                       NaN                       NaN
# 1                    NaN                       NaN                       NaN
# 2                    NaN                       NaN                       NaN
# 3                    NaN                       NaN                       NaN
# 4                    NaN                       NaN                       NaN
#
#    Match_Norm_Validation_Allele1  Match_Norm_Validation_Allele2  \
# 0                            NaN                            NaN
# 1                            NaN                            NaN
# 2                            NaN                            NaN
# 3                            NaN                            NaN
# 4                            NaN                            NaN
#
#    Verification_Status Validation_Status Mutation_Status  Sequencing_Phase  \
# 0                  NaN           Unknown         SOMATIC               NaN
# 1                  NaN           Unknown         SOMATIC               NaN
# 2                  NaN           Unknown         SOMATIC               NaN
# 3                  NaN           Unknown         SOMATIC               NaN
# 4                  NaN           Unknown         SOMATIC               NaN
#
#    Sequence_Source  Validation_Method       Score  BAM_File  Sequencer  \
# 0              NaN                NaN  MSK-IMPACT       NaN        NaN
# 1              NaN                NaN  MSK-IMPACT       NaN        NaN
# 2              NaN                NaN  MSK-IMPACT       NaN        NaN
# 3              NaN                NaN  MSK-IMPACT       NaN        NaN
# 4              NaN                NaN  MSK-IMPACT       NaN        NaN
#
#    Tumor_Sample_UUID  Matched_Norm_Sample_UUID           HGVSc  \
# 0                NaN                       NaN         c.80G>A
# 1                NaN                       NaN       c.1633G>A
# 2                NaN                       NaN       c.959dupA
# 3                NaN                       NaN        c.680G>A
# 4                NaN                       NaN  c.364_365insTG
#
#                 HGVSp   HGVSp_Short    Transcript_ID Exon_Number  t_depth  \
# 0          p.Arg27His        p.R27H  ENST00000367120        3/22   1279.0
# 1         p.Glu545Lys       p.E545K  ENST00000263967       10/21    618.0
# 2   p.Ser321ValfsTer6   p.S321Vfs*6  ENST00000257566         6/8    742.0
# 3         p.Cys227Tyr       p.C227Y  ENST00000250448         2/2    872.0
# 4  p.His122LeufsTer94  p.H122Lfs*94  ENST00000261769        3/16    316.0
#
#    t_ref_count  t_alt_count  n_depth n_ref_count n_alt_count  \
# 0       1027.0        252.0      809         809           0
# 1        334.0        284.0      160         160           0
# 2        384.0        358.0      695         695           0
# 3        462.0        410.0      733         733           0
# 4         31.0        285.0      600         600           0
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             all_effects  \
# 0                                                                                                                                                                                                                                                                                                                             IKBKE,missense_variant,p.Arg27His,ENST00000367120,NM_014002.3,NM_001193322.1;IKBKE,intron_variant,,ENST00000537984,NM_001193321.1;IKBKE,intron_variant,,ENST00000463979,;
# 1                                                                                                                                                                                                                                                                                                                                                                                       PIK3CA,missense_variant,p.Glu545Lys,ENST00000263967,NM_006218.2;PIK3CA,upstream_gene_variant,,ENST00000462255,;
# 2                                                                                                                                                                                                               TBX3,frameshift_variant,p.Ser301ValfsTer6,ENST00000349155,NM_005996.3;TBX3,frameshift_variant,p.Ser321ValfsTer6,ENST00000257566,NM_016569.3;TBX3,downstream_gene_variant,,ENST00000552054,;TBX3,downstream_gene_variant,,ENST00000548503,;,regulatory_region_variant,,ENSR00000077729,;
# 3                                                                                                                           FOXA1,missense_variant,p.Cys227Tyr,ENST00000250448,NM_004496.3;FOXA1,missense_variant,p.Cys194Tyr,ENST00000540786,;TTC6,upstream_gene_variant,,ENST00000556845,;FOXA1,non_coding_transcript_exon_variant,,ENST00000545425,;FOXA1,downstream_gene_variant,,ENST00000554607,;FOXA1,downstream_gene_variant,,ENST00000557418,;FOXA1,downstream_gene_variant,,ENST00000553751,;
# 4  CDH1,frameshift_variant,p.His122LeufsTer94,ENST00000261769,NM_004360.3;CDH1,frameshift_variant,p.His122LeufsTer94,ENST00000422392,;CDH1,non_coding_transcript_exon_variant,,ENST00000562836,;CDH1,non_coding_transcript_exon_variant,,ENST00000564676,;CDH1,non_coding_transcript_exon_variant,,ENST00000564745,;CDH1,frameshift_variant,p.His122LeufsTer94,ENST00000566612,;CDH1,frameshift_variant,p.His122LeufsTer77,ENST00000566510,;CDH1,frameshift_variant,p.His45LeufsTer94,ENST00000561751,;
#
#   Allele             Gene          Feature Feature_type         Consequence  \
# 0      A  ENSG00000143466  ENST00000367120   Transcript    missense_variant
# 1      A  ENSG00000121879  ENST00000263967   Transcript    missense_variant
# 2      T  ENSG00000135111  ENST00000257566   Transcript  frameshift_variant
# 3      T  ENSG00000129514  ENST00000250448   Transcript    missense_variant
# 4     TG  ENSG00000039068  ENST00000261769   Transcript  frameshift_variant
#
#     cDNA_position  CDS_position Protein_position Amino_acids     Codons  \
# 0        453/3269       80/2151           27/716         R/H    cGc/cAc
# 1       1790/9093     1633/3207         545/1068         E/K    Gag/Aag
# 2  1349-1350/4208  959-960/2232          320/743        Q/QX   cag/caAg
# 3        742/2862      680/1419          227/472         C/Y    tGc/tAc
# 4    555-556/4889  364-365/2649          122/882        H/LX  cac/cTGac
#
#    Existing_variation  ALLELE_NUM  DISTANCE  STRAND_VEP  SYMBOL SYMBOL_SOURCE  \
# 0                 NaN           1       NaN           1   IKBKE          HGNC
# 1                 NaN           1       NaN           1  PIK3CA          HGNC
# 2                 NaN           1       NaN          -1    TBX3          HGNC
# 3                 NaN           1       NaN          -1   FOXA1          HGNC
# 4                 NaN           1       NaN           1    CDH1          HGNC
#
#    HGNC_ID         BIOTYPE CANONICAL         CCDS             ENSP SWISSPROT  \
# 0  14552.0  protein_coding       YES  CCDS30996.1  ENSP00000356087    Q14164
# 1   8975.0  protein_coding       YES  CCDS43171.1  ENSP00000263967    P42336
# 2  11602.0  protein_coding       YES   CCDS9176.1  ENSP00000257566    O15119
# 3   5021.0  protein_coding       YES   CCDS9665.1  ENSP00000250448    P55317
# 4   1748.0  protein_coding       YES  CCDS10869.1  ENSP00000261769    P12830
#
#                  TREMBL        UNIPARC                      RefSeq  \
# 0                   NaN  UPI0000033727  NM_014002.3,NM_001193322.1
# 1  Q4LE51,C9JAM9,C9J951  UPI000013D494                 NM_006218.2
# 2                   NaN  UPI0000136AA0                 NM_016569.3
# 3                B7ZAP5  UPI000013CCBA                 NM_004496.3
# 4                B3GN61  UPI00000341EF                 NM_004360.3
#
#                 SIFT                  PolyPhen   EXON INTRON  \
# 0     deleterious(0)      probably_damaging(1)   3/22    NaN
# 1  deleterious(0.02)  probably_damaging(0.959)  10/21    NaN
# 2                NaN                       NaN    6/8    NaN
# 3     deleterious(0)      probably_damaging(1)    2/2    NaN
# 4                NaN                       NaN   3/16    NaN
#
#                                                                                                                                                                                       DOMAINS  \
# 0  Gene3D:3.30.200.20,Pfam_domain:PF00069,PROSITE_patterns:PS00107,PROSITE_profiles:PS50011,hmmpanther:PTHR22969,hmmpanther:PTHR22969:SF10,SMART_domains:SM00220,Superfamily_domains:SSF56112
# 1                            PROSITE_profiles:PS51545,hmmpanther:PTHR10048:SF54,hmmpanther:PTHR10048,Pfam_domain:PF00613,Gene3D:1.25.40.70,SMART_domains:SM00145,Superfamily_domains:SSF48371
# 2                                                                                                                                              hmmpanther:PTHR11267,hmmpanther:PTHR11267:SF91
# 3     Gene3D:1.10.10.10,Pfam_domain:PF00250,Prints_domain:PR00053,PROSITE_profiles:PS50039,hmmpanther:PTHR11829,hmmpanther:PTHR11829:SF132,SMART_domains:SM00339,Superfamily_domains:SSF46785
# 4                                                                                                                hmmpanther:PTHR24027:SF252,hmmpanther:PTHR24027,Superfamily_domains:SSF49313
#
#    GMAF  AFR_MAF  AMR_MAF  ASN_MAF  EAS_MAF  EUR_MAF  SAS_MAF  AA_MAF  EA_MAF  \
# 0   NaN      NaN      NaN      NaN      NaN      NaN      NaN     NaN     NaN
# 1   NaN      NaN      NaN      NaN      NaN      NaN      NaN     NaN     NaN
# 2   NaN      NaN      NaN      NaN      NaN      NaN      NaN     NaN     NaN
# 3   NaN      NaN      NaN      NaN      NaN      NaN      NaN     NaN     NaN
# 4   NaN      NaN      NaN      NaN      NaN      NaN      NaN     NaN     NaN
#
#    CLIN_SIG  SOMATIC  PUBMED  MOTIF_NAME  MOTIF_POS  HIGH_INF_POS  \
# 0       NaN      NaN     NaN         NaN        NaN           NaN
# 1       NaN      NaN     NaN         NaN        NaN           NaN
# 2       NaN      NaN     NaN         NaN        NaN           NaN
# 3       NaN      NaN     NaN         NaN        NaN           NaN
# 4       NaN      NaN     NaN         NaN        NaN           NaN
#
#    MOTIF_SCORE_CHANGE    IMPACT  PICK VARIANT_CLASS  TSL  HGVS_OFFSET  PHENO  \
# 0                 NaN  MODERATE   1.0         indel  NaN          NaN    NaN
# 1                 NaN  MODERATE   1.0         indel  NaN          NaN    NaN
# 2                 NaN      HIGH   1.0     insertion  NaN          NaN    NaN
# 3                 NaN  MODERATE   1.0         indel  NaN          NaN    NaN
# 4                 NaN      HIGH   1.0     insertion  NaN          NaN    NaN
#
#    MINIMISED  ExAC_AF  ExAC_AF_AFR  ExAC_AF_AMR  ExAC_AF_EAS  ExAC_AF_FIN  \
# 0        NaN      NaN          NaN          NaN          NaN          NaN
# 1        NaN      NaN          NaN          NaN          NaN          NaN
# 2        NaN      NaN          NaN          NaN          NaN          NaN
# 3        NaN      NaN          NaN          NaN          NaN          NaN
# 4        NaN      NaN          NaN          NaN          NaN          NaN
#
#    ExAC_AF_NFE  ExAC_AF_OTH  ExAC_AF_SAS  GENE_PHENO FILTER flanking_bps  \
# 0          NaN          NaN          NaN         NaN    NaN          CGC
# 1          NaN          NaN          NaN         1.0    NaN          TGA
# 2          NaN          NaN          NaN         1.0    NaN          ACT
# 3          NaN          NaN          NaN         1.0    NaN          GCA
# 4          NaN          NaN          NaN         1.0    NaN          CCA
#
#   variant_id variant_qual  ExAC_AF_Adj ExAC_AC_AN_Adj ExAC_AC_AN  \
# 0          .            .          NaN            NaN        NaN
# 1          .            .          NaN            NaN        NaN
# 2          .            .          NaN            NaN        NaN
# 3          .            .          NaN            NaN        NaN
# 4          .            .          NaN            NaN        NaN
#
#   ExAC_AC_AN_AFR ExAC_AC_AN_AMR ExAC_AC_AN_EAS ExAC_AC_AN_FIN ExAC_AC_AN_NFE  \
# 0            NaN            NaN            NaN            NaN            NaN
# 1            NaN            NaN            NaN            NaN            NaN
# 2            NaN            NaN            NaN            NaN            NaN
# 3            NaN            NaN            NaN            NaN            NaN
# 4            NaN            NaN            NaN            NaN            NaN
#
#   ExAC_AC_AN_OTH ExAC_AC_AN_SAS ExAC_FILTER  Caller is-a-hotspot  \
# 0            NaN            NaN         NaN     NaN          NaN
# 1            NaN            NaN         NaN     NaN            Y
# 2            NaN            NaN        PASS     NaN          NaN
# 3            NaN            NaN         NaN     NaN          NaN
# 4            NaN            NaN        PASS     NaN          NaN
#
#   is-a-3d-hotspot          mutation_effect            oncogenic  \
# 0             NaN                      NaN                  NaN
# 1               Y         Gain-of-function            Oncogenic
# 2             NaN  Likely Loss-of-function     Likely Oncogenic
# 3               Y                      NaN  Predicted Oncogenic
# 4             NaN  Likely Loss-of-function     Likely Oncogenic
#
#                  LEVEL_1 LEVEL_2A LEVEL_2B  \
# 0                    NaN      NaN      NaN
# 1  Fulvestrant+Alpelisib      NaN      NaN
# 2                    NaN      NaN      NaN
# 3                    NaN      NaN      NaN
# 4                    NaN      NaN      NaN
#
#                                                                                                       LEVEL_3A  \
# 0                                                                                                          NaN
# 1  Alpelisib,Buparlisib,Buparlisib+Fulvestrant,Copanlisib,GDC-0077,Serabelisib,Taselisib,Taselisib+Fulvestrant
# 2                                                                                                          NaN
# 3                                                                                                          NaN
# 4                                                                                                          NaN
#
#   LEVEL_3B LEVEL_4 LEVEL_R1 LEVEL_R2  LEVEL_R3 Highest_level  \
# 0      NaN     NaN      NaN      NaN       NaN           NaN
# 1      NaN     NaN      NaN      NaN       NaN       LEVEL_1
# 2      NaN     NaN      NaN      NaN       NaN           NaN
# 3      NaN     NaN      NaN      NaN       NaN           NaN
# 4      NaN     NaN      NaN      NaN       NaN           NaN
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   citations  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       NaN
# 1  16322248;30206110;20593314;16432179;26627007;17376864;30093452;25877889;31091374;30543347;24608574;29401002;24652201;30715997;22188813;Di Leo et al. Abstract# S4-07, SABCS 2016(http://cancerres.aacrjournals.org/content/77/4_Supplement/S4-07);22049316;27672108;Edgar et al. Abstract# 156, AACR 2017(http://cancerres.aacrjournals.org/content/77/13_Supplement/156);Staben et al. Abstract# DDT02-01, AACR 2017(http://www.abstractsonline.com/pp8/#!/4292/presentation/11034);28490463;23662903;25172762;Wade et al. Abstract# 9054, ASCO 2017(http://ascopubs.org/doi/abs/10.1200/JCO.2017.35.15_suppl.9054);29793946;Dickler et al. Abstract# 520, ASCO 2016(http://meetinglibrary.asco.org/content/165518-176)
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         11689487;26579496
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       NaN
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          8934538;2070412;17522512;9515965
#
#    driver  tcn  lcn        cf    purity  t_var_freq  expected_alt_copies  \
# 0   False  4.0  1.0  0.946448  0.946448    0.197029                  1.0
# 1    True  2.0  1.0  1.000000  0.946448    0.459547                  1.0
# 2    True  2.0  1.0  1.000000  0.946448    0.482480                  1.0
# 3    True  2.0  1.0  1.000000  0.946448    0.470183                  1.0
# 4    True  1.0  0.0  0.946448  0.946448    0.901899                  1.0
#
#    ccf_Mcopies  ccf_Mcopies_lower  ccf_Mcopies_upper  ccf_Mcopies_prob95  \
# 0        0.270              0.252              0.289       2.574074e-293
# 1        0.971              0.921              1.000        5.984038e-01
# 2        1.000              0.969              1.000        8.882590e-01
# 3        0.994              0.951              1.000        8.134786e-01
# 4        1.000              0.980              1.000        9.867642e-01
#
#    ccf_Mcopies_prob90  ccf_1copy  ccf_1copy_lower  ccf_1copy_upper  \
# 0       3.629664e-249      0.810            0.757            0.866
# 1        9.415561e-01      0.971            0.921            1.000
# 2        9.970941e-01      1.000            0.969            1.000
# 3        9.930881e-01      0.994            0.951            1.000
# 4        9.999929e-01      1.000            0.980            1.000
#
#    ccf_1copy_prob95  ccf_1copy_prob90  ccf_expected_copies  \
# 0          0.001839          0.030659                0.810
# 1          0.598404          0.941556                0.971
# 2          0.888259          0.997094                1.000
# 3          0.813479          0.993088                0.994
# 4          0.986764          0.999993                1.000
#
#    ccf_expected_copies_lower  ccf_expected_copies_upper  \
# 0                      0.757                      0.866
# 1                      0.921                      1.000
# 2                      0.969                      1.000
# 3                      0.951                      1.000
# 4                      0.980                      1.000
#
#    ccf_expected_copies_prob95  ccf_expected_copies_prob90  \
# 0                    0.001839                    0.030659
# 1                    0.598404                    0.941556
# 2                    0.888259                    0.997094
# 3                    0.813479                    0.993088
# 4                    0.986764                    0.999993
#
#                                                                                                facets_fit  \
# 0  /juno/work/ccs/shared/resources/impact/facets/all/P-00342/P-0034223-T01-IM6_P-0034223-N01-IM6//default
# 1  /juno/work/ccs/shared/resources/impact/facets/all/P-00342/P-0034223-T01-IM6_P-0034223-N01-IM6//default
# 2  /juno/work/ccs/shared/resources/impact/facets/all/P-00342/P-0034223-T01-IM6_P-0034223-N01-IM6//default
# 3  /juno/work/ccs/shared/resources/impact/facets/all/P-00342/P-0034223-T01-IM6_P-0034223-N01-IM6//default
# 4  /juno/work/ccs/shared/resources/impact/facets/all/P-00342/P-0034223-T01-IM6_P-0034223-N01-IM6//default
#
#    reviewer_set_purity  use_only_purity_run  use_edited_cncf  \
# 0                  NaN                False            False
# 1                  NaN                False            False
# 2                  NaN                False            False
# 3                  NaN                False            False
# 4                  NaN                False            False
#
#                                                                                                                                                cncf_file_used
# 0  /juno/work/ccs/shared/resources/impact/facets/all/P-00342/P-0034223-T01-IM6_P-0034223-N01-IM6//default/P-0034223-T01-IM6_P-0034223-N01-IM6_hisens.cncf.txt
# 1  /juno/work/ccs/shared/resources/impact/facets/all/P-00342/P-0034223-T01-IM6_P-0034223-N01-IM6//default/P-0034223-T01-IM6_P-0034223-N01-IM6_hisens.cncf.txt
# 2  /juno/work/ccs/shared/resources/impact/facets/all/P-00342/P-0034223-T01-IM6_P-0034223-N01-IM6//default/P-0034223-T01-IM6_P-0034223-N01-IM6_hisens.cncf.txt
# 3  /juno/work/ccs/shared/resources/impact/facets/all/P-00342/P-0034223-T01-IM6_P-0034223-N01-IM6//default/P-0034223-T01-IM6_P-0034223-N01-IM6_hisens.cncf.txt
# 4  /juno/work/ccs/shared/resources/impact/facets/all/P-00342/P-0034223-T01-IM6_P-0034223-N01-IM6//default/P-0034223-T01-IM6_P-0034223-N01-IM6_hisens.cncf.txt

# %%
arm_level.head()
# Out:
#                                 sample arm  tcn  lcn  cn_length  arm_length  \
# 0  P-0034223-T01-IM6_P-0034223-N01-IM6  1p    2    1  120534257   120534257
# 1  P-0034223-T01-IM6_P-0034223-N01-IM6  1q    4    1  101461100   125135032
# 2  P-0034223-T01-IM6_P-0034223-N01-IM6  2p    2    1   87764506    87764506
# 3  P-0034223-T01-IM6_P-0034223-N01-IM6  2q    2    1  150656179   150656179
# 4  P-0034223-T01-IM6_P-0034223-N01-IM6  3p    2    1   89055004    89055004
#
#    frac_of_arm cn_state
# 0         1.00  DIPLOID
# 1         0.81     GAIN
# 2         1.00  DIPLOID
# 3         1.00  DIPLOID
# 4         1.00  DIPLOID

# %%
annotated_cohort.head()
# Out:
#                              sample_id  \
# 0  P-0034223-T01-IM6_P-0034223-N01-IM6
# 1  P-0009819-T01-IM5_P-0009819-N01-IM5
# 2  P-0025956-T01-IM6_P-0025956-N01-IM6
# 3  P-0027609-T01-IM6_P-0027609-N01-IM6
# 4  P-0027408-T01-IM6_P-0027408-N01-IM6
#
#                                                                                       sample_path  \
# 0  /juno/work/ccs/shared/resources/impact/facets/all/P-00342/P-0034223-T01-IM6_P-0034223-N01-IM6/
# 1  /juno/work/ccs/shared/resources/impact/facets/all/P-00098/P-0009819-T01-IM5_P-0009819-N01-IM5/
# 2  /juno/work/ccs/shared/resources/impact/facets/all/P-00259/P-0025956-T01-IM6_P-0025956-N01-IM6/
# 3  /juno/work/ccs/shared/resources/impact/facets/all/P-00276/P-0027609-T01-IM6_P-0027609-N01-IM6/
# 4  /juno/work/ccs/shared/resources/impact/facets/all/P-00274/P-0027408-T01-IM6_P-0027408-N01-IM6/
#
#    fit_to_use    patient       tumor_sample tumor_bamname      normal_sample  \
# 0         NaN  P-0034223  P-0034223-T01-IM6    JU212898-T  P-0034223-N01-IM6
# 1         NaN  P-0009819  P-0009819-T01-IM5    TZ263291-T  P-0009819-N01-IM5
# 2         NaN  P-0025956  P-0025956-T01-IM6    FL762959-T  P-0025956-N01-IM6
# 3         NaN  P-0027609  P-0027609-T01-IM6    EJ805003-T  P-0027609-N01-IM6
# 4         NaN  P-0027408  P-0027408-T01-IM6    JK407486-T  P-0027408-N01-IM6
#
#   normal_bamname                                  tag  \
# 0     NL131958-N  P-0034223-T01-IM6_P-0034223-N01-IM6
# 1     TZ263291-N  P-0009819-T01-IM5_P-0009819-N01-IM5
# 2     ZR679900-N  P-0025956-T01-IM6_P-0025956-N01-IM6
# 3     DK557544-N  P-0027609-T01-IM6_P-0027609-N01-IM6
# 4     YX876228-N  P-0027408-T01-IM6_P-0027408-N01-IM6
#
#                                                                                        run_prefix  \
# 0  /juno/work/ccs/shared/resources/impact/facets/all/P-00342/P-0034223-T01-IM6_P-0034223-N01-IM6/
# 1  /juno/work/ccs/shared/resources/impact/facets/all/P-00098/P-0009819-T01-IM5_P-0009819-N01-IM5/
# 2  /juno/work/ccs/shared/resources/impact/facets/all/P-00259/P-0025956-T01-IM6_P-0025956-N01-IM6/
# 3  /juno/work/ccs/shared/resources/impact/facets/all/P-00276/P-0027609-T01-IM6_P-0027609-N01-IM6/
# 4  /juno/work/ccs/shared/resources/impact/facets/all/P-00274/P-0027408-T01-IM6_P-0027408-N01-IM6/
#
#                                                                                            run_output_dir  \
# 0  /juno/work/ccs/shared/resources/impact/facets/all/P-00342/P-0034223-T01-IM6_P-0034223-N01-IM6/default/
# 1  /juno/work/ccs/shared/resources/impact/facets/all/P-00098/P-0009819-T01-IM5_P-0009819-N01-IM5/default/
# 2  /juno/work/ccs/shared/resources/impact/facets/all/P-00259/P-0025956-T01-IM6_P-0025956-N01-IM6/default/
# 3  /juno/work/ccs/shared/resources/impact/facets/all/P-00276/P-0027609-T01-IM6_P-0027609-N01-IM6/default/
# 4  /juno/work/ccs/shared/resources/impact/facets/all/P-00274/P-0027408-T01-IM6_P-0027408-N01-IM6/default/
#
#                                                                                                    run_log_dir  \
# 0  /juno/work/ccs/shared/resources/impact/facets/all/P-00342/P-0034223-T01-IM6_P-0034223-N01-IM6/default/logs/
# 1  /juno/work/ccs/shared/resources/impact/facets/all/P-00098/P-0009819-T01-IM5_P-0009819-N01-IM5/default/logs/
# 2  /juno/work/ccs/shared/resources/impact/facets/all/P-00259/P-0025956-T01-IM6_P-0025956-N01-IM6/default/logs/
# 3  /juno/work/ccs/shared/resources/impact/facets/all/P-00276/P-0027609-T01-IM6_P-0027609-N01-IM6/default/logs/
# 4  /juno/work/ccs/shared/resources/impact/facets/all/P-00274/P-0027408-T01-IM6_P-0027408-N01-IM6/default/logs/
#
#                                                                                                                                                 counts_file  \
# 0  /juno/work/ccs/shared/resources/impact/facets/all/P-00342/P-0034223-T01-IM6_P-0034223-N01-IM6/countsMerged____P-0034223-T01-IM6_P-0034223-N01-IM6.dat.gz
# 1  /juno/work/ccs/shared/resources/impact/facets/all/P-00098/P-0009819-T01-IM5_P-0009819-N01-IM5/countsMerged____P-0009819-T01-IM5_P-0009819-N01-IM5.dat.gz
# 2  /juno/work/ccs/shared/resources/impact/facets/all/P-00259/P-0025956-T01-IM6_P-0025956-N01-IM6/countsMerged____P-0025956-T01-IM6_P-0025956-N01-IM6.dat.gz
# 3  /juno/work/ccs/shared/resources/impact/facets/all/P-00276/P-0027609-T01-IM6_P-0027609-N01-IM6/countsMerged____P-0027609-T01-IM6_P-0027609-N01-IM6.dat.gz
# 4  /juno/work/ccs/shared/resources/impact/facets/all/P-00274/P-0027408-T01-IM6_P-0027408-N01-IM6/countsMerged____P-0027408-T01-IM6_P-0027408-N01-IM6.dat.gz
#
#    has_counts_file  has_hisens_run  has_purity_run  has_qc  has_maf_anno  \
# 0             True            True            True   False         False
# 1             True            True            True   False         False
# 2             True            True            True   False         False
# 3             True            True            True   False         False
# 4             True            True            True   False         False
#
#   run_status                      tumor_sample_id  \
# 0   complete  P-0034223-T01-IM6_P-0034223-N01-IM6
# 1   complete  P-0009819-T01-IM5_P-0009819-N01-IM5
# 2   complete  P-0025956-T01-IM6_P-0025956-N01-IM6
# 3   complete  P-0027609-T01-IM6_P-0027609-N01-IM6
# 4   complete  P-0027408-T01-IM6_P-0027408-N01-IM6
#
#                                                                                              path  \
# 0  /juno/work/ccs/shared/resources/impact/facets/all/P-00342/P-0034223-T01-IM6_P-0034223-N01-IM6/
# 1  /juno/work/ccs/shared/resources/impact/facets/all/P-00098/P-0009819-T01-IM5_P-0009819-N01-IM5/
# 2  /juno/work/ccs/shared/resources/impact/facets/all/P-00259/P-0025956-T01-IM6_P-0025956-N01-IM6/
# 3  /juno/work/ccs/shared/resources/impact/facets/all/P-00276/P-0027609-T01-IM6_P-0027609-N01-IM6/
# 4  /juno/work/ccs/shared/resources/impact/facets/all/P-00274/P-0027408-T01-IM6_P-0027408-N01-IM6/
#
#   fit_name purity_run_version  \
# 0  default             0.5.14
# 1  default             0.5.14
# 2  default             0.5.14
# 3  default             0.5.14
# 4  default             0.5.14
#
#                                                                                                                                    purity_run_prefix  \
# 0  /juno/work/ccs/shared/resources/impact/facets/all/P-00342/P-0034223-T01-IM6_P-0034223-N01-IM6//default/P-0034223-T01-IM6_P-0034223-N01-IM6_purity
# 1  /juno/work/ccs/shared/resources/impact/facets/all/P-00098/P-0009819-T01-IM5_P-0009819-N01-IM5//default/P-0009819-T01-IM5_P-0009819-N01-IM5_purity
# 2  /juno/work/ccs/shared/resources/impact/facets/all/P-00259/P-0025956-T01-IM6_P-0025956-N01-IM6//default/P-0025956-T01-IM6_P-0025956-N01-IM6_purity
# 3  /juno/work/ccs/shared/resources/impact/facets/all/P-00276/P-0027609-T01-IM6_P-0027609-N01-IM6//default/P-0027609-T01-IM6_P-0027609-N01-IM6_purity
# 4  /juno/work/ccs/shared/resources/impact/facets/all/P-00274/P-0027408-T01-IM6_P-0027408-N01-IM6//default/P-0027408-T01-IM6_P-0027408-N01-IM6_purity
#
#    purity_run_Seed  purity_run_cval  purity_run_nhet  purity_run_snp_nbhd  \
# 0              100              100               15                  250
# 1              100              100               15                  250
# 2              100              100               15                  250
# 3              100              100               15                  250
# 4              100              100               15                  250
#
#    purity_run_ndepth  purity_run_Purity  purity_run_Ploidy  \
# 0                 35               0.94                2.2
# 1                 35               0.28                2.7
# 2                 35               0.19                3.5
# 3                 35               0.30                2.1
# 4                 35               0.31                1.8
#
#    purity_run_dipLogR purity_run_alBalLogR hisens_run_version  \
# 0               -0.16                -0.16             0.5.14
# 1               -0.13                -0.13             0.5.14
# 2               -0.19          -0.19, 0.02             0.5.14
# 3               -0.02                -0.02             0.5.14
# 4                0.04                 0.04             0.5.14
#
#                                                                                                                                    hisens_run_prefix  \
# 0  /juno/work/ccs/shared/resources/impact/facets/all/P-00342/P-0034223-T01-IM6_P-0034223-N01-IM6//default/P-0034223-T01-IM6_P-0034223-N01-IM6_hisens
# 1  /juno/work/ccs/shared/resources/impact/facets/all/P-00098/P-0009819-T01-IM5_P-0009819-N01-IM5//default/P-0009819-T01-IM5_P-0009819-N01-IM5_hisens
# 2  /juno/work/ccs/shared/resources/impact/facets/all/P-00259/P-0025956-T01-IM6_P-0025956-N01-IM6//default/P-0025956-T01-IM6_P-0025956-N01-IM6_hisens
# 3  /juno/work/ccs/shared/resources/impact/facets/all/P-00276/P-0027609-T01-IM6_P-0027609-N01-IM6//default/P-0027609-T01-IM6_P-0027609-N01-IM6_hisens
# 4  /juno/work/ccs/shared/resources/impact/facets/all/P-00274/P-0027408-T01-IM6_P-0027408-N01-IM6//default/P-0027408-T01-IM6_P-0027408-N01-IM6_hisens
#
#    hisens_run_Seed  hisens_run_cval  hisens_run_nhet  hisens_run_snp_nbhd  \
# 0              100               50               15                  250
# 1              100               50               15                  250
# 2              100               50               15                  250
# 3              100               50               15                  250
# 4              100               50               15                  250
#
#    hisens_run_ndepth  hisens_run_hisens  hisens_run_Ploidy  \
# 0                 35                NaN                2.2
# 1                 35                NaN                2.7
# 2                 35                NaN                3.0
# 3                 35                NaN                2.1
# 4                 35                NaN                1.8
#
#    hisens_run_dipLogR  manual_note  is_best_fit    purity    ploidy   dipLogR  \
# 0               -0.16          NaN        False  0.941111  2.241830 -0.155483
# 1               -0.13          NaN        False  0.275237  2.681075 -0.129255
# 2               -0.19          NaN        False  0.185874  3.496971 -0.187925
# 3               -0.02          NaN        False  0.300000  2.110732 -0.023766
# 4                0.04          NaN        False  0.308886  1.811066  0.042724
#
#    dipLogR_flag  n_alternative_dipLogR    wgd  n_dip_bal_segs  \
# 0         False                      0  False              12
# 1         False                      0  False               7
# 2         False                      0   True               2
# 3         False                      0  False               9
# 4         False                      0  False               7
#
#    frac_dip_bal_segs  n_dip_imbal_segs  frac_dip_imbal_segs  n_amps  \
# 0              0.590                 0                0.000       0
# 1              0.430                 0                0.000       0
# 2              0.096                 4                0.180       0
# 3              0.440                 1                0.014       0
# 4              0.280                 1                0.035       0
#
#    n_homdels  frac_homdels  n_homdels_clonal  frac_homdels_clonal  \
# 0          0        0.0000                 0               0.0000
# 1          1        0.0062                 1               0.0062
# 2          0        0.0000                 0               0.0000
# 3          0        0.0000                 0               0.0000
# 4          0        0.0000                 0               0.0000
#
#    n_cn_states  n_segs  n_cnlr_clusters  n_lcn_na  n_loh  frac_loh  \
# 0            6      31               10         2      4     0.062
# 1            3      25                6         0      5     0.094
# 2            6      26                6         0      5     0.190
# 3            4      31                6         2      1     0.014
# 4            4      31                6         0     12     0.340
#
#    n_segs_subclonal  frac_segs_subclonal  n_segs_below_dipLogR  \
# 0                 1             0.000011                    11
# 1                 0             0.000000                    15
# 2                 3             0.120000                     0
# 3                 5             0.130000                    11
# 4                 0             0.000000                    18
#
#    frac_below_dipLogR  n_segs_balanced_odd_tcn  frac_balanced_odd_tcn  \
# 0                0.26                        0               0.000000
# 1                0.46                        1               0.000085
# 2                0.00                        4               0.140000
# 3                0.27                        0               0.000000
# 4                0.55                        0               0.000000
#
#    n_segs_imbalanced_diploid_cn  frac_imbalanced_diploid_cn  \
# 0                             0                       0.000
# 1                             0                       0.000
# 2                             0                       0.000
# 3                             0                       0.000
# 4                             1                       0.071
#
#    n_segs_lcn_greater_mcn  frac_lcn_greater_mcn  n_snps  n_het_snps  \
# 0                       7                 0.110   22963        2655
# 1                       4                 0.088   16527        2041
# 2                      15                 0.600   17971        2159
# 3                       1                 0.033   18401        2497
# 4                      15                 0.450   18633        2163
#
#    frac_het_snps  n_snps_with_300x_in_tumor  n_het_snps_with_300x_in_tumor  \
# 0           0.12                       6450                            634
# 1           0.12                       4837                            373
# 2           0.12                       6748                            774
# 3           0.14                       9893                           1396
# 4           0.12                       8281                            924
#
#    n_het_snps_hom_in_tumor_1pct  n_het_snps_hom_in_tumor_5pct  \
# 0                            43                            80
# 1                            10                             0
# 2                             0                             0
# 3                             0                             0
# 4                             0                             0
#
#    frac_het_snps_hom_in_tumor_1pct  frac_het_snps_hom_in_tumor_5pct  \
# 0                           0.0160                             0.03
# 1                           0.0049                             0.00
# 2                           0.0000                             0.00
# 3                           0.0000                             0.00
# 4                           0.0000                             0.00
#
#    mean_cnlr_residual  sd_cnlr_residual  n_segs_discordant_tcn  \
# 0              -0.190              0.63                      1
# 1              -0.250              0.83                      1
# 2              -0.052              0.30                      2
# 3              -0.032              0.24                      0
# 4              -0.058              0.29                      2
#
#    frac_discordant_tcn  n_segs_discordant_lcn  frac_discordant_lcn  \
# 0               0.0038                    0.0                  0.0
# 1               0.0062                    0.0                  0.0
# 2               0.0150                    0.0                  0.0
# 3               0.0000                    0.0                  0.0
# 4               0.0960                    0.0                  0.0
#
#    n_segs_discordant_both  frac_discordant_both  n_segs_icn_cnlor_discordant  \
# 0                       0                  0.00                            1
# 1                       0                  0.00                            2
# 2                       3                  0.12                            8
# 3                       0                  0.00                            3
# 4                       0                  0.00                            4
#
#    frac_icn_cnlor_discordant  mafr_median_all  mafr_median_clonal  \
# 0                     0.0420           0.0042              0.0034
# 1                     0.0063           0.0057              0.0057
# 2                     0.3000           0.0210              0.0250
# 3                     0.1200           0.0230              0.0190
# 4                     0.2100           0.0460              0.0460
#
#    mafr_n_gt_1 facets_suite_version  facets_qc_version  homdel_filter_pass  \
# 0            5                2.0.5                  1                True
# 1            0                2.0.5                  1                True
# 2            0                2.0.5                  1                True
# 3            0                2.0.5                  1                True
# 4            0                2.0.5                  1                True
#
#    diploid_bal_seg_filter_pass  diploid_imbal_seg_filter_pass  \
# 0                         True                          False
# 1                         True                          False
# 2                         True                           True
# 3                         True                          False
# 4                         True                          False
#
#    waterfall_filter_pass  hyper_seg_filter_pass  high_ploidy_filter_pass  \
# 0                   True                   True                     True
# 1                   True                   True                     True
# 2                   True                   True                     True
# 3                   True                   True                     True
# 4                   True                   True                     True
#
#    valid_purity_filter_pass  diploid_seg_filter_pass  \
# 0                      True                     True
# 1                      True                     True
# 2                      True                     True
# 3                     False                     True
# 4                      True                     True
#
#   em_cncf_icn_discord_filter_pass  dipLogR_too_low_filter_pass  \
# 0                            True                         True
# 1                            True                         True
# 2                            True                         True
# 3                            True                         True
# 4                            True                         True
#
#    subclonal_genome_filter_pass  icn_allelic_state_concordance_filter_pass  \
# 0                          True                                       True
# 1                          True                                       True
# 2                          True                                       True
# 3                          True                                       True
# 4                          True                                       True
#
#   contamination_filter_pass  facets_qc  \
# 0                      True       True
# 1                      True       True
# 2                      True       True
# 3                      True      False
# 4                      True       True
#
#                                                                                                                                              arm_level_file  \
# 0  /juno/work/ccs/shared/resources/impact/facets/all/P-00342/P-0034223-T01-IM6_P-0034223-N01-IM6//default/P-0034223-T01-IM6_P-0034223-N01-IM6.arm_level.txt
# 1  /juno/work/ccs/shared/resources/impact/facets/all/P-00098/P-0009819-T01-IM5_P-0009819-N01-IM5//default/P-0009819-T01-IM5_P-0009819-N01-IM5.arm_level.txt
# 2  /juno/work/ccs/shared/resources/impact/facets/all/P-00259/P-0025956-T01-IM6_P-0025956-N01-IM6//default/P-0025956-T01-IM6_P-0025956-N01-IM6.arm_level.txt
# 3  /juno/work/ccs/shared/resources/impact/facets/all/P-00276/P-0027609-T01-IM6_P-0027609-N01-IM6//default/P-0027609-T01-IM6_P-0027609-N01-IM6.arm_level.txt
# 4  /juno/work/ccs/shared/resources/impact/facets/all/P-00274/P-0027408-T01-IM6_P-0027408-N01-IM6//default/P-0027408-T01-IM6_P-0027408-N01-IM6.arm_level.txt
#
#                                                                                                                                              gene_level_file  \
# 0  /juno/work/ccs/shared/resources/impact/facets/all/P-00342/P-0034223-T01-IM6_P-0034223-N01-IM6//default/P-0034223-T01-IM6_P-0034223-N01-IM6.gene_level.txt
# 1  /juno/work/ccs/shared/resources/impact/facets/all/P-00098/P-0009819-T01-IM5_P-0009819-N01-IM5//default/P-0009819-T01-IM5_P-0009819-N01-IM5.gene_level.txt
# 2  /juno/work/ccs/shared/resources/impact/facets/all/P-00259/P-0025956-T01-IM6_P-0025956-N01-IM6//default/P-0025956-T01-IM6_P-0025956-N01-IM6.gene_level.txt
# 3  /juno/work/ccs/shared/resources/impact/facets/all/P-00276/P-0027609-T01-IM6_P-0027609-N01-IM6//default/P-0027609-T01-IM6_P-0027609-N01-IM6.gene_level.txt
# 4  /juno/work/ccs/shared/resources/impact/facets/all/P-00274/P-0027408-T01-IM6_P-0027408-N01-IM6//default/P-0027408-T01-IM6_P-0027408-N01-IM6.gene_level.txt
#
#                                                                                                                                              ccf_file  \
# 0  /juno/work/ccs/shared/resources/impact/facets/all/P-00342/P-0034223-T01-IM6_P-0034223-N01-IM6//default/P-0034223-T01-IM6_P-0034223-N01-IM6.ccf.maf
# 1  /juno/work/ccs/shared/resources/impact/facets/all/P-00098/P-0009819-T01-IM5_P-0009819-N01-IM5//default/P-0009819-T01-IM5_P-0009819-N01-IM5.ccf.maf
# 2  /juno/work/ccs/shared/resources/impact/facets/all/P-00259/P-0025956-T01-IM6_P-0025956-N01-IM6//default/P-0025956-T01-IM6_P-0025956-N01-IM6.ccf.maf
# 3  /juno/work/ccs/shared/resources/impact/facets/all/P-00276/P-0027609-T01-IM6_P-0027609-N01-IM6//default/P-0027609-T01-IM6_P-0027609-N01-IM6.ccf.maf
# 4  /juno/work/ccs/shared/resources/impact/facets/all/P-00274/P-0027408-T01-IM6_P-0027408-N01-IM6//default/P-0027408-T01-IM6_P-0027408-N01-IM6.ccf.maf
#
#    arm_level_file_exists  gene_level_file_exists  ccf_file_exists
# 0                   True                    True             True
# 1                   True                    True             True
# 2                   True                    True             True
# 3                   True                    True             True
# 4                   True                    True             True

# %%
# Number of samples in the entire cohort
print( 'Number of samples in the entire cohort :' + str(len(set(maf_cohort.Tumor_Sample_Barcode))))
print( 'Number of samples without purity estimate (NA or 0.3) : ' + str(len(set(maf_cohort[(maf_cohort.purity == 0.3)| (maf_cohort.purity.isna())].Tumor_Sample_Barcode))))
# Out:
# Number of samples in the entire cohort :38465
# Number of samples without purity estimate (NA or 0.3) : 6437

# %%
# We filter the samples that have no purity
maf_cohort_na = maf_cohort[(maf_cohort.purity == 0.3)| (maf_cohort.purity.isna())]

# How many samples with a TP53 mutation ?
maf_cohort_na_tp53 = maf_cohort_na[maf_cohort_na['Hugo_Symbol'] == 'TP53']
print('Number of NA purity samples with a TP53 mutation: ' + str(len(set(maf_cohort_na_tp53.Tumor_Sample_Barcode))))

# More precisely, we wannna rescue only the samples with tp53_vaf > 0.15.
# How many samples ?
maf_cohort_na_tp53_vaf = maf_cohort_na_tp53[maf_cohort_na_tp53['t_var_freq']>0.15]
print('Number of NA purity samples with a TP53 mutation and vaf>0.15: ' + str(len(set(maf_cohort_na_tp53_vaf.Tumor_Sample_Barcode))))
# Out:
# Number of NA purity samples with a TP53 mutation: 2198
# Number of NA purity samples with a TP53 mutation and vaf>0.15: 427

# %%
# Distribution of cancer for the 427 targeted samples
samples = list(set(maf_cohort_na_tp53_vaf.Tumor_Sample_Barcode))
# we load clinical data from CBioPortal
clinical_data = pd.read_csv(data_path + 'cbioportal/raw/mskimpact_clinical_data-2.tsv', sep= '\t')
get_groupby(clinical_data[clinical_data['Sample ID'].isin(samples)], 'Cancer Type', 'count').sort_values(by='count', ascending=False)
# Out:
#                                    count
# Cancer Type
# Colorectal Cancer                     78
# Non-Small Cell Lung Cancer            58
# Endometrial Cancer                    40
# Pancreatic Cancer                     36
# Breast Cancer                         27
# Glioma                                27
# Prostate Cancer                       24
# Esophagogastric Cancer                23
# Bladder Cancer                        21
# Hepatobiliary Cancer                  12
# Cancer of Unknown Primary             10
# Ovarian Cancer                         9
# Skin Cancer, Non-Melanoma              7
# Head and Neck Cancer                   6
# Thyroid Cancer                         5
# Ampullary Cancer                       5
# Appendiceal Cancer                     5
# Soft Tissue Sarcoma                    4
# Bone Cancer                            3
# Salivary Gland Cancer                  3
# Melanoma                               2
# Germ Cell Tumor                        2
# Cervical Cancer                        2
# Small Bowel Cancer                     2
# Small Cell Lung Cancer                 2
# Uterine Sarcoma                        2
# Wilms Tumor                            2
# Gastrointestinal Stromal Tumor         1
# Blood Cancer, NOS                      1
# Thymic Tumor                           1
# B-Lymphoblastic Leukemia/Lymphoma      1

# %%
# Filtering the files on the selected samples
maf_cohort_samples = maf_cohort[maf_cohort.Tumor_Sample_Barcode.isin(samples)]
arm_level_samples = arm_level[arm_level['sample'].str[:17].isin(samples)]
annotated_cohort_samples = annotated_cohort[annotated_cohort.tumor_sample.isin(samples)]

# %%
len(set(annotated_cohort_samples['tumor_sample']))
# Out:
# 427
