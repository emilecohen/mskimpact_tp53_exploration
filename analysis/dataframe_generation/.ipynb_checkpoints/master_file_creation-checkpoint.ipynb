# %% [markdown]
# # <span style='font-family:"Times New Roman"'> <span styel=''> **MASTER FILE CREATION**
#
# ## <span style='font-family:"Times New Roman"'> <span styel=''> *Emile Cohen*
# *March 2020*

# %% [markdown]
# **Goal:** In this Notebook, we create a master file that summarizes all useful information.
#
# The Notebook is divided in 4 parts, representing the four parts of our Master file:
#
# * **1. Patient/Sample Information**
# * **2. TP53 Mutations**
# * **3. TP53 Copy Numbers**
# * **4. TP53 Computed Metrics**
# * **5. Subgroup columns creation**
# * **6. Merge tables**
#
# **NB1:** In each part, you must run the cells from the begining in order to initialize the variables
#
# **NB2:** In order to launch the last script (Merge Tables), you have to define the functions in each part.
#
# **NB3:** All functions used for the plots are located in utils/custom_tools.py
#
# ---

# %%
# %run -i '../../utils/setup_environment.ipy'

from pathlib import Path
from utils.filters import *

import warnings
warnings.filterwarnings('ignore')

data_path = '../../data/'
# Out:
# Setup environment... done!
# <span style="color:green">✅ Working on **mskimpact_env** conda environment.</span>

# %% [markdown]
# ---
# ## 1. Patient/Sample Information

# %% [markdown]
# In this part, we focus on clinical information exported from CbioPortal. We use the maf file created in the script *./maf_cohort_creation.ipynb* and stored in *../../data/merged_data/maf_cohort.pkl*.
#
# The following columns are selected:
# * Sample_Id
# * Tumor_Id
# * Patient_Id
# * Cancer_Type
# * Sample_Type
# * purity
# * ploidy
# * samples_per_patient
# * Overall Survival Status
# * Overall Survival (Months)
# * MSI Score
# * Tumor Mutational Burden

# %%
def create_sample_info(path):
    '''
    This function aims to create a dataframe gathering all samples from the cohort with important clinical
    information.
    We use the function normal_samp_duplicates_filter to filter out the samples that have the same tumor
    but different normal samples, we keep only the one with the highest purity.
    '''
    maf_cohort = pd.read_pickle(path)
    
    #We select only interesting columns
    selected_cohort = maf_cohort[['Sample_Id','Tumor_Id', 'Patient_Id','Cancer_Type', 'Sample_Type', 'purity', 'ploidy',
                                  'samples_per_patient','Overall Survival Status', 'Overall Survival (Months)', 
                                  'MSI Score', 'TMB_Score']]

    # But we have many duplicates
    # First, we remove the duplicates based on Sample_Id
    selected_cohort = selected_cohort.drop_duplicates('Sample_Id')
    
    return selected_cohort #selected_cohort

# %%
sample_info = create_sample_info(data_path + 'merged_data/maf_cohort.pkl')
sample_info
# Out:
#                                   Sample_Id           Tumor_Id Patient_Id  \
# 0       P-0034223-T01-IM6_P-0034223-N01-IM6  P-0034223-T01-IM6  P-0034223
# 6       P-0009819-T01-IM5_P-0009819-N01-IM5  P-0009819-T01-IM5  P-0009819
# 9       P-0025956-T01-IM6_P-0025956-N01-IM6  P-0025956-T01-IM6  P-0025956
# 15      P-0027408-T01-IM6_P-0027408-N01-IM6  P-0027408-T01-IM6  P-0027408
# 36      P-0006554-T01-IM5_P-0006554-N01-IM5  P-0006554-T01-IM5  P-0006554
# ...                                     ...                ...        ...
# 260784  P-0050644-T01-IM6_P-0050644-N01-IM6  P-0050644-T01-IM6  P-0050644
# 260787  P-0050741-T01-IM6_P-0050741-N01-IM6  P-0050741-T01-IM6  P-0050741
# 260795  P-0050747-T01-IM6_P-0050747-N01-IM6  P-0050747-T01-IM6  P-0050747
# 260801  P-0050652-T01-IM6_P-0050652-N01-IM6  P-0050652-T01-IM6  P-0050652
# 260804  P-0050745-T01-IM6_P-0050745-N01-IM6  P-0050745-T01-IM6  P-0050745
#
#                        Cancer_Type Sample_Type    purity    ploidy  \
# 0                    Breast Cancer  Metastasis  0.941111  2.241830
# 6                  Prostate Cancer     Primary  0.275237  2.681075
# 9       Non-Small Cell Lung Cancer     Primary  0.185874  3.496971
# 15      Non-Small Cell Lung Cancer  Metastasis  0.308886  1.811066
# 36                          Glioma     Primary  0.715208  1.910719
# ...                            ...         ...       ...       ...
# 260784             Prostate Cancer     Primary  0.576103  2.175837
# 260787      Small Cell Lung Cancer  Metastasis  0.833591  2.006039
# 260795           Pancreatic Cancer     Primary  0.360576  2.187990
# 260801           Pancreatic Cancer     Primary  0.171442  2.011650
# 260804               Breast Cancer     Primary  0.597798  1.808634
#
#         samples_per_patient Overall Survival Status  \
# 0                       1.0                  LIVING
# 6                       1.0                  LIVING
# 9                       1.0                DECEASED
# 15                      1.0                  LIVING
# 36                      1.0                  LIVING
# ...                     ...                     ...
# 260784                  1.0                  LIVING
# 260787                  1.0                  LIVING
# 260795                  1.0                  LIVING
# 260801                  1.0                  LIVING
# 260804                  1.0                  LIVING
#
#         Overall Survival (Months)  MSI Score
# 0                             NaN       0.55
# 6                          23.441       0.00
# 9                           3.584       0.00
# 15                         22.586       0.27
# 36                         26.170       1.30
# ...                           ...        ...
# 260784                      1.249       0.00
# 260787                      1.940       0.22
# 260795                        NaN       0.05
# 260801                      1.085       0.26
# 260804                      1.841       1.85
#
# [29304 rows x 11 columns]

# %% [markdown]
# ---
# ## 2. TP53 Mutations

# %% [markdown]
# In this part, we focus on mutational information exported from *default_qc_pass.ccf_TP53.maf* file. We use the maf file created in the script *./maf_tp53_creation.ipynb* and stored in *../../data/merged_data/maf_tp53.pkl*.
#
# We gather all mutations per sample, and split it into different columns. We have the following columns:
# * Tumor_Id
# * key_1 (2,3,4,5) --> Mutation key allowing to filter duplicates
# * vc_1 (2,3,4,5) --> Variant Classification
# * ccf_1 (2,3,4,5) --> Cancer Cell Fraction of the mutation
# * vaf_1 (2,3,4,5) --> Variant Allele Frequency of the mutation
# * HGVSp_1 (2,3,4,5) --> protein change
# * spot_1 (2,3,4,5) --> Integer that defines the spot of the tp53 mutation
# * tp53_count --> Number of tp53 mutations of the sample

# %%
def f(x):
    # This function helps us to group mutations together in a single cell per patient
    return pd.DataFrame(dict(Sample_Id = x['Sample_Id'],  
                        muts = "%s" % ','.join(x['sample_mut_key_vc_ccf_vaf_hgv_spot'])))

def count_tp53_muts(x):
    count = 0
    for i in range(1,6):
        if x['key_' + str(i)]:
            count+= 1
    return count

def create_tp53_muts(sample_info, path):
    '''
    This function aims to gather all tp53 mutation characteristics.
    For each sample we gather the tp53 mutations and their characteristics for all patients.
    '''
    # We load the  table created in maf_tp53_creation.ipynb
    maf_tp53 = pd.read_pickle(path)
    
    # We select only intresting columns
    maf_tp53_filtered = maf_tp53[['Sample_Id','sample_mut_key', 'Variant_Classification',\
                                        'ccf_expected_copies', 't_var_freq', 'HGVSp','mut_spot' ]]

    # Let's Merge mut_key,Variant_classification, CF, CCF, and VAF to gather them
    maf_tp53_filtered['sample_mut_key_vc_ccf_vaf_hgv_spot'] = pd.Series([str(i)+'%'+str(j)+'%'+str(k)+'%'+str(l)+'%'+str(m)+'%'+str(n) for i,j,k,l,m,n\
                                                            in zip(maf_tp53_filtered.sample_mut_key, \
                                                                   maf_tp53_filtered.Variant_Classification,\
                                                                   maf_tp53_filtered.ccf_expected_copies,\
                                                                   maf_tp53_filtered.t_var_freq,\
                                                                   maf_tp53_filtered.HGVSp,\
                                                                   maf_tp53_filtered.mut_spot\
                                                                  )]) 

 

    # We Select important columns
    final = maf_tp53_filtered[['Sample_Id', 'sample_mut_key_vc_ccf_vaf_hgv_spot']]
    # We groupby Patient_Id and apply the function above to group mutations
    final = final.groupby(['Sample_Id'], sort=False).apply(f)

    # We separate the different mutations into 5 different columns (5 is the max number of tp53 mutations in our cohort)
    final[['mut_key_1','mut_key_2','mut_key_3','mut_key_4','mut_key_5']] = final.muts.str.split(',', expand=True)

    # Split the columns into mut_key_ and vc_
    final[['key_1','vc_1','ccf_1','vaf_1','HGVSp_1', 'spot_1']] = final.mut_key_1.str.split('%', expand=True)
    final[['key_2','vc_2','ccf_2','vaf_2','HGVSp_2', 'spot_2']] = final.mut_key_2.str.split('%', expand=True)
    final[['key_3','vc_3','ccf_3','vaf_3','HGVSp_3', 'spot_3']] = final.mut_key_3.str.split('%', expand=True)
    final[['key_4','vc_4','ccf_4','vaf_4','HGVSp_4', 'spot_4']] = final.mut_key_4.str.split('%', expand=True)
    final[['key_5','vc_5','ccf_5','vaf_5','HGVSp_5', 'spot_5']] = final.mut_key_5.str.split('%', expand=True)

    # We remove the muts column
    final = final.drop(['muts','mut_key_1','mut_key_2','mut_key_3','mut_key_4','mut_key_5'], axis=1)

    # We remove duplicates
    final = final.drop_duplicates('Sample_Id')

    # We add the cohort patients that are not tp53 positive
    #First we create a dataframe with all missing samples
    cohort_samples = set(sample_info.Tumor_Id)
    final_samples = set(final.Sample_Id)
    missing_samp = pd.DataFrame(cohort_samples - final_samples, columns = ['Sample_Id'])
    #Then we append the two datframe
    final = final.append(missing_samp)
    
    # We rename the Sample_Id column to have the same key as in other datframes
    final = final.rename(columns={'Sample_Id': 'Tumor_Id'})
    
    # We add a last column tp53_count that represents the number of tp53 mutations per sample
    final = final.where(final.notnull(), None)
    final['tp53_count'] = final.apply(count_tp53_muts, axis = 1)
    
    # We change the type of vafs column to float64 instead of strings
    final = final.astype({'vaf_1': 'float64', 'vaf_2': 'float64', 'vaf_3': 'float64', 'vaf_4': 'float64', 'vaf_5': 'float64',
                       'ccf_1': 'float64', 'ccf_2': 'float64', 'ccf_3': 'float64', 'ccf_4': 'float64', 'ccf_5': 'float64'})

    return final

# %%
tp53_muts = create_tp53_muts(sample_info, data_path + 'merged_data/maf_tp53.pkl')
tp53_muts.head()
# Out:
#             Tumor_Id                               key_1               vc_1  \
# 0  P-0027408-T01-IM6  P-0027408-T01-IM6_17_7578409_CT_TC  Missense_Mutation
# 1  P-0036909-T01-IM6    P-0036909-T01-IM6_17_7577121_G_A  Missense_Mutation
# 2  P-0023546-T01-IM6    P-0023546-T01-IM6_17_7578442_T_C  Missense_Mutation
# 3  P-0023546-T02-IM6    P-0023546-T02-IM6_17_7578442_T_C  Missense_Mutation
# 4  P-0025997-T01-IM6    P-0025997-T01-IM6_17_7578471_G_-    Frame_Shift_Del
#
#    ccf_1     vaf_1             HGVSp_1 spot_1 key_2  vc_2  ccf_2  vaf_2  \
# 0  0.925  0.168901         p.Arg174Glu    174  None  None    NaN    NaN
# 1  0.812  0.312169         p.Arg273Cys    273  None  None    NaN    NaN
# 2  0.935  0.845070         p.Tyr163Cys    163  None  None    NaN    NaN
# 3  1.000  0.636735         p.Tyr163Cys    163  None  None    NaN    NaN
# 4  1.000  0.912621  p.Gly154AlafsTer16    154  None  None    NaN    NaN
#
#   HGVSp_2 spot_2 key_3  vc_3  ccf_3  vaf_3 HGVSp_3 spot_3 key_4  vc_4  ccf_4  \
# 0    None   None  None  None    NaN    NaN    None   None  None  None    NaN
# 1    None   None  None  None    NaN    NaN    None   None  None  None    NaN
# 2    None   None  None  None    NaN    NaN    None   None  None  None    NaN
# 3    None   None  None  None    NaN    NaN    None   None  None  None    NaN
# 4    None   None  None  None    NaN    NaN    None   None  None  None    NaN
#
#    vaf_4 HGVSp_4 spot_4 key_5  vc_5  ccf_5  vaf_5 HGVSp_5 spot_5  tp53_count
# 0    NaN    None   None  None  None    NaN    NaN    None   None           1
# 1    NaN    None   None  None  None    NaN    NaN    None   None           1
# 2    NaN    None   None  None  None    NaN    NaN    None   None           1
# 3    NaN    None   None  None  None    NaN    NaN    None   None           1
# 4    NaN    None   None  None  None    NaN    NaN    None   None           1

# %% [markdown]
# ---
# ## 3. TP53 Copy Numbers

# %% [markdown]
# In this part, we gather the information from gene_level table.
# We creaste the following columns:
# * Sample_Id
# * tcn --> total copy number
# * mcn --> major copy number
# * lcn --> lower copy number
# * seg_length --> length of the segment
# * cn_state --> copy number state
# * cf --> Cell fraction of the cn_state
# * wgd --> Wholde Genome Doubling (1 or -1)

# %%
def wgd_condition(x):
    cond_wgd = ['LOSS BEFORE & AFTER', 'LOSS BEFORE', 'CNLOH BEFORE & AFTER',
           'CNLOH BEFORE', 'CNLOH BEFORE & GAIN', 'DOUBLE LOSS AFTER',
           'LOSS AFTER', 'CNLOH AFTER', 'LOSS & GAIN']
    cond_no_wgd = ['CNLOH', 'HETLOSS', 'CNLOH & GAIN', 'DIPLOID']
    
    for cn_state in list(arm_level[arm_level['sample'] == x.Sample_Id]['cn_state']):
        if cn_state in cond_wgd:
            return 1
        
    if x.cn_state in cond_no_wgd :
        return -1

# %%
def create_copy_number_state(sample_info, path):
    arm_level = pd.read_csv(data_path + 'impact-facets-tp53/raw/default_qc_pass.arm_level.txt', sep='\t')
    
    gene_level = pd.read_csv(path, sep='\t')
    gene_level['Tumor_Id'] = gene_level['sample'].str[:17]
    gene_level_subset = gene_level[['sample','tcn','mcn','lcn','seg_length','cn_state', 'cf.em']]
    
    # We add the cohort patients that are not in the dataframe
    #First we create a dataframe with all missing samples
    cohort_samples = set(sample_info.Sample_Id)
    gene_level_samples = set(gene_level_subset['sample'])
    missing_samp = pd.DataFrame(cohort_samples - gene_level_samples, columns = ['sample'])
    
    
    #Then we append the two dataframe
    gene_level_subset = gene_level_subset.append(missing_samp)
    
    # We rename the cf.em column 
    gene_level_subset = gene_level_subset.rename(columns={'cf.em': 'cf', 'sample':'Sample_Id'})
    
    # We add WGD information
    gene_level_subset['wgd'] = gene_level_subset.apply(wgd_condition, axis = 1)
    
    return gene_level_subset

# %%
def compute_frac_genome(x):
    lookup_table = arm_level[arm_level['sample'] == x.Sample_Id]
    lookup_table_altered = lookup_table[lookup_table['cn_state'] != 'DIPLOID']
    altered_length = lookup_table_altered.cn_length.sum()
    total_length = lookup_table.arm_length.sum()
    
    frac_gen_altered = round(altered_length/total_length,3)
    
    return frac_gen_altered

# Here is the function that allws to compute genome instability columns
def chr_computations(x):
    CNLOH = ['CNLOH', 'CNLOH BEFORE & LOSS', 'CNLOH AFTER', 'CNLOH BEFORE', 'CNLOH & GAIN', 'CNLOH BEFORE & GAIN', 'AMP (LOH)']
    LOSS = ['HETLOSS', 'LOSS BEFORE', 'LOSS AFTER', 'HOMDEL', 'LOSS BEFORE & AFTER', 'DOUBLE LOSS AFTER']
    GAIN = ['GAIN', 'AMP', 'AMP (BALANCED)', 'LOSS & GAIN', 'TETRAPLOID']
    
    lookup_table = arm_level[arm_level['sample'] == x.Sample_Id]
    lookup_table['chr'] = lookup_table.arm.str.extract('(\d+)')
    lookup_table = lookup_table[lookup_table['cn_state'] != 'DIPLOID'][lookup_table['chr'] != '17']
    lookup_table['state_chr'] = lookup_table['cn_state']+lookup_table['chr']
    #chr_affected colum
    lookup_table_chr = lookup_table.drop_duplicates(subset=['chr'])
    chr_affected = len(lookup_table_chr)
    
    #chr_loss, chr_gain, chr_cnloh columns
    lookup_table_events = lookup_table.drop_duplicates(subset=['state_chr'])
    chr_loss = len(lookup_table_events[lookup_table_events.cn_state.isin(LOSS)])
    chr_gain = len(lookup_table_events[lookup_table_events.cn_state.isin(GAIN)])
    chr_cnloh = len(lookup_table_events[lookup_table_events.cn_state.isin(CNLOH)])
    
    #frac_gen_altered column
    frac_gen_altered = compute_frac_genome(x)
    
    return [chr_affected, chr_loss, chr_gain, chr_cnloh, frac_gen_altered]

# %%
sample_info
# Out:
#                                   Sample_Id           Tumor_Id Patient_Id  \
# 0       P-0034223-T01-IM6_P-0034223-N01-IM6  P-0034223-T01-IM6  P-0034223
# 6       P-0009819-T01-IM5_P-0009819-N01-IM5  P-0009819-T01-IM5  P-0009819
# 9       P-0025956-T01-IM6_P-0025956-N01-IM6  P-0025956-T01-IM6  P-0025956
# 15      P-0027408-T01-IM6_P-0027408-N01-IM6  P-0027408-T01-IM6  P-0027408
# 36      P-0006554-T01-IM5_P-0006554-N01-IM5  P-0006554-T01-IM5  P-0006554
# ...                                     ...                ...        ...
# 260784  P-0050644-T01-IM6_P-0050644-N01-IM6  P-0050644-T01-IM6  P-0050644
# 260787  P-0050741-T01-IM6_P-0050741-N01-IM6  P-0050741-T01-IM6  P-0050741
# 260795  P-0050747-T01-IM6_P-0050747-N01-IM6  P-0050747-T01-IM6  P-0050747
# 260801  P-0050652-T01-IM6_P-0050652-N01-IM6  P-0050652-T01-IM6  P-0050652
# 260804  P-0050745-T01-IM6_P-0050745-N01-IM6  P-0050745-T01-IM6  P-0050745
#
#                        Cancer_Type Sample_Type    purity    ploidy  \
# 0                    Breast Cancer  Metastasis  0.941111  2.241830
# 6                  Prostate Cancer     Primary  0.275237  2.681075
# 9       Non-Small Cell Lung Cancer     Primary  0.185874  3.496971
# 15      Non-Small Cell Lung Cancer  Metastasis  0.308886  1.811066
# 36                          Glioma     Primary  0.715208  1.910719
# ...                            ...         ...       ...       ...
# 260784             Prostate Cancer     Primary  0.576103  2.175837
# 260787      Small Cell Lung Cancer  Metastasis  0.833591  2.006039
# 260795           Pancreatic Cancer     Primary  0.360576  2.187990
# 260801           Pancreatic Cancer     Primary  0.171442  2.011650
# 260804               Breast Cancer     Primary  0.597798  1.808634
#
#         samples_per_patient Overall Survival Status  \
# 0                       1.0                  LIVING
# 6                       1.0                  LIVING
# 9                       1.0                DECEASED
# 15                      1.0                  LIVING
# 36                      1.0                  LIVING
# ...                     ...                     ...
# 260784                  1.0                  LIVING
# 260787                  1.0                  LIVING
# 260795                  1.0                  LIVING
# 260801                  1.0                  LIVING
# 260804                  1.0                  LIVING
#
#         Overall Survival (Months)  MSI Score
# 0                             NaN       0.55
# 6                          23.441       0.00
# 9                           3.584       0.00
# 15                         22.586       0.27
# 36                         26.170       1.30
# ...                           ...        ...
# 260784                      1.249       0.00
# 260787                      1.940       0.22
# 260795                        NaN       0.05
# 260801                      1.085       0.26
# 260804                      1.841       1.85
#
# [29304 rows x 11 columns]

# %%
arm_level = pd.read_csv(data_path + 'impact-facets-tp53/raw/default_qc_pass.arm_level.txt', sep='\t')
lookup_table = arm_level[arm_level['sample'] == 'P-0034223-T01-IM6_P-0034223-N01-IM6']
lookup_table_altered = lookup_table[lookup_table['cn_state'] != 'DIPLOID']
display(lookup_table)
altered_length = lookup_table_altered.cn_length.sum()
total_length = lookup_table.arm_length.sum()
frac_gen_altered = round(altered_length/total_length,3)
frac_gen_altered
# Out:
#                                  sample  arm  tcn  lcn  cn_length  arm_length  \
# 0   P-0034223-T01-IM6_P-0034223-N01-IM6   1p    2    1  120534257   120534257
# 1   P-0034223-T01-IM6_P-0034223-N01-IM6   1q    4    1  101461100   125135032
# 2   P-0034223-T01-IM6_P-0034223-N01-IM6   2p    2    1   87764506    87764506
# 3   P-0034223-T01-IM6_P-0034223-N01-IM6   2q    2    1  150656179   150656179
# 4   P-0034223-T01-IM6_P-0034223-N01-IM6   3p    2    1   89055004    89055004
# 5   P-0034223-T01-IM6_P-0034223-N01-IM6   3q    2    1  106857923   106857923
# 6   P-0034223-T01-IM6_P-0034223-N01-IM6   4p    2    1   48257537    48257537
# 7   P-0034223-T01-IM6_P-0034223-N01-IM6   4q    2    1  140602481   140602481
# 8   P-0034223-T01-IM6_P-0034223-N01-IM6   5p    2    1   46187241    46187241
# 9   P-0034223-T01-IM6_P-0034223-N01-IM6   5q    2    1  134121897   134121897
# 10  P-0034223-T01-IM6_P-0034223-N01-IM6   6p    2    1   58437159    58437159
# 11  P-0034223-T01-IM6_P-0034223-N01-IM6   6q    2    1  111968888   111968888
# 12  P-0034223-T01-IM6_P-0034223-N01-IM6   7p    2    1   56381732    56381732
# 13  P-0034223-T01-IM6_P-0034223-N01-IM6   7q    2    1  100573669   100573669
# 14  P-0034223-T01-IM6_P-0034223-N01-IM6   8q    2    1  102347589   102347589
# 15  P-0034223-T01-IM6_P-0034223-N01-IM6   9p    2    1   46945819    46945819
# 16  P-0034223-T01-IM6_P-0034223-N01-IM6   9q    2    1   92452921    92452921
# 17  P-0034223-T01-IM6_P-0034223-N01-IM6  10p    2    1   37744888    37744888
# 18  P-0034223-T01-IM6_P-0034223-N01-IM6  10q    2    1   95926530    95926530
# -1.0  17920
#  1.0   9286

# %% [markdown]
# ---
# ## 4. TP53 Computed Metrics

# %% [markdown]
# In this part, we compute mainly 4 metrics:
#
# * mutation_count (*create_mut_count*) --> It is the total mutation count per sample
# * gene_count (*create_gene_count*)--> It is the number of mutated genes per sample
# * max_vaf --> It is the maximum Variant Allele Frequency within all the mutations of a sample
# * exp_nb_1 (2,3,4,5) --> It is the expected number of copies of tp53 mutations in a cell

# %%
def create_gene_count(maf_cohort):
    '''
    This function create the count of genes mutated for each sample.
    Arguments:
        - maf_cohort: the maf_cohort file located in data/merged/data
    '''
    
    # First we create the gene_count table by groupbying and sizing, we then change the index
    selected_cohort = maf_cohort[['Sample_Id','Tumor_Id', 'Gene_Id']]
    gene_count = pd.DataFrame(pd.DataFrame(selected_cohort[['Sample_Id', 'Gene_Id']].groupby(['Sample_Id', 'Gene_Id']).size(), columns = ['count']).groupby(['Sample_Id']).size(), columns = ['gene_count'])
    gene_count = gene_count.reset_index()

    # We add missing patients to the gene_count to have all the cohort
    no_gene_id = selected_cohort.Gene_Id.isna()
    no_gene_samples = set(selected_cohort[selected_cohort.index.isin(list(no_gene_id[no_gene_id == True].index))]['Sample_Id'])
    missing_samp = pd.DataFrame(no_gene_samples, columns = ['Sample_Id'])

    # We append the two dataframes
    gene_count = gene_count.append(missing_samp)
    
    #Fillna with 0
    gene_count = gene_count.fillna(0)

    return gene_count

def create_mut_count(maf_cohort):
    '''
    This function computes the dataframe of mutation count per sample.
    '''
    selected_cohort = maf_cohort[['Sample_Id','Tumor_Id', 'Gene_Id']]
    mut_count = get_groupby(selected_cohort, 'Sample_Id', 'mutation_count')
    
    return mut_count

# The following function needs to be called on the complete master file because it needs info from different parts
def create_copies_tp53_muts(master):
    master['exp_nb_1'] = master.apply(lambda x:(x.vaf_1 / x.purity) * (x.tcn * x.purity + 2*(1 - x.purity)), axis = 1)
    master['exp_nb_2'] = master.apply(lambda x:(x.vaf_2 / x.purity) * (x.tcn * x.purity + 2*(1 - x.purity)), axis = 1)
    master['exp_nb_3'] = master.apply(lambda x:(x.vaf_3 / x.purity) * (x.tcn * x.purity + 2*(1 - x.purity)), axis = 1)
    master['exp_nb_4'] = master.apply(lambda x:(x.vaf_4 / x.purity) * (x.tcn * x.purity + 2*(1 - x.purity)), axis = 1)
    master['exp_nb_5'] = master.apply(lambda x:(x.vaf_5 / x.purity) * (x.tcn * x.purity + 2*(1 - x.purity)), axis = 1)
    
    return master


def vc_group_cond_1(x):
    truncated = ['Splice_Site','Intron','Nonsense_Mutation','Splice_Region','Frame_Shift_Del','Frame_Shift_Ins']
    in_frame = ['In_Frame_Ins','In_Frame_Del']
    missense = ['Missense_Mutation']
    
    if x.vc_1 in truncated: return 'truncated'
    if x.vc_1 in in_frame: return 'in_frame'
    if x.vc_1 in missense: return 'missense'
def vc_group_cond_2(x):
    truncated = ['Splice_Site','Intron','Nonsense_Mutation','Splice_Region','Frame_Shift_Del','Frame_Shift_Ins']
    in_frame = ['In_Frame_Ins','In_Frame_Del']
    missense = ['Missense_Mutation']
    
    if x.vc_2 in truncated: return 'truncated'
    if x.vc_2 in in_frame: return 'in_frame'
    if x.vc_2 in missense: return 'missense'   
def vc_group_cond_3(x):
    truncated = ['Splice_Site','Intron','Nonsense_Mutation','Splice_Region','Frame_Shift_Del','Frame_Shift_Ins']
    in_frame = ['In_Frame_Ins','In_Frame_Del']
    missense = ['Missense_Mutation']
    
    if x.vc_3 in truncated: return 'truncated'
    if x.vc_3 in in_frame: return 'in_frame'
    if x.vc_3 in missense: return 'missense'  
def vc_group_cond_4(x):
    truncated = ['Splice_Site','Intron','Nonsense_Mutation','Splice_Region','Frame_Shift_Del','Frame_Shift_Ins']
    in_frame = ['In_Frame_Ins','In_Frame_Del']
    missense = ['Missense_Mutation']
    
    if x.vc_4 in truncated: return 'truncated'
    if x.vc_4 in in_frame: return 'in_frame'
    if x.vc_4 in missense: return 'missense'
def vc_group_cond_5(x):
    truncated = ['Splice_Site','Intron','Nonsense_Mutation','Splice_Region','Frame_Shift_Del','Frame_Shift_Ins']
    in_frame = ['In_Frame_Ins','In_Frame_Del']
    missense = ['Missense_Mutation']
    
    if x.vc_5 in truncated: return 'truncated'
    if x.vc_5 in in_frame: return 'in_frame'
    if x.vc_5 in missense: return 'missense'

# %%
def create_computed_metrics(path):
    # We add mutation_count and max_vaf
    maf_cohort = pd.read_pickle(path)

    # MUTATION COUNT
    #We create the table for mutation_count
    mut_count = create_mut_count(maf_cohort)
    
    # We create the table for gene_count
    gene_count = create_gene_count(maf_cohort)

    # MAX_VAF
    # To do so, we groupby Tumor_Id and apply the max() function
    # But first we need to transform None values in Nan to compute the max
    maf_cohort['vaf'].replace('None', np.nan, inplace=True)
    max_vaf = maf_cohort[['Sample_Id','vaf']].groupby(['Sample_Id']).max()
    max_vaf = max_vaf.rename(columns={'vaf': 'max_vaf'})
    
    # Merge the tables
    computed_metrics = pd.merge(mut_count, gene_count, on=['Sample_Id'])
    computed_metrics = pd.merge(computed_metrics, max_vaf, on=['Sample_Id'])
    
    
    return computed_metrics

# %%
computed_metrics = create_computed_metrics(data_path + 'merged_data/maf_cohort.pkl')
computed_metrics.head()
# Out:
#                              Sample_Id  mutation_count  gene_count   max_vaf
# 0  P-0000004-T01-IM3_P-0000004-N01-IM3               4         4.0  0.547085
# 1  P-0000012-T02-IM3_P-0000012-N01-IM3               1         1.0  0.502203
# 2  P-0000024-T01-IM3_P-0000024-N01-IM3               6         5.0  0.368683
# 3  P-0000025-T02-IM5_P-0000025-N01-IM5               2         2.0  0.203236
# 4  P-0000026-T01-IM3_P-0000026-N01-IM3               4         4.0  0.590164

# %% [markdown]
# ## 5. Subgroup Columns Creation

# %% [markdown]
# #### First, we group the different COpy Number States *cn_state* in subgroups, under the column *cn_group*:
# * Group 1: cnLOH gathering ['CNLOH', 'CNLOH BEFORE & LOSS', 'CNLOH BEFORE', 'CNLOH BEFORE & GAIN']
# * Group 2: LOSS gathering ['LOSS BEFORE', 'HETLOSS', 'LOSS BEFORE & AFTER']
# * Group 3: HOMDEL gathering ['HOMDEL']
# * Group 4: DOUBLE LOSS AFTER gathering ['DOUBLE LOSS AFTER']
# * Group 5: WILD_TYPE gathering ['LOSS AFTER', 'DIPLOID', 'TETRAPLOID']
# * Group 6: GAIN gathering ['GAIN']
# * Group 7: OTHER gathering ['CNLOH AFTER', 'AMP (BALANCED)', 'AMP (LOH)', 'AMP','LOSS & GAIN', 'CNLOH & GAIN']
#
#
# Based on this first column we define 7 final groups of patients adding the mutational information. These groups will be under the column *mut_cn_group*.
# * Group 1: Samples with 0 tp53 mutations and HETLOSS
# * Group 2: Samples with HOMDEL
# * Group 3: Samples with 1 tp53 mutation and WILD_TYPE (DIPLOID, LOSS AFTER, TETRAPLOID)
# * Group 4: Samples with 1 tp53 mutation or more and LOSS
# * Group 5: Samples with 1 tp53 mutation or more and cnLOH
# * Group 6: Samples with 2/3/4/5 tp53 mutations and WILD_TYPE or GAIN
#
# We define the columns thanks to 2 functions that we call in the **Merge Tables** part through *create_master* function.

# %%
def cn_group_cond(x):
    if x.cn_state in ['CNLOH', 'CNLOH BEFORE & LOSS', 'CNLOH BEFORE', 'CNLOH BEFORE & GAIN']:
        return 'cnLOH'
    if x.cn_state in ['LOSS BEFORE', 'HETLOSS', 'LOSS BEFORE & AFTER']:
        return 'LOSS'
    if x.cn_state == 'HOMDEL':
        return 'HOMDEL'
    if x.cn_state in ['LOSS AFTER', 'DIPLOID', 'TETRAPLOID']:
        return 'WILD_TYPE'
    if x.cn_state == 'DOUBLE LOSS AFTER':
        return 'DOUBLE LOSS AFTER'
    if x.cn_state == 'GAIN':
        return 'GAIN'
    if x.cn_state in ['CNLOH AFTER', 'AMP (BALANCED)', 'AMP (LOH)', 'AMP','LOSS & GAIN', 'CNLOH & GAIN']:
        return 'OTHER'

def mut_cn_group_cond(x):
    if x.cn_state == 'HETLOSS' and x.tp53_count == 0:
        return '0_HETLOSS'
    if x.cn_group == 'HOMDEL':
        return 'HOMDEL'
    if x.cn_group == 'WILD_TYPE' and x.tp53_count == 1 :
        return '1_WILD_TYPE'
    if x.cn_group == 'LOSS' and x.tp53_count >=1:
        return '>=1_LOSS'
    if x.cn_group == 'cnLOH' and x.tp53_count >=1:
        return '>=1_cnLOH'
    if (x.cn_group == 'WILD_TYPE' or x.cn_group == 'DOUBLE LOSS AFTER' or x.cn_group == 'GAIN') and x.tp53_count > 1:
        return '>1muts'

# %% [markdown]
# ---
# ## 5. Merge Tables

# %%
def create_master():
    '''
    This function creates the tables and merges them.
    '''
    sample_info = create_sample_info(data_path + 'merged_data/maf_cohort.pkl')
    tp53_muts = create_tp53_muts(sample_info, data_path + 'merged_data/maf_tp53.pkl')
    
    # We load the copy number table if it is already stored 
    file = Path(data_path + 'merged_data/copy_number.pkl')
    if file.is_file():
        copy_number_state =  pd.read_pickle(data_path + 'merged_data/copy_number.pkl')
    else:
        copy_number_state = create_copy_number_state(sample_info, data_path + 'impact-facets-tp53/raw/default_qc_pass.gene_level_TP53.txt')
    computed_metrics = create_computed_metrics(data_path + 'merged_data/maf_cohort.pkl')
    
    # We first merge sample_info and tp53_muts because they have the same list of keys
    master_file = pd.merge(sample_info, tp53_muts, on=['Tumor_Id'])
    #For copy_number_state we have to do a right join because it contains less Tumor_Ids
    master_file = pd.merge(master_file, copy_number_state, on=['Sample_Id'])
    # Finally we merge the computedmetrics table
    master_file = pd.merge(master_file, computed_metrics, on=['Sample_Id'])
    
    # We filter out the sample duplicates
    master_file = master_file.drop_duplicates('Sample_Id')
    
    # At this step we need to remove samples that comes from same tumor but different normal sample
    # BUT this step makes us loose important clinical information for some samples
    # So we wil spread the Patient_Id and Cancer_Type by front and backpropagating the non-NaN values
    master_file['Patient_Id'] = master_file.Tumor_Id.str[:9]
    master_file['Cancer_Type'] = master_file[['Patient_Id','Cancer_Type']].groupby(['Patient_Id']).bfill().ffill()
    
    # Then we filter out samples with the same Tumor_Id but different Sample_Id with a filter function
    master_file = normal_samp_duplicates_filter(master_file, 'Sample_Id', 'purity')
    master_file = normal_samp_duplicates_filter(master_file, 'Sample_Id', 'purity')
    
    #We compute the expected number of copies of tp53 mutations
    master_file = create_copies_tp53_muts(master_file)
    
    #Finally we add the subgroup columns defined in Part 5
    master_file['cn_group'] = master_file.apply(cn_group_cond, axis = 1)
    master_file['mut_cn_group'] = master_file.apply(mut_cn_group_cond, axis = 1)
    
    # We add Genome Instability columns
    # Genome Instability columns computed from arm_level file
    arm_level = pd.read_csv(data_path + 'impact-facets-tp53/raw/default_qc_pass.arm_level.txt', sep='\t')
    arm_level['chr'] = arm_level.arm.str.extract('(\d+)')
    print('checkpoint_1')
    master_file['chr_comput'] = master_file.apply(chr_computations, axis=1)
    print('checkpoint_2')
    master_file[['chr_affected', 'chr_loss', 'chr_gain', 'chr_cnloh', 'frac_genome_altered']] = pd.DataFrame(master_file.chr_comput.values.tolist(), index= master_file.index)
    print('checkpoint_3')
    
    # Grouping the Variant Classificationb into 3 Classes
    master_file['vc_group_1'] = master_file.apply(vc_group_cond_1, axis = 1)
    master_file['vc_group_2'] = master_file.apply(vc_group_cond_2, axis = 1)
    master_file['vc_group_3'] = master_file.apply(vc_group_cond_3, axis = 1)
    master_file['vc_group_4'] = master_file.apply(vc_group_cond_4, axis = 1)
    master_file['vc_group_5'] = master_file.apply(vc_group_cond_5, axis = 1)
    return master_file

# %%
# %%time
master_file = create_master()
# Out:
# checkpoint_1
# checkpoint_2
# checkpoint_3
# CPU times: user 51min 2s, sys: 2.27 s, total: 51min 5s
# Wall time: 51min 6s

# %%
master_file
# Out:
#                                  Sample_Id           Tumor_Id Patient_Id  \
# 0      P-0034223-T01-IM6_P-0034223-N01-IM6  P-0034223-T01-IM6  P-0034223
# 1      P-0009819-T01-IM5_P-0009819-N01-IM5  P-0009819-T01-IM5  P-0009819
# 2      P-0025956-T01-IM6_P-0025956-N01-IM6  P-0025956-T01-IM6  P-0025956
# 3      P-0027408-T01-IM6_P-0027408-N01-IM6  P-0027408-T01-IM6  P-0027408
# 4      P-0006554-T01-IM5_P-0006554-N01-IM5  P-0006554-T01-IM5  P-0006554
# ...                                    ...                ...        ...
# 29299  P-0050644-T01-IM6_P-0050644-N01-IM6  P-0050644-T01-IM6  P-0050644
# 29300  P-0050741-T01-IM6_P-0050741-N01-IM6  P-0050741-T01-IM6  P-0050741
# 29301  P-0050747-T01-IM6_P-0050747-N01-IM6  P-0050747-T01-IM6  P-0050747
# 29302  P-0050652-T01-IM6_P-0050652-N01-IM6  P-0050652-T01-IM6  P-0050652
# 29303  P-0050745-T01-IM6_P-0050745-N01-IM6  P-0050745-T01-IM6  P-0050745
#
#                       Cancer_Type Sample_Type    purity    ploidy  \
# 0                   Breast Cancer  Metastasis  0.941111  2.241830
# 1                 Prostate Cancer     Primary  0.275237  2.681075
# 2      Non-Small Cell Lung Cancer     Primary  0.185874  3.496971
# 3      Non-Small Cell Lung Cancer  Metastasis  0.308886  1.811066
# 4                          Glioma     Primary  0.715208  1.910719
# ...                           ...         ...       ...       ...
# 29299             Prostate Cancer     Primary  0.576103  2.175837
# 29300      Small Cell Lung Cancer  Metastasis  0.833591  2.006039
# 29301           Pancreatic Cancer     Primary  0.360576  2.187990
# 29302           Pancreatic Cancer     Primary  0.171442  2.011650
# 29303               Breast Cancer     Primary  0.597798  1.808634
#
#        samples_per_patient Overall Survival Status  Overall Survival (Months)  \
# 0                      1.0                  LIVING                        NaN
# 1                      1.0                  LIVING                     23.441
# 2                      1.0                DECEASED                      3.584
# 3                      1.0                  LIVING                     22.586
# 4                      1.0                  LIVING                     26.170
# ...                    ...                     ...                        ...
# 29299                  1.0                  LIVING                      1.249
# 29300                  1.0                  LIVING                      1.940
# 29301                  1.0                  LIVING                        NaN
# 29302                  1.0                  LIVING                      1.085
# 29303                  1.0                  LIVING                      1.841
#
#        MSI Score  TMB_Score                               key_1  \
# 0           0.55        5.3                                None
# 1           0.00        1.0                                None
# 2           0.00        5.3                                None
# 3           0.27       17.6  P-0027408-T01-IM6_17_7578409_CT_TC
# 4           1.30       46.2                                None
# ...          ...        ...                                 ...
# 29299       0.00        0.9                                None
# 29300       0.22        7.0    P-0050741-T01-IM6_17_7578394_T_A
# 29301       0.05        6.1    P-0050747-T01-IM6_17_7577570_C_T
# 29302       0.26        2.6    P-0050652-T01-IM6_17_7578208_T_C
# 29303       1.85        5.3    P-0050745-T01-IM6_17_7577079_C_A
#
#                     vc_1  ccf_1     vaf_1      HGVSp_1 spot_1 key_2  vc_2  \
# 0                   None    NaN       NaN         None   None  None  None
# 1                   None    NaN       NaN         None   None  None  None
# 2                   None    NaN       NaN         None   None  None  None
# 3      Missense_Mutation  0.925  0.168901  p.Arg174Glu    174  None  None
# 4                   None    NaN       NaN         None   None  None  None
# ...                  ...    ...       ...          ...    ...   ...   ...
# 29299               None    NaN       NaN         None   None  None  None
# 29300  Missense_Mutation  1.000  0.757801  p.His179Leu    179  None  None
# 29301  Missense_Mutation  0.937  0.168975  p.Met237Ile    237  None  None
# 29302  Missense_Mutation    NaN  0.082168  p.His214Arg    214  None  None
# 29303  Nonsense_Mutation  0.994  0.428571  p.Glu287Ter    287  None  None
#
#        ccf_2  vaf_2 HGVSp_2 spot_2 key_3  vc_3  ccf_3  vaf_3 HGVSp_3 spot_3  \
# 0        NaN    NaN    None   None  None  None    NaN    NaN    None   None
# 1        NaN    NaN    None   None  None  None    NaN    NaN    None   None
# 2        NaN    NaN    None   None  None  None    NaN    NaN    None   None
# 3        NaN    NaN    None   None  None  None    NaN    NaN    None   None
# 4        NaN    NaN    None   None  None  None    NaN    NaN    None   None
# ...      ...    ...     ...    ...   ...   ...    ...    ...     ...    ...
# 29299    NaN    NaN    None   None  None  None    NaN    NaN    None   None
# 29300    NaN    NaN    None   None  None  None    NaN    NaN    None   None
# 29301    NaN    NaN    None   None  None  None    NaN    NaN    None   None
# 29302    NaN    NaN    None   None  None  None    NaN    NaN    None   None
# 29303    NaN    NaN    None   None  None  None    NaN    NaN    None   None
#
#       key_4  vc_4  ccf_4  vaf_4 HGVSp_4 spot_4 key_5  vc_5  ccf_5  vaf_5  \
# 0      None  None    NaN    NaN    None   None  None  None    NaN    NaN
# 1      None  None    NaN    NaN    None   None  None  None    NaN    NaN
# 2      None  None    NaN    NaN    None   None  None  None    NaN    NaN
# 3      None  None    NaN    NaN    None   None  None  None    NaN    NaN
# 4      None  None    NaN    NaN    None   None  None  None    NaN    NaN
# ...     ...   ...    ...    ...     ...    ...   ...   ...    ...    ...
# 29299  None  None    NaN    NaN    None   None  None  None    NaN    NaN
# 29300  None  None    NaN    NaN    None   None  None  None    NaN    NaN
# 29301  None  None    NaN    NaN    None   None  None  None    NaN    NaN
# 29302  None  None    NaN    NaN    None   None  None  None    NaN    NaN
# 29303  None  None    NaN    NaN    None   None  None  None    NaN    NaN
#
#       HGVSp_5 spot_5  tp53_count  tcn  mcn  lcn  seg_length       cn_state  \
# 0        None   None           0  2.0  1.0  1.0  80668592.0        DIPLOID
# 1        None   None           0  1.0  1.0  0.0  80668309.0        HETLOSS
# 2        None   None           0  NaN  NaN  NaN         NaN            NaN
# 3        None   None           1  1.0  1.0  0.0  25260272.0        HETLOSS
# 4        None   None           0  2.0  NaN  NaN   7465132.0  INDETERMINATE
# ...       ...    ...         ...  ...  ...  ...         ...            ...
# 29299    None   None           0  2.0  1.0  1.0  80668455.0        DIPLOID
# 29300    None   None           1  1.0  1.0  0.0  21694879.0        HETLOSS
# 29301    None   None           1  1.0  1.0  0.0  18461117.0        HETLOSS
# 29302    None   None           1  2.0  1.0  1.0  28981250.0        DIPLOID
# 29303    None   None           1  1.0  1.0  0.0  29307621.0        HETLOSS
#
#              cf  wgd  mutation_count  gene_count   max_vaf  exp_nb_1  \
# 0      1.000000 -1.0               6         6.0  0.901899       NaN
# 1      0.154578 -1.0               3         3.0  0.148014       NaN
# 2           NaN  NaN               6         6.0  0.200000       NaN
# 3      0.315621 -1.0              21        19.0  0.192475  0.924711
# 4           NaN  NaN              47        39.0  0.706897       NaN
# ...         ...  ...             ...         ...       ...       ...
# 29299  1.000000 -1.0               3         3.0  0.300000       NaN
# 29300  0.824066 -1.0               8         8.0  0.757801  1.060359
# 29301  0.254038 -1.0               6         6.0  0.270471  0.768275
# 29302  1.000000 -1.0               3         3.0  0.086842  0.958552
# 29303  0.602685 -1.0               9         9.0  0.451400  1.005263
#
#        exp_nb_2  exp_nb_3  exp_nb_4  exp_nb_5   cn_group mut_cn_group  \
# 0           NaN       NaN       NaN       NaN  WILD_TYPE         None
# 1           NaN       NaN       NaN       NaN       LOSS    0_HETLOSS
# 2           NaN       NaN       NaN       NaN       None         None
# 3           NaN       NaN       NaN       NaN       LOSS     >=1_LOSS
# 4           NaN       NaN       NaN       NaN       None         None
# ...         ...       ...       ...       ...        ...          ...
# 29299       NaN       NaN       NaN       NaN  WILD_TYPE         None
# 29300       NaN       NaN       NaN       NaN       LOSS     >=1_LOSS
# 29301       NaN       NaN       NaN       NaN       LOSS     >=1_LOSS
# 29302       NaN       NaN       NaN       NaN  WILD_TYPE  1_WILD_TYPE
# 29303       NaN       NaN       NaN       NaN       LOSS     >=1_LOSS
#
#                   chr_comput  chr_affected  chr_loss  chr_gain  chr_cnloh  \
# 0         [3, 2, 2, 0, 0.08]             3         2         2          0
# 1        [4, 4, 0, 0, 0.137]             4         4         0          0
# 2          [0, 0, 0, 0, nan]             0         0         0          0
# 3      [12, 11, 3, 0, 0.452]            12        11         3          0
# 4        [5, 4, 1, 0, 0.173]             5         4         1          0
# ...                      ...           ...       ...       ...        ...
# 29299    [7, 7, 0, 0, 0.144]             7         7         0          0
# 29300     [6, 5, 2, 0, 0.23]             6         5         2          0
# 29301    [5, 5, 1, 0, 0.192]             5         5         1          0
# 29302    [2, 1, 0, 1, 0.088]             2         1         0          1
# 29303    [7, 7, 0, 0, 0.693]             7         7         0          0
#
#        frac_genome_altered vc_group_1 vc_group_2 vc_group_3 vc_group_4  \
# 0                    0.080       None       None       None       None
# 1                    0.137       None       None       None       None
# 2                      NaN       None       None       None       None
# 3                    0.452   missense       None       None       None
# 4                    0.173       None       None       None       None
# ...                    ...        ...        ...        ...        ...
# 29299                0.144       None       None       None       None
# 29300                0.230   missense       None       None       None
# 29301                0.192   missense       None       None       None
# 29302                0.088   missense       None       None       None
# 29303                0.693  truncated       None       None       None
#
#       vc_group_5
# 0           None
# 1           None
# 2           None
# 3           None
# 4           None
# ...          ...
# 29299       None
# 29300       None
# 29301       None
# 29302       None
# 29303       None
#
# [29259 rows x 71 columns]

# %%
print('Number of samples: ' + str(len(set(master_file.Tumor_Id))))
print('Number of patients: ' + str(len(set(master_file.Patient_Id))))
print('Number of tp53 positive samples: ' + str( len(set(master_file.Tumor_Id)) - master_file.key_1.isna().sum()))
print('Number of tp53 positive patients: ' + str( len(set(master_file.Patient_Id)) - master_file.drop_duplicates('Patient_Id').key_1.isna().sum()))
print('Number of samples with missing wgd : ' + str(master_file.wgd.isna().sum()))
print('Number of samples with missing cf : ' + str(master_file.cf.isna().sum()))
print('Number of samples with missing max_vaf : ' + str(master_file.max_vaf.isna().sum()))
print('Number of samples with missing Cn state: ' + str(master_file.cn_state.isna().sum()))
print('Number of samples with missing Sample_Type : ' + str(master_file.Sample_Type.isna().sum()))
# Out:
# Number of samples: 29259
# Number of patients: 27021
# Number of tp53 positive samples: 12731
# Number of tp53 positive patients: 11885
# Number of samples with missing wgd : 2092
# Number of samples with missing cf : 1746
# Number of samples with missing max_vaf : 1421
# Number of samples with missing Cn state: 517
# Number of samples with missing Sample_Type : 104

# %%
# Saving to pickle File
master_file.to_pickle(data_path + 'merged_data/master_file.pkl')

# %%
master_file[master_file['wgd'] == 1].describe()
# Out:
#             purity       ploidy  samples_per_patient  \
# count  9272.000000  9272.000000          9266.000000
# mean      0.477368     3.185226             1.283510
# std       0.188877     0.567033             0.639602
# min       0.122458     1.376369             1.000000
# 25%       0.323767     2.798844             1.000000
# 50%       0.450435     3.133504             1.000000
# 75%       0.611323     3.492561             1.000000
# max       0.968505     6.724265             9.000000
#
#        Overall Survival (Months)    MSI Score        ccf_1        vaf_1  \
# count                8750.000000  9265.000000  5268.000000  6025.000000
# mean                   18.343750     1.146893     0.903747     0.457104
# std                    15.825557     1.980211     0.151989     0.211558
# min                     0.000000    -1.000000     0.001000     0.020833
# 25%                     5.655000     0.210000     0.861750     0.289655
# 50%                    13.512000     0.660000     0.972000     0.428721
# 75%                    27.847000     1.460000     1.000000     0.603064
# max                    73.118000    39.600000     1.000000     0.992523
#
#             ccf_2       vaf_2      ccf_3      vaf_3  ccf_4     vaf_4  ccf_5  \
# count  323.000000  357.000000  21.000000  27.000000    2.0  6.000000  1.000
# mean     0.736220    0.277294   0.738286   0.284815    1.0  0.278522  0.612
# std      0.258898    0.165031   0.329655   0.201141    0.0  0.120586    NaN
# min      0.029000    0.023593   0.107000   0.026432    1.0  0.136111  0.612
# 25%      0.533000    0.156475   0.419000   0.141049    1.0  0.177837  0.612
# 50%      0.830000    0.246166   0.917000   0.255076    1.0  0.287632  0.612
# 75%      0.989500    0.363073   1.000000   0.366050    1.0  0.361761  0.612
# max      1.000000    0.919643   1.000000   0.930791    1.0  0.432049  0.612
#
#           vaf_5   tp53_count          tcn          mcn          lcn  \
# count  2.000000  9272.000000  9270.000000  8085.000000  8085.000000
# mean   0.221435     0.692731     2.540777     2.105133     0.369450
# std    0.026298     0.554211     1.256511     1.054938     0.631463
# min    0.202840     0.000000     0.000000     0.000000     0.000000
# 25%    0.212137     0.000000     2.000000     2.000000     0.000000
# 50%    0.221435     1.000000     2.000000     2.000000     0.000000
# 75%    0.230733     1.000000     3.000000     2.000000     1.000000
# max    0.240030     5.000000    76.000000    71.000000     5.000000
#
#          seg_length           cf     wgd  mutation_count   gene_count  \
# count  9.270000e+03  8686.000000  9272.0     9272.000000  9272.000000
# mean   3.352478e+07     0.470042     1.0        8.488676     7.788395
# std    2.532821e+07     0.240559     0.0       12.572563     9.223415
# min    4.679000e+03     0.004850     1.0        1.000000     0.000000
# 25%    1.594222e+07     0.281185     1.0        4.000000     3.000000
# 50%    2.169483e+07     0.414251     1.0        6.000000     6.000000
# 75%    4.038590e+07     0.621502     1.0        9.000000     9.000000
# max    8.096900e+07     1.000000     1.0      433.000000   216.000000
#
#            max_vaf
# count  9212.000000
# mean      0.488342
# std       0.213706
# min       0.022587
# 25%       0.321511
# 50%       0.467728
# 75%       0.642857
# max       1.000000

# %%
count = get_groupby(master_file, 'tp53_count', 'count')
100*count[1:6].sum()/count.sum()
# Out:
# count    43.511398
# dtype: float64

# %%
master_file[master_file['cn_state'] == 'LOSS AFTER']
# Out:
#                                  Sample_Id           Tumor_Id Patient_Id  \
# 37     P-0004008-T01-IM3_P-0004008-N01-IM3  P-0004008-T01-IM3  P-0004008
# 41     P-0034676-T01-IM6_P-0034676-N01-IM6  P-0034676-T01-IM6  P-0034676
# 45     P-0023185-T01-IM6_P-0023185-N01-IM6  P-0023185-T01-IM6  P-0023185
# 85     P-0004506-T01-IM5_P-0004506-N01-IM5  P-0004506-T01-IM5  P-0004506
# 88     P-0017817-T01-IM6_P-0017817-N01-IM6  P-0017817-T01-IM6  P-0017817
# ...                                    ...                ...        ...
# 29146  P-0050419-T01-IM6_P-0050419-N01-IM6  P-0050419-T01-IM6  P-0050419
# 29181  P-0050568-T01-IM6_P-0050568-N01-IM6  P-0050568-T01-IM6  P-0050568
# 29238  P-0050640-T01-IM6_P-0050640-N01-IM6  P-0050640-T01-IM6  P-0050640
# 29244  P-0042302-T02-IM6_P-0042302-N01-IM6  P-0042302-T02-IM6  P-0042302
# 29283  P-0050749-T01-IM6_P-0050749-N01-IM6  P-0050749-T01-IM6  P-0050749
#
#                       Cancer_Type Sample_Type    purity    ploidy  \
# 37                 Bladder Cancer     Primary  0.347987  3.602656
# 41                Prostate Cancer     Primary  0.340776  3.288384
# 45                 Bladder Cancer     Primary  0.168290  2.801844
# 85                Germ Cell Tumor  Metastasis  0.639988  2.721189
# 88     Non-Small Cell Lung Cancer  Metastasis  0.643735  3.239155
# ...                           ...         ...       ...       ...
# 29146          Endometrial Cancer     Primary  0.275983  4.951381
# 29181  Non-Small Cell Lung Cancer     Primary  0.468580  4.456271
# 29238              Ovarian Cancer  Metastasis  0.412215  4.461590
# 29244         Soft Tissue Sarcoma  Metastasis  0.838210  3.255732
# 29283           Colorectal Cancer     Primary  0.244127  5.075630
#
#        samples_per_patient Overall Survival Status  Overall Survival (Months)  \
# 37                     1.0                DECEASED                      6.477
# 41                     1.0                  LIVING                      0.953
# 45                     1.0                  LIVING                     29.063
# 85                     1.0                  LIVING                     57.534
# 88                     3.0                DECEASED                     34.751
# ...                    ...                     ...                        ...
# 29146                  1.0                  LIVING                      2.203
# 29181                  1.0                  LIVING                        NaN
# 29238                  1.0                  LIVING                      0.427
# 29244                  1.0                  LIVING                      1.973
# 29283                  1.0                  LIVING                      1.479
#
#        MSI Score                                    key_1             vc_1  \
# 37          0.45                                     None             None
# 41          0.10                                     None             None
# 45          0.00  P-0023185-T01-IM6_17_7578551_AGTACTGT_-      Splice_Site
# 85          1.06                                     None             None
# 88          1.63                                     None             None
# ...          ...                                      ...              ...
# 29146       0.13         P-0050419-T01-IM6_17_7578176_C_T      Splice_Site
# 29181       0.47                                     None             None
# 29238       0.42        P-0050640-T01-IM6_17_7577137_CC_-  Frame_Shift_Del
# 29244       0.92                                     None             None
# 29283       0.31                                     None             None
#
#        ccf_1     vaf_1            HGVSp_1 spot_1  \
# 37       NaN       NaN               None   None
# 41       NaN       NaN               None   None
# 45     1.000  0.242208                nan    nan
# 85       NaN       NaN               None   None
# 88       NaN       NaN               None   None
# ...      ...       ...                ...    ...
# 29146  0.931  0.331588                nan    nan
# 29181    NaN       NaN               None   None
# 29238  0.965  0.329564  p.Arg267GlnfsTer4    267
# 29244    NaN       NaN               None   None
# 29283    NaN       NaN               None   None
#
#                                   key_2               vc_2  ccf_2     vaf_2  \
# 37                                 None               None    NaN       NaN
# 41                                 None               None    NaN       NaN
# 45                                 None               None    NaN       NaN
# 85                                 None               None    NaN       NaN
# 88                                 None               None    NaN       NaN
# ...                                 ...                ...    ...       ...
# 29146  P-0050419-T01-IM6_17_7578239_C_A  Nonsense_Mutation  0.349  0.124183
# 29181                              None               None    NaN       NaN
# 29238                              None               None    NaN       NaN
# 29244                              None               None    NaN       NaN
# 29283                              None               None    NaN       NaN
#
#            HGVSp_2 spot_2 key_3  vc_3  ccf_3  vaf_3 HGVSp_3 spot_3 key_4  \
# 37            None   None  None  None    NaN    NaN    None   None  None
# 41            None   None  None  None    NaN    NaN    None   None  None
# 45            None   None  None  None    NaN    NaN    None   None  None
# 85            None   None  None  None    NaN    NaN    None   None  None
# 88            None   None  None  None    NaN    NaN    None   None  None
# ...            ...    ...   ...   ...    ...    ...     ...    ...   ...
# 29146  p.Glu204Ter    204  None  None    NaN    NaN    None   None  None
# 29181         None   None  None  None    NaN    NaN    None   None  None
# 29238         None   None  None  None    NaN    NaN    None   None  None
# 29244         None   None  None  None    NaN    NaN    None   None  None
# 29283         None   None  None  None    NaN    NaN    None   None  None
#
#        vc_4  ccf_4  vaf_4 HGVSp_4 spot_4 key_5  vc_5  ccf_5  vaf_5 HGVSp_5  \
# 37     None    NaN    NaN    None   None  None  None    NaN    NaN    None
# 41     None    NaN    NaN    None   None  None  None    NaN    NaN    None
# 45     None    NaN    NaN    None   None  None  None    NaN    NaN    None
# 85     None    NaN    NaN    None   None  None  None    NaN    NaN    None
# 88     None    NaN    NaN    None   None  None  None    NaN    NaN    None
# ...     ...    ...    ...     ...    ...   ...   ...    ...    ...     ...
# 29146  None    NaN    NaN    None   None  None  None    NaN    NaN    None
# 29181  None    NaN    NaN    None   None  None  None    NaN    NaN    None
# 29238  None    NaN    NaN    None   None  None  None    NaN    NaN    None
# 29244  None    NaN    NaN    None   None  None  None    NaN    NaN    None
# 29283  None    NaN    NaN    None   None  None  None    NaN    NaN    None
#
#       spot_5  tp53_count  tcn  mcn  lcn  seg_length    cn_state        cf  \
# 37      None           0  3.0  2.0  1.0  37566216.0  LOSS AFTER  0.319947
# 41      None           0  3.0  2.0  1.0  80668381.0  LOSS AFTER  0.303377
# 45      None           1  3.0  2.0  1.0  80668431.0  LOSS AFTER  0.171336
# 85      None           0  3.0  2.0  1.0  80668370.0  LOSS AFTER  0.628645
# 88      None           0  3.0  2.0  1.0  41683023.0  LOSS AFTER  0.623412
# ...      ...         ...  ...  ...  ...         ...         ...       ...
# 29146   None           2  3.0  2.0  1.0  20839566.0  LOSS AFTER  0.310078
# 29181   None           0  3.0  2.0  1.0  80668650.0  LOSS AFTER  0.460274
# 29238   None           1  3.0  2.0  1.0  43234200.0  LOSS AFTER  0.434324
# 29244   None           0  3.0  2.0  1.0  80668531.0  LOSS AFTER  0.831630
# 29283   None           0  3.0  2.0  1.0  80668381.0  LOSS AFTER  0.244819
#
#        wgd  mutation_count  gene_count   max_vaf
# 37     1.0               6         6.0  0.540453
# 41     1.0               5         5.0  0.302026
# 45     1.0              14        14.0  0.242208
# 85     1.0               3         3.0  0.110197
# 88     1.0               6         6.0  0.395810
# ...    ...             ...         ...       ...
# 29146  1.0               7         6.0  0.440162
# 29181  1.0              13        13.0  0.572903
# 29238  1.0               4         4.0  0.329564
# 29244  1.0               2         2.0       NaN
# 29283  1.0              10         9.0  0.518160
#
# [1014 rows x 52 columns]

# %%
master_file = pd.read_pickle(data_path + 'merged_data/master_file.pkl')

inconsistent = []
for cn_state in ['CNLOH', 'HETLOSS', 'CNLOH & GAIN', 'DIPLOID']:
    print(cn_state, list(master_file[master_file['cn_state'] == cn_state][master_file['wgd'] == 1]['Sample_Id']))
# Out:
# CNLOH ['P-0026468-T01-IM6_P-0026468-N01-IM6', 'P-0006688-T01-IM5_P-0006688-N01-IM5', 'P-0019652-T02-IM6_P-0019652-N01-IM6', 'P-0019413-T01-IM6_P-0019413-N01-IM6', 'P-0016973-T01-IM6_P-0016973-N01-IM6', 'P-0010790-T01-IM5_P-0010790-N01-IM5', 'P-0015281-T01-IM6_P-0015281-N01-IM6', 'P-0027996-T01-IM6_P-0027996-N01-IM6', 'P-0015884-T01-IM6_P-0015884-N01-IM6', 'P-0002849-T01-IM3_P-0002849-N01-IM3', 'P-0021829-T01-IM6_P-0021829-N01-IM6', 'P-0022151-T01-IM6_P-0022151-N01-IM6', 'P-0030980-T01-IM6_P-0030980-N01-IM6', 'P-0021804-T01-IM6_P-0021804-N01-IM6', 'P-0010337-T01-IM5_P-0010337-N01-IM5', 'P-0029301-T01-IM6_P-0029301-N01-IM6', 'P-0005158-T01-IM5_P-0005158-N01-IM5', 'P-0009505-T01-IM5_P-0009505-N01-IM5', 'P-0008813-T01-IM5_P-0008813-N01-IM5', 'P-0008813-T02-IM5_P-0008813-N01-IM5', 'P-0029988-T01-IM6_P-0029988-N01-IM6', 'P-0004046-T02-IM5_P-0004046-N01-IM5', 'P-0027163-T01-IM6_P-0027163-N01-IM6', 'P-0018024-T01-IM6_P-0018024-N01-IM6', 'P-0030506-T01-IM6_P-0030506-N01-IM6', 'P-0004116-T01-IM5_P-0004116-N01-IM5', 'P-0015553-T01-IM6_P-0015553-N01-IM6', 'P-0014637-T01-IM6_P-0014637-N01-IM6', 'P-0018689-T01-IM6_P-0018689-N01-IM6', 'P-0019919-T01-IM6_P-0019919-N01-IM6', 'P-0012808-T01-IM5_P-0012808-N01-IM5', 'P-0018927-T02-IM6_P-0018927-N01-IM6', 'P-0018592-T01-IM6_P-0
01-IM6_P-0046244-N01-IM6', 'P-0014833-T02-IM6_P-0014833-N02-IM6', 'P-0047571-T01-IM6_P-0047571-N01-IM6', 'P-0047889-T01-IM6_P-0047889-N01-IM6', 'P-0048296-T01-IM6_P-0048296-N01-IM6', 'P-0047687-T02-IM6_P-0047687-N01-IM6', 'P-0047363-T02-IM6_P-0047363-N01-IM6', 'P-0048257-T01-IM6_P-0048257-N01-IM6', 'P-0000088-T01-IM3_P-0000088-N01-IM3', 'P-0049149-T01-IM6_P-0049149-N01-IM6', 'P-0048291-T02-IM6_P-0048291-N01-IM6', 'P-0049930-T01-IM6_P-0049930-N01-IM6']

# %%
master_file
# Out:
#                                  Sample_Id           Tumor_Id Patient_Id  \
# 0      P-0034223-T01-IM6_P-0034223-N01-IM6  P-0034223-T01-IM6  P-0034223
# 1      P-0009819-T01-IM5_P-0009819-N01-IM5  P-0009819-T01-IM5  P-0009819
# 2      P-0025956-T01-IM6_P-0025956-N01-IM6  P-0025956-T01-IM6  P-0025956
# 3      P-0027408-T01-IM6_P-0027408-N01-IM6  P-0027408-T01-IM6  P-0027408
# 4      P-0006554-T01-IM5_P-0006554-N01-IM5  P-0006554-T01-IM5  P-0006554
# ...                                    ...                ...        ...
# 29299  P-0050644-T01-IM6_P-0050644-N01-IM6  P-0050644-T01-IM6  P-0050644
# 29300  P-0050741-T01-IM6_P-0050741-N01-IM6  P-0050741-T01-IM6  P-0050741
# 29301  P-0050747-T01-IM6_P-0050747-N01-IM6  P-0050747-T01-IM6  P-0050747
# 29302  P-0050652-T01-IM6_P-0050652-N01-IM6  P-0050652-T01-IM6  P-0050652
# 29303  P-0050745-T01-IM6_P-0050745-N01-IM6  P-0050745-T01-IM6  P-0050745
#
#                       Cancer_Type Sample_Type    purity    ploidy  \
# 0                   Breast Cancer  Metastasis  0.941111  2.241830
# 1                 Prostate Cancer     Primary  0.275237  2.681075
# 2      Non-Small Cell Lung Cancer     Primary  0.185874  3.496971
# 3      Non-Small Cell Lung Cancer  Metastasis  0.308886  1.811066
# 4                          Glioma     Primary  0.715208  1.910719
# ...                           ...         ...       ...       ...
# 29299             Prostate Cancer     Primary  0.576103  2.175837
# 29300      Small Cell Lung Cancer  Metastasis  0.833591  2.006039
# 29301           Pancreatic Cancer     Primary  0.360576  2.187990
# 29302           Pancreatic Cancer     Primary  0.171442  2.011650
# 29303               Breast Cancer     Primary  0.597798  1.808634
#
#        samples_per_patient Overall Survival Status  Overall Survival (Months)  \
# 0                      1.0                  LIVING                        NaN
# 1                      1.0                  LIVING                     23.441
# 2                      1.0                DECEASED                      3.584
# 3                      1.0                  LIVING                     22.586
# 4                      1.0                  LIVING                     26.170
# ...                    ...                     ...                        ...
# 29299                  1.0                  LIVING                      1.249
# 29300                  1.0                  LIVING                      1.940
# 29301                  1.0                  LIVING                        NaN
# 29302                  1.0                  LIVING                      1.085
# 29303                  1.0                  LIVING                      1.841
#
#        MSI Score                               key_1               vc_1  \
# 0           0.55                                None               None
# 1           0.00                                None               None
# 2           0.00                                None               None
# 3           0.27  P-0027408-T01-IM6_17_7578409_CT_TC  Missense_Mutation
# 4           1.30                                None               None
# ...          ...                                 ...                ...
# 29299       0.00                                None               None
# 29300       0.22    P-0050741-T01-IM6_17_7578394_T_A  Missense_Mutation
# 29301       0.05    P-0050747-T01-IM6_17_7577570_C_T  Missense_Mutation
# 29302       0.26    P-0050652-T01-IM6_17_7578208_T_C  Missense_Mutation
# 29303       1.85    P-0050745-T01-IM6_17_7577079_C_A  Nonsense_Mutation
#
#        ccf_1     vaf_1      HGVSp_1 spot_1 key_2  vc_2  ccf_2  vaf_2 HGVSp_2  \
# 0        NaN       NaN         None   None  None  None    NaN    NaN    None
# 1        NaN       NaN         None   None  None  None    NaN    NaN    None
# 2        NaN       NaN         None   None  None  None    NaN    NaN    None
# 3      0.925  0.168901  p.Arg174Glu    174  None  None    NaN    NaN    None
# 4        NaN       NaN         None   None  None  None    NaN    NaN    None
# ...      ...       ...          ...    ...   ...   ...    ...    ...     ...
# 29299    NaN       NaN         None   None  None  None    NaN    NaN    None
# 29300  1.000  0.757801  p.His179Leu    179  None  None    NaN    NaN    None
# 29301  0.937  0.168975  p.Met237Ile    237  None  None    NaN    NaN    None
# 29302    NaN  0.082168  p.His214Arg    214  None  None    NaN    NaN    None
# 29303  0.994  0.428571  p.Glu287Ter    287  None  None    NaN    NaN    None
#
#       spot_2 key_3  vc_3  ccf_3  vaf_3 HGVSp_3 spot_3 key_4  vc_4  ccf_4  \
# 0       None  None  None    NaN    NaN    None   None  None  None    NaN
# 1       None  None  None    NaN    NaN    None   None  None  None    NaN
# 2       None  None  None    NaN    NaN    None   None  None  None    NaN
# 3       None  None  None    NaN    NaN    None   None  None  None    NaN
# 4       None  None  None    NaN    NaN    None   None  None  None    NaN
# ...      ...   ...   ...    ...    ...     ...    ...   ...   ...    ...
# 29299   None  None  None    NaN    NaN    None   None  None  None    NaN
# 29300   None  None  None    NaN    NaN    None   None  None  None    NaN
# 29301   None  None  None    NaN    NaN    None   None  None  None    NaN
# 29302   None  None  None    NaN    NaN    None   None  None  None    NaN
# 29303   None  None  None    NaN    NaN    None   None  None  None    NaN
#
#        vaf_4 HGVSp_4 spot_4 key_5  vc_5  ccf_5  vaf_5 HGVSp_5 spot_5  \
# 0        NaN    None   None  None  None    NaN    NaN    None   None
# 1        NaN    None   None  None  None    NaN    NaN    None   None
# 2        NaN    None   None  None  None    NaN    NaN    None   None
# 3        NaN    None   None  None  None    NaN    NaN    None   None
# 4        NaN    None   None  None  None    NaN    NaN    None   None
# ...      ...     ...    ...   ...   ...    ...    ...     ...    ...
# 29299    NaN    None   None  None  None    NaN    NaN    None   None
# 29300    NaN    None   None  None  None    NaN    NaN    None   None
# 29301    NaN    None   None  None  None    NaN    NaN    None   None
# 29302    NaN    None   None  None  None    NaN    NaN    None   None
# 29303    NaN    None   None  None  None    NaN    NaN    None   None
#
#        tp53_count  tcn  mcn  lcn  seg_length       cn_state        cf  wgd  \
# 0               0  2.0  1.0  1.0  80668592.0        DIPLOID  1.000000 -1.0
# 1               0  1.0  1.0  0.0  80668309.0        HETLOSS  0.154578 -1.0
# 2               0  NaN  NaN  NaN         NaN            NaN       NaN  NaN
# 3               1  1.0  1.0  0.0  25260272.0        HETLOSS  0.315621 -1.0
# 4               0  2.0  NaN  NaN   7465132.0  INDETERMINATE       NaN  NaN
# ...           ...  ...  ...  ...         ...            ...       ...  ...
# 29299           0  2.0  1.0  1.0  80668455.0        DIPLOID  1.000000 -1.0
# 29300           1  1.0  1.0  0.0  21694879.0        HETLOSS  0.824066 -1.0
# 29301           1  1.0  1.0  0.0  18461117.0        HETLOSS  0.254038 -1.0
# 29302           1  2.0  1.0  1.0  28981250.0        DIPLOID  1.000000 -1.0
# 29303           1  1.0  1.0  0.0  29307621.0        HETLOSS  0.602685 -1.0
#
#        mutation_count  gene_count   max_vaf  exp_nb_1  exp_nb_2  exp_nb_3  \
# 0                   6         6.0  0.901899       NaN       NaN       NaN
# 1                   3         3.0  0.148014       NaN       NaN       NaN
# 2                   6         6.0  0.200000       NaN       NaN       NaN
# 3                  21        19.0  0.192475  0.924711       NaN       NaN
# 4                  47        39.0  0.706897       NaN       NaN       NaN
# ...               ...         ...       ...       ...       ...       ...
# 29299               3         3.0  0.300000       NaN       NaN       NaN
# 29300               8         8.0  0.757801  1.060359       NaN       NaN
# 29301               6         6.0  0.270471  0.768275       NaN       NaN
# 29302               3         3.0  0.086842  0.958552       NaN       NaN
# 29303               9         9.0  0.451400  1.005263       NaN       NaN
#
#        exp_nb_4  exp_nb_5   cn_group mut_cn_group      chr_comput  \
# 0           NaN       NaN  WILD_TYPE         None    (3, 2, 2, 0)
# 1           NaN       NaN       LOSS    0_HETLOSS    (4, 4, 0, 0)
# 2           NaN       NaN       None         None    (0, 0, 0, 0)
# 3           NaN       NaN       LOSS     >=1_LOSS  (12, 11, 3, 0)
# 4           NaN       NaN       None         None    (5, 4, 1, 0)
# ...         ...       ...        ...          ...             ...
# 29299       NaN       NaN  WILD_TYPE         None    (7, 7, 0, 0)
# 29300       NaN       NaN       LOSS     >=1_LOSS    (6, 5, 2, 0)
# 29301       NaN       NaN       LOSS     >=1_LOSS    (5, 5, 1, 0)
# 29302       NaN       NaN  WILD_TYPE  1_WILD_TYPE    (2, 1, 0, 1)
# 29303       NaN       NaN       LOSS     >=1_LOSS    (7, 7, 0, 0)
#
#        chr_affected  chr_loss  chr_gain  chr_cnloh vc_group_1 vc_group_2  \
# 0                 3         2         2          0       None       None
# 1                 4         4         0          0       None       None
# 2                 0         0         0          0       None       None
# 3                12        11         3          0   missense       None
# 4                 5         4         1          0       None       None
# ...             ...       ...       ...        ...        ...        ...
# 29299             7         7         0          0       None       None
# 29300             6         5         2          0   missense       None
# 29301             5         5         1          0   missense       None
# 29302             2         1         0          1   missense       None
# 29303             7         7         0          0  truncated       None
#
#       vc_group_3 vc_group_4 vc_group_5
# 0           None       None       None
# 1           None       None       None
# 2           None       None       None
# 3           None       None       None
# 4           None       None       None
# ...          ...        ...        ...
# 29299       None       None       None
# 29300       None       None       None
# 29301       None       None       None
# 29302       None       None       None
# 29303       None       None       None
#
# [29259 rows x 69 columns]
